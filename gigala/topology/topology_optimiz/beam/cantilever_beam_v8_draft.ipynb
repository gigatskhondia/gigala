# %%
import time
import os
import random
import numpy as np                                                
import matplotlib.pyplot as plt                                   
import autograd, autograd.core, autograd.extend, autograd.tracer  
import autograd.numpy as anp      
import scipy, scipy.ndimage, scipy.sparse, scipy.sparse.linalg    
                                                     
import gym
from gymnasium import spaces

from stable_baselines3 import PPO, A2C
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common import results_plotter

from skimage.transform import resize
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# The below code is my RL extension to https://www.researchgate.net/publication/360698153_A_Tutorial_on_Structural_Optimization

# %%
x0,y0=16,16

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d
    
def get_args(normals, forces, density=1e-4):  # Manage the problem setup parameters
    width = normals.shape[0] - 1
    height = normals.shape[1] - 1
    fixdofs = np.flatnonzero(normals.ravel())
    alldofs = np.arange(2 * (width + 1) * (height + 1))
    freedofs = np.sort(list(set(alldofs) - set(fixdofs)))
    params = {
      # material properties
      'young': 1, 'young_min': 1e-9, 'poisson': 0.3, 'g': 0,
      # constraints
      'density': density, 'xmin': 0.001, 'xmax': 1.0,
      # input parameters
      'nelx': width, 'nely': height, 'mask': 1, 'penal': 3.0, 'filter_width': 1,
      'freedofs': freedofs, 'fixdofs': fixdofs, 'forces': forces.ravel(),
      # optimization parameters
      'opt_steps': 80, 'print_every': 10}
    return ObjectView(params)

def mbb_beam(width = y0, height = x0, density=1e-4, y=1, x=0, rd=-1):  # textbook beam example
    normals = np.zeros((width + 1, height + 1, 2))
    normals[0, 0, x] = 1
    normals[0, 0, y] = 1
    normals[0, -1, x] = 1
    normals[0, -1, y] = 1
    forces = np.zeros((width + 1, height + 1, 2))
    forces[-1, rd, y] = -1
    return normals, forces, density

# %%
def young_modulus(x, e_0, e_min, p=3):
    return e_min + x ** p * (e_0 - e_min)

def physical_density(x, args, volume_contraint=False, use_filter=True):
    x = args.mask * x.reshape(args.nely, args.nelx)  # reshape from 1D to 2D
    return gaussian_filter(x, args.filter_width) if use_filter else x  # maybe filter

def mean_density(x, args, volume_contraint=False, use_filter=True):
    return anp.mean(physical_density(x, args, volume_contraint, use_filter)) / anp.mean(args.mask)

# %%
def objective(x, args, volume_contraint=False, use_filter=True):
    kwargs = dict(penal=args.penal, e_min=args.young_min, e_0=args.young)
    x_phys = physical_density(x, args, volume_contraint=volume_contraint, use_filter=use_filter)
    ke     = get_stiffness_matrix(args.young, args.poisson)  # stiffness matrix
    u      = displace(x_phys, ke, args.forces, args.freedofs, args.fixdofs, **kwargs)
    c      = compliance(x_phys, u, ke, **kwargs)
    return c

# %%
@autograd.extend.primitive
def gaussian_filter(x, width): # 2D gaussian blur/filter
    return scipy.ndimage.gaussian_filter(x, width, mode='reflect')

def _gaussian_filter_vjp(ans, x, width): # gives the gradient of orig. function w.r.t. x
    del ans, x  # unused
    return lambda g: gaussian_filter(g, width)
autograd.extend.defvjp(gaussian_filter, _gaussian_filter_vjp)

# %%
def compliance(x_phys, u, ke, *, penal=3, e_min=1e-9, e_0=1):
    nely, nelx = x_phys.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords for the index map

    n1 = (nely+1)*(elx+0) + (ely+0)  # nodes
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    all_ixs = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    u_selected = u[all_ixs]  # select from u matrix

    ke_u = anp.einsum('ij,jkl->ikl', ke, u_selected)  # compute x^penal * U.T @ ke @ U
    ce = anp.einsum('ijk,ijk->jk', u_selected, ke_u)
    C = young_modulus(x_phys, e_0, e_min, p=penal) * ce.T
    return anp.sum(C)

def get_stiffness_matrix(e, nu):  # e=young's modulus, nu=poisson coefficient
    k = anp.array([1/2-nu/6, 1/8+nu/8, -1/4-nu/12, -1/8+3*nu/8,
                -1/4+nu/12, -1/8-nu/8, nu/6, 1/8-3*nu/8])
    return e/(1-nu**2)*anp.array([[k[0], k[1], k[2], k[3], k[4], k[5], k[6], k[7]],
                               [k[1], k[0], k[7], k[6], k[5], k[4], k[3], k[2]],
                               [k[2], k[7], k[0], k[5], k[6], k[3], k[4], k[1]],
                               [k[3], k[6], k[5], k[0], k[7], k[2], k[1], k[4]],
                               [k[4], k[5], k[6], k[7], k[0], k[1], k[2], k[3]],
                               [k[5], k[4], k[3], k[2], k[1], k[0], k[7], k[6]],
                               [k[6], k[3], k[4], k[1], k[2], k[7], k[0], k[5]],
                               [k[7], k[2], k[1], k[4], k[3], k[6], k[5], k[0]]])

# %%
def get_k(stiffness, ke):
    # Constructs sparse stiffness matrix k (used in the displace fn)
    # First, get position of the nodes of each element in the stiffness matrix
    nely, nelx = stiffness.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords
    ely, elx = ely.reshape(-1, 1), elx.reshape(-1, 1)

    n1 = (nely+1)*(elx+0) + (ely+0)
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    edof = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    edof = edof.T[0]
    x_list = anp.repeat(edof, 8)  # flat list pointer of each node in an element
    y_list = anp.tile(edof, 8).flatten()  # flat list pointer of each node in elem

    # make the global stiffness matrix K
    kd = stiffness.T.reshape(nelx*nely, 1, 1)
    value_list = (kd * anp.tile(ke, kd.shape)).flatten()
    return value_list, y_list, x_list

def displace(x_phys, ke, forces, freedofs, fixdofs, *, penal=3, e_min=1e-9, e_0=1):
    # Displaces the load x using finite element techniques (solve_coo=most of runtime)
    stiffness = young_modulus(x_phys, e_0, e_min, p=penal)
    k_entries, k_ylist, k_xlist = get_k(stiffness, ke)

    index_map, keep, indices = _get_dof_indices(freedofs, fixdofs, k_ylist, k_xlist)

    u_nonzero = solve_coo(k_entries[keep], indices, forces[freedofs], sym_pos=True)
    u_values = anp.concatenate([u_nonzero, anp.zeros(len(fixdofs))])
    return u_values[index_map]

# %%
def _get_dof_indices(freedofs, fixdofs, k_xlist, k_ylist):
    index_map = inverse_permutation(anp.concatenate([freedofs, fixdofs]))
    keep = anp.isin(k_xlist, freedofs) & anp.isin(k_ylist, freedofs)
    # Now we index an indexing array that is being indexed by the indices of k
    i = index_map[k_ylist][keep]
    j = index_map[k_xlist][keep]
    return index_map, keep, anp.stack([i, j])

def inverse_permutation(indices):  # reverses an index operation
    inverse_perm = np.zeros(len(indices), dtype=anp.int64)
    inverse_perm[indices] = np.arange(len(indices), dtype=anp.int64)
    return inverse_perm

# %%
def _get_solver(a_entries, a_indices, size, sym_pos):
    # a is (usu.) symmetric positive; could solve 2x faster w/sksparse.cholmod.cholesky(a).solve_A
    a = scipy.sparse.coo_matrix((a_entries, a_indices), shape=(size,)*2).tocsc()
    return scipy.sparse.linalg.splu(a).solve

@autograd.primitive
def solve_coo(a_entries, a_indices, b, sym_pos=False):
    solver = _get_solver(a_entries, a_indices, b.size, sym_pos)
    return solver(b)

def grad_solve_coo_entries(ans, a_entries, a_indices, b, sym_pos=False):
    def jvp(grad_ans):
        lambda_ = solve_coo(a_entries, a_indices if sym_pos else a_indices[::-1],
                            grad_ans, sym_pos)
        i, j = a_indices
        return -lambda_[i] * ans[j]
    return jvp

autograd.extend.defvjp(solve_coo, grad_solve_coo_entries,
                       lambda: print('err: gradient undefined'),
                       lambda: print('err: gradient not implemented'))

# %%
class Model:
    def __init__(self, shape):
        self.flag_ = True
#         self.flag_ = False
        self.n, self.m = shape
        self.actions_dic={} 
    
        k=0
        for i in range(self.n):
            for j in range(self.m):
                self.actions_dic[k]=(i,j)
                k+=1
        
    def action_space_(self, x, y, X):
#         x,y=self.actions_dic[action]
        X[x][y]=1
        
    def draw(self,X):  
        plt.figure(dpi=50) 
        print('\nFinal Cantilever beam design:')
        plt.imshow(X) 
        plt.show()

# %%
def fast_stopt(args, x):

    reshape = lambda x: x.reshape(args.nely, args.nelx)
    objective_fn = lambda x: objective(reshape(x), args)
#     constraint = lambda params: mean_density(reshape(params), args) - args.density
    constraint = lambda params: mean_density(reshape(params), args) 
    value = objective_fn(x)
    const = constraint(x)
    return value, const

# %%
class CantileverEnv(gym.Env):
    
    metadata = {"render.modes": ["human"]}

    def __init__(self, normalized_image: bool = False):
        super().__init__()
        
        
        self.rd=0
        self.args = get_args(*mbb_beam(rd=self.rd))
        
#         DIM=self.args.nelx*self.args.nely
#         N_DISCRETE_ACTIONS=self.args.nelx*self.args.nely
        N_DISCRETE_ACTIONS=4*4
        
        self.action_space = spaces.Discrete(N_DISCRETE_ACTIONS)
        self.observation_space = spaces.Box(low=0,
                                            high=255,
                                            shape=(self.args.nely, self.args.nelx, 1),
                                            dtype=np.float64)
        
 
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density
    
        self.M=Model((4,4))
        
        self.reward=0
        self.step_=0
        self.needs_reset = True
        self.level=1
        self.save_x, self.save_y = 0, 0
        
    def step(self, action):
        
        self.args = get_args(*mbb_beam(rd=self.rd))
        
        if self.level==1:
            self.save_x, self.save_y = self.M.actions_dic[action]
            self.level-=1
            self.reward+=0
            const=0
        else:
            x_c, y_c = self.M.actions_dic[action]
            x_c, y_c=x_c+2*self.save_x, y_c+2*self.save_y 
            self.M.action_space_(x_c, y_c, self.x)
            self.level=1
            
            tmp, const = fast_stopt(self.args, self.x)
        
            self.step_+=1
        
            self.reward+=-np.sqrt(tmp)
#         print(self.reward)    
       
        done=False
                  
        if self.step_>self.M.n*self.M.m:
            done=True
            
        if const>0.65:
#             self.reward-=1
            done=True
            
        if self.needs_reset:
            raise RuntimeError("Tried to step environment that needs reset")
            
        if done:
            self.needs_reset = True
                         
                
#         resized_x = resize(self.x, ( self.args.nely, self.args.nelx), anti_aliasing=True)  
#         resized_x = (resized_x * 255).astype(np.uint8).reshape(x0,y0,1)

        return self.x.reshape(x0,y0,1), self.reward, done, False, {}

    def reset(self, seed=0):
        
        if not self.M.flag_:
            self.rd=random.choice([0,2,-2])
        else:
            self.rd=-1
           
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density 

        self.reward=0
        self.needs_reset = False
        self.step_=0
        self.level=1
        
#         resized_x = resize(self.x, (self.args.nely, self.args.nelx), anti_aliasing=True)
#         resized_x = (resized_x * 255).astype(np.uint8).reshape(x0,y0,1)

        return self.x.reshape(x0,y0,1), {}

    def render(self, mode="human"):
        self.M.draw(self.x)    

    def close(self):
        pass

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %%
# ts=5e6
ts=3e6

# %%
# Create log dir
log_dir = "/tmp/gym8/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = CantileverEnv()
# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)
check_env(env)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/env_checker.py:30: UserWarning: It seems that your observation  is an image but its `dtype` is (float64) whereas it has to be `np.uint8`. If your observation is not an image, we recommend you to flatten the observation to have only a 1D vector
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/env_checker.py:51: UserWarning: The minimal resolution for an image is 36x36 for the default `CnnPolicy`. You might need to use a custom features extractor cf. https://stable-baselines3.readthedocs.io/en/master/guide/custom_policy.html
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.render_mode to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.render_mode` for environment variables or `env.get_wrapper_attr('render_mode')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:77: UserWarning: The `render_mode` attribute is not defined in your environment. It will be set to None.
#   warnings.warn("The `render_mode` attribute is not defined in your environment. It will be set to None.")

# %%
# callback = SaveOnBestTrainingRewardCallback(check_freq=5000, log_dir=log_dir)
callback = SaveOnBestTrainingRewardCallback(check_freq = 10000, log_dir = log_dir)

# %%
start = time.time()
model = PPO("MlpPolicy", env).learn(total_timesteps=ts, callback=callback)
# model = PPO.load(log_dir + "best_model.zip", env=env).learn(total_timesteps=ts, callback=callback)
end = time.time()
# Out:
# Num timesteps: 10000
# Best mean reward: -inf - Last mean reward per episode: -33649413.24
# Saving new best model to /tmp/gym8/best_model.zip
# Num timesteps: 20000
# Best mean reward: -33649413.24 - Last mean reward per episode: -33817878.46
# Num timesteps: 30000
# Best mean reward: -33649413.24 - Last mean reward per episode: -33844795.58
# Num timesteps: 40000
# Best mean reward: -33649413.24 - Last mean reward per episode: -33935984.11
# Num timesteps: 50000
# Best mean reward: -33649413.24 - Last mean reward per episode: -33937430.51
# Num timesteps: 60000
# Best mean reward: -33649413.24 - Last mean reward per episode: -33970629.80
# Num timesteps: 70000
# Best mean reward: -33649413.24 - Last mean reward per episode: -33846774.27
# Num timesteps: 80000
# Best mean reward: -33649413.24 - Last mean reward per episode: -33849545.65
# Num timesteps: 90000
# Best mean reward: -33649413.24 - Last mean reward per episode: -33804764.35
# Num timesteps: 100000
# Best mean reward: -33649413.24 - Last mean reward per episode: -33809187.51
# Num timesteps: 110000
# Best mean reward: -33649413.24 - Last mean reward per episode: -33883075.79
# Num timesteps: 120000
# Best mean reward: -33649413.24 - Last mean reward per episode: -33609128.09
# Saving new best model to /tmp/gym8/best_model.zip
# Num timesteps: 130000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33784228.07
# Num timesteps: 140000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34115644.16
# Num timesteps: 150000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33851572.94
# Num timesteps: 160000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34007544.12
# Num timesteps: 170000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33799188.90
# Num timesteps: 180000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33939170.94
# Num timesteps: 190000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33782276.71
# Num timesteps: 200000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34072000.00
# Num timesteps: 210000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33844474.15
# Num timesteps: 220000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33899246.57
# Num timesteps: 230000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33991370.35
# Num timesteps: 240000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33696086.37
# Num timesteps: 250000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33751658.68
# Num timesteps: 260000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33891103.34
# Num timesteps: 270000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33877992.94
# Num timesteps: 280000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34078264.76
# Num timesteps: 290000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34100043.94
# Num timesteps: 300000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33941713.15
# Num timesteps: 310000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33994517.40
# Num timesteps: 320000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33914567.42
# Num timesteps: 330000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33770263.22
# Num timesteps: 340000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34109248.15
# Num timesteps: 350000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33836693.71
# Num timesteps: 360000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33884052.07
# Num timesteps: 370000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34001034.24
# Num timesteps: 380000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33883702.35
# Num timesteps: 390000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34055821.34
# Num timesteps: 400000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33999547.98
# Num timesteps: 410000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33989263.39
# Num timesteps: 420000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33917209.86
# Num timesteps: 430000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33999862.06
# Num timesteps: 440000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33739915.19
# Num timesteps: 450000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33840701.63
# Num timesteps: 460000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33879183.25
# Num timesteps: 470000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33933795.81
# Num timesteps: 480000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33886360.20
# Num timesteps: 490000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34158404.41
# Num timesteps: 500000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33960373.20
# Num timesteps: 510000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33893655.23
# Num timesteps: 520000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33765919.20
# Num timesteps: 530000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33885850.96
# Num timesteps: 540000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33902225.09
# Num timesteps: 550000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33896993.41
# Num timesteps: 560000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33946246.17
# Num timesteps: 570000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33852584.02
# Num timesteps: 580000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33959946.60
# Num timesteps: 590000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33784031.47
# Num timesteps: 600000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33687355.25
# Num timesteps: 610000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33892010.72
# Num timesteps: 620000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33721578.38
# Num timesteps: 630000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33850747.50
# Num timesteps: 640000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33987349.95
# Num timesteps: 650000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33847233.40
# Num timesteps: 660000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34052928.63
# Num timesteps: 670000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33968282.17
# Num timesteps: 680000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34057104.16
# Num timesteps: 690000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33811458.95
# Num timesteps: 700000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34047737.24
# Num timesteps: 710000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33902247.18
# Num timesteps: 720000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33805511.97
# Num timesteps: 730000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33729830.63
# Num timesteps: 740000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34030036.95
# Num timesteps: 750000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33809916.65
# Num timesteps: 760000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33806417.63
# Num timesteps: 770000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34076397.35
# Num timesteps: 780000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33784628.47
# Num timesteps: 790000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33932798.93
# Num timesteps: 800000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33621557.74
# Num timesteps: 810000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33961022.46
# Num timesteps: 820000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34024310.93
# Num timesteps: 830000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33823135.62
# Num timesteps: 840000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33797198.52
# Num timesteps: 850000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33906683.18
# Num timesteps: 860000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33971341.66
# Num timesteps: 870000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33643195.84
# Num timesteps: 880000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34062385.30
# Num timesteps: 890000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34002938.81
# Num timesteps: 900000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34003601.99
# Num timesteps: 910000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33960822.49
# Num timesteps: 920000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33828166.59
# Num timesteps: 930000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33897199.17
# Num timesteps: 940000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33731386.86
# Num timesteps: 950000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33936806.04
# Num timesteps: 960000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33848943.33
# Num timesteps: 970000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33973205.75
# Num timesteps: 980000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33874795.12
# Num timesteps: 990000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33749125.90
# Num timesteps: 1000000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33847174.43
# Num timesteps: 1010000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33780039.84
# Num timesteps: 1020000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33760951.17
# Num timesteps: 1030000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34008005.78
# Num timesteps: 1040000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33843760.44
# Num timesteps: 1050000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33980074.48
# Num timesteps: 1060000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33790818.82
# Num timesteps: 1070000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33927258.66
# Num timesteps: 1080000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33973665.75
# Num timesteps: 1090000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33858400.13
# Num timesteps: 1100000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33767355.39
# Num timesteps: 1110000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33789552.44
# Num timesteps: 1120000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33840083.34
# Num timesteps: 1130000
# Best mean reward: -33609128.09 - Last mean reward per episode: -34033011.41
# Num timesteps: 1140000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33886377.10
# Num timesteps: 1150000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33989714.30
# Num timesteps: 1160000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33977411.47
# Num timesteps: 1170000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33873961.34
# Num timesteps: 1180000
# Best mean reward: -33609128.09 - Last mean reward per episode: -33483325.93
# Saving new best model to /tmp/gym8/best_model.zip
# Num timesteps: 1190000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33925135.20
# Num timesteps: 1200000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33884681.69
# Num timesteps: 1210000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33786386.58
# Num timesteps: 1220000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34023948.44
# Num timesteps: 1230000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33961444.65
# Num timesteps: 1240000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33874658.60
# Num timesteps: 1250000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33821836.32
# Num timesteps: 1260000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33738338.58
# Num timesteps: 1270000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33759604.64
# Num timesteps: 1280000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34195990.53
# Num timesteps: 1290000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33705756.38
# Num timesteps: 1300000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33883814.14
# Num timesteps: 1310000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33690492.18
# Num timesteps: 1320000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33891089.18
# Num timesteps: 1330000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34133872.30
# Num timesteps: 1340000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33730295.08
# Num timesteps: 1350000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33666044.46
# Num timesteps: 1360000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33793973.17
# Num timesteps: 1370000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33928446.75
# Num timesteps: 1380000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33902903.05
# Num timesteps: 1390000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33773064.45
# Num timesteps: 1400000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34012879.12
# Num timesteps: 1410000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33770995.04
# Num timesteps: 1420000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33646156.62
# Num timesteps: 1430000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33680341.05
# Num timesteps: 1440000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33940968.49
# Num timesteps: 1450000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33816769.37
# Num timesteps: 1460000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33814636.90
# Num timesteps: 1470000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33760549.56
# Num timesteps: 1480000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33981379.72
# Num timesteps: 1490000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33937402.73
# Num timesteps: 1500000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33773664.81
# Num timesteps: 1510000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33779159.34
# Num timesteps: 1520000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34116062.58
# Num timesteps: 1530000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33810822.37
# Num timesteps: 1540000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33847824.63
# Num timesteps: 1550000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33718306.54
# Num timesteps: 1560000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33932192.71
# Num timesteps: 1570000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34030447.62
# Num timesteps: 1580000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34050633.04
# Num timesteps: 1590000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34223222.94
# Num timesteps: 1600000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33854117.16
# Num timesteps: 1610000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33780062.54
# Num timesteps: 1620000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33801051.97
# Num timesteps: 1630000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33895595.61
# Num timesteps: 1640000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33710631.69
# Num timesteps: 1650000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33698667.99
# Num timesteps: 1660000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33817298.20
# Num timesteps: 1670000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33946034.32
# Num timesteps: 1680000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33830387.97
# Num timesteps: 1690000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33989636.38
# Num timesteps: 1700000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33973953.40
# Num timesteps: 1710000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33818101.14
# Num timesteps: 1720000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34023078.96
# Num timesteps: 1730000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33950359.27
# Num timesteps: 1740000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33850892.18
# Num timesteps: 1750000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33851556.09
# Num timesteps: 1760000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33568694.20
# Num timesteps: 1770000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33747400.11
# Num timesteps: 1780000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34028821.61
# Num timesteps: 1790000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33780267.95
# Num timesteps: 1800000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33851321.33
# Num timesteps: 1810000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33944456.65
# Num timesteps: 1820000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33879628.13
# Num timesteps: 1830000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33973868.74
# Num timesteps: 1840000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33882110.82
# Num timesteps: 1850000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33848634.66
# Num timesteps: 1860000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33686005.58
# Num timesteps: 1870000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34009046.90
# Num timesteps: 1880000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33825162.84
# Num timesteps: 1890000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34038752.78
# Num timesteps: 1900000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33944376.80
# Num timesteps: 1910000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33907929.96
# Num timesteps: 1920000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33786954.65
# Num timesteps: 1930000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33885457.17
# Num timesteps: 1940000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33927993.83
# Num timesteps: 1950000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33822955.13
# Num timesteps: 1960000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33864554.29
# Num timesteps: 1970000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33696048.58
# Num timesteps: 1980000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33749571.72
# Num timesteps: 1990000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33868527.18
# Num timesteps: 2000000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33880246.33
# Num timesteps: 2010000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33911840.39
# Num timesteps: 2020000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33774932.50
# Num timesteps: 2030000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33740448.66
# Num timesteps: 2040000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33807285.17
# Num timesteps: 2050000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33898960.04
# Num timesteps: 2060000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33820316.35
# Num timesteps: 2070000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33869041.26
# Num timesteps: 2080000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34113950.47
# Num timesteps: 2090000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33883197.64
# Num timesteps: 2100000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33967779.12
# Num timesteps: 2110000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33673391.26
# Num timesteps: 2120000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34281999.39
# Num timesteps: 2130000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33967897.17
# Num timesteps: 2140000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34166480.62
# Num timesteps: 2150000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33746463.56
# Num timesteps: 2160000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33807059.22
# Num timesteps: 2170000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33842865.62
# Num timesteps: 2180000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33855181.14
# Num timesteps: 2190000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33979111.16
# Num timesteps: 2200000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33834778.18
# Num timesteps: 2210000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33658344.90
# Num timesteps: 2220000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33815880.88
# Num timesteps: 2230000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33752451.90
# Num timesteps: 2240000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33755600.76
# Num timesteps: 2250000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33890206.93
# Num timesteps: 2260000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33809942.73
# Num timesteps: 2270000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33857841.68
# Num timesteps: 2280000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33931102.71
# Num timesteps: 2290000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33970546.71
# Num timesteps: 2300000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33817198.58
# Num timesteps: 2310000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33519087.52
# Num timesteps: 2320000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33758375.38
# Num timesteps: 2330000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34309190.57
# Num timesteps: 2340000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33778190.62
# Num timesteps: 2350000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33820485.58
# Num timesteps: 2360000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33944840.20
# Num timesteps: 2370000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33848416.31
# Num timesteps: 2380000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33941360.26
# Num timesteps: 2390000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33955056.13
# Num timesteps: 2400000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33768426.79
# Num timesteps: 2410000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34091895.29
# Num timesteps: 2420000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33852302.86
# Num timesteps: 2430000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33969417.58
# Num timesteps: 2440000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33838497.05
# Num timesteps: 2450000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33971896.12
# Num timesteps: 2460000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33951988.32
# Num timesteps: 2470000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33769974.53
# Num timesteps: 2480000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33920804.47
# Num timesteps: 2490000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33951158.57
# Num timesteps: 2500000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33899181.64
# Num timesteps: 2510000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34149294.55
# Num timesteps: 2520000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34009138.03
# Num timesteps: 2530000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33767847.41
# Num timesteps: 2540000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34111144.24
# Num timesteps: 2550000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33940828.84
# Num timesteps: 2560000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34026897.52
# Num timesteps: 2570000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34172209.17
# Num timesteps: 2580000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33962229.95
# Num timesteps: 2590000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34059771.15
# Num timesteps: 2600000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33678120.01
# Num timesteps: 2610000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33694830.11
# Num timesteps: 2620000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33928689.57
# Num timesteps: 2630000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33696560.68
# Num timesteps: 2640000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33783731.96
# Num timesteps: 2650000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33774678.82
# Num timesteps: 2660000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33880468.75
# Num timesteps: 2670000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34049820.36
# Num timesteps: 2680000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33897288.84
# Num timesteps: 2690000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33923661.00
# Num timesteps: 2700000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33915731.19
# Num timesteps: 2710000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33866892.28
# Num timesteps: 2720000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33876657.06
# Num timesteps: 2730000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33763658.27
# Num timesteps: 2740000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33906233.22
# Num timesteps: 2750000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33898578.96
# Num timesteps: 2760000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33965383.67
# Num timesteps: 2770000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34035793.05
# Num timesteps: 2780000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33837856.63
# Num timesteps: 2790000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33851451.58
# Num timesteps: 2800000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33825884.03
# Num timesteps: 2810000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33816437.98
# Num timesteps: 2820000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33851820.82
# Num timesteps: 2830000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33913069.36
# Num timesteps: 2840000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33883647.04
# Num timesteps: 2850000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34013169.04
# Num timesteps: 2860000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33674179.24
# Num timesteps: 2870000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33841780.97
# Num timesteps: 2880000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34072253.22
# Num timesteps: 2890000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33956123.08
# Num timesteps: 2900000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33891157.33
# Num timesteps: 2910000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33729554.90
# Num timesteps: 2920000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33878482.90
# Num timesteps: 2930000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33814949.62
# Num timesteps: 2940000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33915448.35
# Num timesteps: 2950000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33831159.54
# Num timesteps: 2960000
# Best mean reward: -33483325.93 - Last mean reward per episode: -34018341.08
# Num timesteps: 2970000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33813092.96
# Num timesteps: 2980000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33918047.67
# Num timesteps: 2990000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33791883.90
# Num timesteps: 3000000
# Best mean reward: -33483325.93 - Last mean reward per episode: -33898710.72

# %%
print('Total time taken: {} min'.format((end - start)/60))
# Out:
# Total time taken: 100.10941185156504 min

# %% [markdown]
# ### Inference

# %%
# env.M.flag_=True
env.M.flag_=False
obs=env.reset()
obs=obs[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.M to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.M` for environment variables or `env.get_wrapper_attr('M')` that will search the reminding wrappers.
#   logger.warn(

# %%
i=0
while i<2000:
    action, _states = model.predict(obs)
    obs, rewards, dones, _ , info = env.step(int(action))
    if dones: 
        break
    i+=1

# %%
print(i)
# Out:
# 33

# %%
fast_stopt(env.args, env.x)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.args to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.args` for environment variables or `env.get_wrapper_attr('args')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.x to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.x` for environment variables or `env.get_wrapper_attr('x')` that will search the reminding wrappers.
#   logger.warn(
# (9568856236.601734, 0.06649960937500002)

# %%
env.render()
# Out:
# Final Cantilever beam design:

# %%
results_plotter.plot_results([log_dir], ts, results_plotter.X_TIMESTEPS, "CantileverEnv")

# %%
obs=env.reset()
obs=obs[0]

# %%
# Load the agent
model_best = PPO.load(log_dir + "best_model.zip", env=env)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.render_mode to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.render_mode` for environment variables or `env.get_wrapper_attr('render_mode')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:77: UserWarning: The `render_mode` attribute is not defined in your environment. It will be set to None.
#   warnings.warn("The `render_mode` attribute is not defined in your environment. It will be set to None.")

# %%
i=0
while i<2000:
    action, _states = model_best.predict(obs)
    
    obs, rewards, dones, _ , info = env.step(int(action))
    if dones:
        break
    i+=1

# %%
i
# Out:
# 33

# %%
env.render()
# Out:
# Final Cantilever beam design:

# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/save_format.html

# %%
fast_stopt(env.args, env.x)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.args to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.args` for environment variables or `env.get_wrapper_attr('args')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.x to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.x` for environment variables or `env.get_wrapper_attr('x')` that will search the reminding wrappers.
#   logger.warn(
# (9943367803.796024, 0.05868789062500001)
