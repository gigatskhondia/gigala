# %%
import numpy as np
import autograd.numpy as anp      
import scipy, scipy.ndimage, scipy.sparse, scipy.sparse.linalg

# %%
import matplotlib.pyplot as plt  
import gym
from gym import spaces
import random
import numpy as np
import autograd.numpy as anp  
from gym.utils import seeding

# %%
from hbaselines.algorithms import RLAlgorithm
from hbaselines.goal_conditioned.td3 import GoalConditionedPolicy
# Out:
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:108: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d
    
def get_args(normals, forces, density=1e-4):  # Manage the problem setup parameters
    width = normals.shape[0] - 1
    height = normals.shape[1] - 1
    fixdofs = np.flatnonzero(normals.ravel())
    alldofs = np.arange(2 * (width + 1) * (height + 1))
    freedofs = np.sort(list(set(alldofs) - set(fixdofs)))
    params = {
      # material properties
      'young': 1, 'young_min': 1e-9, 'poisson': 0.3, 'g': 0,
      # constraints
      'density': density, 'xmin': 0.001, 'xmax': 1.0,
      # input parameters
      'nelx': width, 'nely': height, 'mask': 1, 'penal': 3.0, 'filter_width': 1,
      'freedofs': freedofs, 'fixdofs': fixdofs, 'forces': forces.ravel(),
      # optimization parameters
      'opt_steps': 80, 'print_every': 10}
    return ObjectView(params)

def mbb_beam(width=4, height=4, density=1e-4, y=1, x=0, rd=-1):  # textbook rl_beam example
    normals = np.zeros((width + 1, height + 1, 2))
    normals[0, 0, x] = 1
    normals[0, 0, y] = 1
    normals[0, -1, x] = 1
    normals[0, -1, y] = 1
    forces = np.zeros((width + 1, height + 1, 2))
    forces[-1, rd, y] = -1
    return normals, forces, density

def young_modulus(x, e_0, e_min, p=3):
    return e_min + x ** p * (e_0 - e_min)

def physical_density(x, args, volume_contraint=False, use_filter=True):
    x = args.mask * x.reshape(args.nely, args.nelx)  # reshape from 1D to 2D
    return gaussian_filter(x, args.filter_width) if use_filter else x  # maybe filter

def mean_density(x, args, volume_contraint=False, use_filter=True):
    return anp.mean(physical_density(x, args, volume_contraint, use_filter)) / anp.mean(args.mask)

def objective(x, args, volume_contraint=False, use_filter=True):
    kwargs = dict(penal=args.penal, e_min=args.young_min, e_0=args.young)
    x_phys = physical_density(x, args, volume_contraint=volume_contraint, use_filter=use_filter)
    ke     = get_stiffness_matrix(args.young, args.poisson)  # stiffness matrix
    u      = displace(x_phys, ke, args.forces, args.freedofs, args.fixdofs, **kwargs)
    c      = compliance(x_phys, u, ke, **kwargs)
    return c

def gaussian_filter(x, width): # 2D gaussian blur/filter
    return scipy.ndimage.gaussian_filter(x, width, mode='reflect')

def _gaussian_filter_vjp(ans, x, width): # gives the gradient of orig. function w.r.t. x
    del ans, x  # unused
    return lambda g: gaussian_filter(g, width)

def compliance(x_phys, u, ke, *, penal=3, e_min=1e-9, e_0=1):
    nely, nelx = x_phys.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords for the index map

    n1 = (nely+1)*(elx+0) + (ely+0)  # nodes
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    all_ixs = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    u_selected = u[all_ixs]  # select from u matrix

    ke_u = anp.einsum('ij,jkl->ikl', ke, u_selected)  # compute x^penal * U.T @ ke @ U
    ce = anp.einsum('ijk,ijk->jk', u_selected, ke_u)
    C = young_modulus(x_phys, e_0, e_min, p=penal) * ce.T
    return anp.sum(C)

def get_stiffness_matrix(e, nu):  # e=young's modulus, nu=poisson coefficient
    k = anp.array([1/2-nu/6, 1/8+nu/8, -1/4-nu/12, -1/8+3*nu/8,
                -1/4+nu/12, -1/8-nu/8, nu/6, 1/8-3*nu/8])
    return e/(1-nu**2)*anp.array([[k[0], k[1], k[2], k[3], k[4], k[5], k[6], k[7]],
                               [k[1], k[0], k[7], k[6], k[5], k[4], k[3], k[2]],
                               [k[2], k[7], k[0], k[5], k[6], k[3], k[4], k[1]],
                               [k[3], k[6], k[5], k[0], k[7], k[2], k[1], k[4]],
                               [k[4], k[5], k[6], k[7], k[0], k[1], k[2], k[3]],
                               [k[5], k[4], k[3], k[2], k[1], k[0], k[7], k[6]],
                               [k[6], k[3], k[4], k[1], k[2], k[7], k[0], k[5]],
                               [k[7], k[2], k[1], k[4], k[3], k[6], k[5], k[0]]])
    
def get_k(stiffness, ke):
    # Constructs sparse stiffness matrix k (used in the displace fn)
    # First, get position of the nodes of each element in the stiffness matrix
    nely, nelx = stiffness.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords
    ely, elx = ely.reshape(-1, 1), elx.reshape(-1, 1)

    n1 = (nely+1)*(elx+0) + (ely+0)
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    edof = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    edof = edof.T[0]
    x_list = anp.repeat(edof, 8)  # flat list pointer of each node in an element
    y_list = anp.tile(edof, 8).flatten()  # flat list pointer of each node in elem

    # make the global stiffness matrix K
    kd = stiffness.T.reshape(nelx*nely, 1, 1)
    value_list = (kd * anp.tile(ke, kd.shape)).flatten()
    return value_list, y_list, x_list

def displace(x_phys, ke, forces, freedofs, fixdofs, *, penal=3, e_min=1e-9, e_0=1):
    # Displaces the load x using finite element techniques (solve_coo=most of runtime)
    stiffness = young_modulus(x_phys, e_0, e_min, p=penal)
    k_entries, k_ylist, k_xlist = get_k(stiffness, ke)

    index_map, keep, indices = _get_dof_indices(freedofs, fixdofs, k_ylist, k_xlist)

    u_nonzero = solve_coo(k_entries[keep], indices, forces[freedofs], sym_pos=True)
    u_values = anp.concatenate([u_nonzero, anp.zeros(len(fixdofs))])
    return u_values[index_map]    


def _get_dof_indices(freedofs, fixdofs, k_xlist, k_ylist):
    index_map = inverse_permutation(anp.concatenate([freedofs, fixdofs]))
    keep = anp.isin(k_xlist, freedofs) & anp.isin(k_ylist, freedofs)
    # Now we index an indexing array that is being indexed by the indices of k
    i = index_map[k_ylist][keep]
    j = index_map[k_xlist][keep]
    return index_map, keep, anp.stack([i, j])

def inverse_permutation(indices):  # reverses an index operation
    inverse_perm = np.zeros(len(indices), dtype=anp.int64)
    inverse_perm[indices] = np.arange(len(indices), dtype=anp.int64)
    return inverse_perm

def _get_solver(a_entries, a_indices, size, sym_pos):
    # a is (usu.) symmetric positive; could solve 2x faster w/sksparse.cholmod.cholesky(a).solve_A
    a = scipy.sparse.coo_matrix((a_entries, a_indices), shape=(size,)*2).tocsc()
    return scipy.sparse.linalg.splu(a).solve

def solve_coo(a_entries, a_indices, b, sym_pos=False):
    solver = _get_solver(a_entries, a_indices, b.size, sym_pos)
    return solver(b)

def grad_solve_coo_entries(ans, a_entries, a_indices, b, sym_pos=False):
    def jvp(grad_ans):
        lambda_ = solve_coo(a_entries, a_indices if sym_pos else a_indices[::-1],
                            grad_ans, sym_pos)
        i, j = a_indices
        return -lambda_[i] * ans[j]
    return jvp

def fast_stopt(args, x):

    reshape = lambda x: x.reshape(args.nely, args.nelx)
    objective_fn = lambda x: objective(reshape(x), args)
    # constraint = lambda params: mean_density(reshape(params), args) - args.density
    constraint = lambda params: mean_density(reshape(params), args) 
    value = objective_fn(x)
    const = constraint(x)
    return value, const

# %%
class Model:
    def __init__(self, x):
        self.flag_ = True
        # self.flag_ = False
        self.n, self.m = x.shape
        self.x0, self.y0 = 0, 0
#         self.actions_dic={} 
    
#         k=0
#         for i in range(self.n):
#             for j in range(self.m):
#                 self.actions_dic[k]=(i,j)
#                 k+=1
        
    def action_space_(self, act, X):
#         x,y=self.actions_dic[action]
        x, y =int(act[0]), int(act[1])
#         print(x,y)
#         print(x,y)
#         print(x,y)
        # penalty=(X[x][y]==1)
        X[x][y]=1
        # if penalty:
        #     return 1e-7
        # return 0
        
    def draw(self,X):  
        plt.figure(dpi=50) 
        print('\nFinal Cantilever rl_beam design:')
        plt.imshow(X) 
        plt.show(block=False)
        plt.pause(3)
        plt.close('all')


class CantileverEnv(gym.Env):
    
    metadata = {"render.modes": ["human"],
                # 'video.frames_per_second' : 30
                }

    def __init__(self):
        super().__init__()
        
        
        self.rd=0
        self.args = get_args(*mbb_beam(rd=self.rd))
        self.x0, self.y0 = 0, 0
        
#         DIM=self.args.nelx*self.args.nely 
#         self.N_DISCRETE_ACTIONS=self.args.nelx*self.args.nely
        DIM=2
        self.N_DISCRETE_ACTIONS=2
        
        self.action_space = spaces.Box(low=-1, high=1,
                                       shape=(self.N_DISCRETE_ACTIONS,), dtype=np.float32)
        
        self.observation_space = spaces.Box(low=np.array([0,0]),
                                            high=np.array([self.args.nely, self.args.nelx]),
                                            shape=(DIM,),
                                           dtype=np.float32)
        
 
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density 
    
        self.M=Model(self.x)
        
        self.reward=0
        self.step_=0
        self.needs_reset = True
        self.layer_dim=4
        self.n_layers=2
        self.optimizer='SGD'
        self.seed()
        
    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]   
    
    def step(self, action):
        
   
        
        self.args = get_args(*mbb_beam(rd=self.rd))
        
#         vec = action /np.sqrt(np.sum(action**2))
#         print(action)


        
#         act=np.argmax(vec)
        
        self.x0, self.y0 = self.x0 + action[0], self.y0 + action[1]
        act=np.array([self.x0, self.y0])
        
#         if not (0.5<=action[0]<=1):
#             done = True
        
#         if not (0.5<=action[1]<=1):
#             done = True
            
#         print(act)

        done=False

        if self.x0<0 or self.x0>=self.args.nely or self.y0<0 or self.y0>=self.args.nelx:
            done = True
        else:
            self.M.action_space_(act, self.x)
        
        self.tmp, self.const = fast_stopt(self.args, self.x)

#         self.tmp, self.const = fast_stopt(self.args, action)
        self.step_+=1
        
        # self.reward = (1/self.tmp)**2 if self.const <0.7 else (1/self.tmp)**2-(self.const-0.7)
        self.reward += (1/self.tmp)**2

       
        
            
        if self.const>0.68:
            done=True
            
              
        if self.step_ > self.M.n*self.M.m:
            done = True
#         if self.step_ >40:
#             done =True

        if self.needs_reset:
            raise RuntimeError("Tried to step environment that needs reset")
            
        
        if done:
            self.needs_reset = True
            
#         return  self.x.reshape(self.x.shape[0]*self.x.shape[1]), self.reward, done, dict()
        return  act, self.reward, done, dict()
    
    def reset(self):
        
        if not self.M.flag_:
            self.rd=random.choice([0,2,-2])
        else:
            self.rd=-1
           
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density 

        self.reward=0
        self.needs_reset = False
        self.step_=0
        
        self.x0, self.y0 = 0, 0
#         self.y=np.array([1e-4, 1e7])
#         return self.x.reshape(self.x.shape[0]*self.x.shape[1])
        return np.array([self.x0, self.y0])
       

    def render(self, mode="human"):
        self.M.draw(self.x)    

    def close(self):
        pass
    
    @property
    def horizon(self):
        """Return the environment horizon."""
        return 1200

# %%
env = CantileverEnv()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gym/spaces/box.py:78: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
alg = RLAlgorithm(
    policy=GoalConditionedPolicy,
    env=env,
    policy_kwargs={
         # include hindsight action and goal transitions in the replay buffer
        "hindsight": True,
        # specify the sub-goal testing rate
        "subgoal_testing_rate": 0.3,
        "meta_period":9,
        "model_params":{"layers":[50, 50]},
#         "l2_penalty":0.5,
    },
    total_steps=2_000_000
)
# Out:
# /Users/giga/Library/CloudStorage/Dropbox/Giga/D-2018-08/implementation/projects/miscellaneous/Ocean_Intella_1/ocean_intella_1/h_base/h-baselines/hbaselines/utils/tf_util.py:427: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   val = tf.layers.dense(

# %%
alg.learn(log_dir="train_v1")
# Out:
# Collecting initial exploration samples...
# Done!
# -------------------------------------------------------------------
# | rollout/episode_steps          | 7.803921568627451              |
# | rollout/episodes               | 255                            |
# | rollout/return                 | 1.988551853976788e-06          |
# | rollout/return_history         | 4.483904067393635e-06          |
# | total/duration                 | 11.503049850463867             |
# | total/episodes                 | 255                            |
# | total/epochs                   | 1                              |
# | total/steps                    | 2000                           |
# | total/steps_per_second         | 173.86693320461868             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 17.0                           |
# | rollout/episodes               | 118                            |
# | rollout/return                 | 3.4922143707914726e-07         |
# | rollout/return_history         | 2.5188368068795334e-07         |
# | total/duration                 | 16.328057050704956             |
# | total/episodes                 | 373                            |
# | total/epochs                   | 2                              |
# | total/steps                    | 4000                           |
# | total/steps_per_second         | 244.9770960242512              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.707602339181287             |
# | rollout/episodes               | 171                            |
# | rollout/return                 | 2.9071239942703074e-06         |
# | rollout/return_history         | 4.663721677149996e-06          |
# | total/duration                 | 20.950291872024536             |
# | total/episodes                 | 544                            |
# | total/epochs                   | 3                              |
# | total/steps                    | 6000                           |
# | total/steps_per_second         | 286.39219141438093             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 10.709677419354838             |
# | rollout/episodes               | 186                            |
# | rollout/return                 | 9.497875121082546e-06          |
# | rollout/return_history         | 8.05132203620288e-06           |
# | total/duration                 | 25.580798864364624             |
# | total/episodes                 | 730                            |
# | total/epochs                   | 4                              |
# | total/steps                    | 8000                           |
# | total/steps_per_second         | 312.73456479673956             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.201117318435754             |
# | rollout/episodes               | 179                            |
# | rollout/return                 | 2.3526756334111573e-05         |
# | rollout/return_history         | 2.592158590584199e-05          |
# | total/duration                 | 30.234818935394287             |
# | total/episodes                 | 909                            |
# | total/epochs                   | 5                              |
# | total/steps                    | 10000                          |
# | total/steps_per_second         | 330.7444976392279              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.133333333333333             |
# | rollout/episodes               | 180                            |
# | rollout/return                 | 1.754514515292147e-05          |
# | rollout/return_history         | 2.1972811907851618e-05         |
# | total/duration                 | 34.9350860118866               |
# | total/episodes                 | 1089                           |
# | total/epochs                   | 6                              |
# | total/steps                    | 12000                          |
# | total/steps_per_second         | 343.49421655687416             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.348571428571429             |
# | rollout/episodes               | 175                            |
# | rollout/return                 | 6.434562551211252e-05          |
# | rollout/return_history         | 9.20159887047235e-05           |
# | total/duration                 | 39.66526198387146              |
# | total/episodes                 | 1264                           |
# | total/epochs                   | 7                              |
# | total/steps                    | 14000                          |
# | total/steps_per_second         | 352.9536753266026              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.286516853932584             |
# | rollout/episodes               | 178                            |
# | rollout/return                 | 7.366038736136419e-05          |
# | rollout/return_history         | 6.478592837541017e-05          |
# | total/duration                 | 44.245972871780396             |
# | total/episodes                 | 1442                           |
# | total/epochs                   | 8                              |
# | total/steps                    | 16000                          |
# | total/steps_per_second         | 361.6148309444141              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.85207100591716              |
# | rollout/episodes               | 169                            |
# | rollout/return                 | 0.00010824131346245553         |
# | rollout/return_history         | 9.899313706903142e-05          |
# | total/duration                 | 48.8133659362793               |
# | total/episodes                 | 1611                           |
# | total/epochs                   | 9                              |
# | total/steps                    | 18000                          |
# | total/steps_per_second         | 368.75146089079584             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 13.032679738562091             |
# | rollout/episodes               | 153                            |
# | rollout/return                 | 0.00013519263491852755         |
# | rollout/return_history         | 0.00011625590569352941         |
# | total/duration                 | 53.604230880737305             |
# | total/episodes                 | 1764                           |
# | total/epochs                   | 10                             |
# | total/steps                    | 20000                          |
# | total/steps_per_second         | 373.10487757015846             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 13.28476821192053              |
# | rollout/episodes               | 151                            |
# | rollout/return                 | 4.4793806793390663e-05         |
# | rollout/return_history         | 5.2221466608591094e-05         |
# | total/duration                 | 58.220170974731445             |
# | total/episodes                 | 1915                           |
# | total/epochs                   | 11                             |
# | total/steps                    | 22000                          |
# | total/steps_per_second         | 377.87590849824846             |
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.5                           |
# | rollout/episodes               | 160                            |
# | rollout/return                 | 0.00011088140001143123         |
# | rollout/return_history         | 0.00012024720543388987         |
# | total/duration                 | 62.78620481491089              |
# | total/episodes                 | 2075                           |
# | total/epochs                   | 12                             |
# | total/steps                    | 24000                          |
# | total/steps_per_second         | 382.24957330595527             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.44375                       |
# | rollout/episodes               | 160                            |
# | rollout/return                 | 0.00012688404818974168         |
# | rollout/return_history         | 0.00012665091202584063         |
# | total/duration                 | 67.46668982505798              |
# | total/episodes                 | 2235                           |
# | total/epochs                   | 13                             |
# | total/steps                    | 26000                          |
# | total/steps_per_second         | 385.37536178843726             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.047904191616766             |
# | rollout/episodes               | 167                            |
# | rollout/return                 | 7.329241255445445e-05          |
# | rollout/return_history         | 7.843806266675434e-05          |
# | total/duration                 | 71.99361395835876              |
# | total/episodes                 | 2402                           |
# | total/epochs                   | 14                             |
# | total/steps                    | 28000                          |
# | total/steps_per_second         | 388.92338445733884             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.508670520231213             |
# | rollout/episodes               | 173                            |
# | rollout/return                 | 6.253425429044923e-05          |
# | rollout/return_history         | 6.953661990214708e-05          |
# | total/duration                 | 76.50200390815735              |
# | total/episodes                 | 2575                           |
# | total/epochs                   | 15                             |
# | total/steps                    | 30000                          |
# | total/steps_per_second         | 392.1465905130509              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.241573033707866             |
# | rollout/episodes               | 178                            |
# | rollout/return                 | 9.875257632856486e-05          |
# | rollout/return_history         | 8.272046073043906e-05          |
# | total/duration                 | 81.49576807022095              |
# | total/episodes                 | 2753                           |
# | total/epochs                   | 16                             |
# | total/steps                    | 32000                          |
# | total/steps_per_second         | 392.6584258022718              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.344632768361581             |
# | rollout/episodes               | 177                            |
# | rollout/return                 | 7.892688495169218e-05          |
# | rollout/return_history         | 7.74140154450589e-05           |
# | total/duration                 | 86.3021559715271               |
# | total/episodes                 | 2930                           |
# | total/epochs                   | 17                             |
# | total/steps                    | 34000                          |
# | total/steps_per_second         | 393.96466539280107             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.219101123595506             |
# | rollout/episodes               | 178                            |
# | rollout/return                 | 0.00010365617033734645         |
# | rollout/return_history         | 8.205139409702909e-05          |
# | total/duration                 | 91.06101489067078              |
# | total/episodes                 | 3108                           |
# | total/epochs                   | 18                             |
# | total/steps                    | 36000                          |
# | total/steps_per_second         | 395.339323235329               |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.341614906832298             |
# | rollout/episodes               | 161                            |
# | rollout/return                 | 0.00017519994408408035         |
# | rollout/return_history         | 0.00018734880997537607         |
# | total/duration                 | 95.68414878845215              |
# | total/episodes                 | 3269                           |
# | total/epochs                   | 19                             |
# | total/steps                    | 38000                          |
# | total/steps_per_second         | 397.1399702161129              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.343558282208589             |
# | rollout/episodes               | 163                            |
# | rollout/return                 | 0.00016658873607762795         |
# | rollout/return_history         | 0.0001330956145412754          |
# | total/duration                 | 100.64531588554382             |
# | total/episodes                 | 3432                           |
# | total/epochs                   | 20                             |
# | total/steps                    | 40000                          |
# | total/steps_per_second         | 397.4352869585001              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.308641975308642             |
# | rollout/episodes               | 162                            |
# | rollout/return                 | 0.00012609216519273093         |
# | rollout/return_history         | 0.00011222272373035018         |
# | total/duration                 | 105.75306987762451             |
# | total/episodes                 | 3594                           |
# | total/epochs                   | 21                             |
# | total/steps                    | 42000                          |
# | total/steps_per_second         | 397.15159142520986             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.072289156626505             |
# | rollout/episodes               | 166                            |
# | rollout/return                 | 0.0001084748560243942          |
# | rollout/return_history         | 8.677739901991689e-05          |
# | total/duration                 | 110.25146889686584             |
# | total/episodes                 | 3760                           |
# | total/epochs                   | 22                             |
# | total/steps                    | 44000                          |
# | total/steps_per_second         | 399.08765334600275             |
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.257668711656441             |
# | rollout/episodes               | 163                            |
# | rollout/return                 | 0.00013681238898082757         |
# | rollout/return_history         | 0.0001552050693155922          |
# | total/duration                 | 114.74848508834839             |
# | total/episodes                 | 3923                           |
# | total/epochs                   | 23                             |
# | total/steps                    | 46000                          |
# | total/steps_per_second         | 400.87675200751613             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.207317073170731             |
# | rollout/episodes               | 164                            |
# | rollout/return                 | 0.00010492779462529911         |
# | rollout/return_history         | 8.609844728247008e-05          |
# | total/duration                 | 119.25462079048157             |
# | total/episodes                 | 4087                           |
# | total/epochs                   | 24                             |
# | total/steps                    | 48000                          |
# | total/steps_per_second         | 402.5001268867493              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.61006289308176              |
# | rollout/episodes               | 159                            |
# | rollout/return                 | 0.00010066654802476511         |
# | rollout/return_history         | 9.961009707073484e-05          |
# | total/duration                 | 123.83393883705139             |
# | total/episodes                 | 4246                           |
# | total/epochs                   | 25                             |
# | total/steps                    | 50000                          |
# | total/steps_per_second         | 403.7665317727896              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.105555555555556             |
# | rollout/episodes               | 180                            |
# | rollout/return                 | 7.600587887564959e-05          |
# | rollout/return_history         | 8.847260860785633e-05          |
# | total/duration                 | 128.8894078731537              |
# | total/episodes                 | 4426                           |
# | total/epochs                   | 26                             |
# | total/steps                    | 52000                          |
# | total/steps_per_second         | 403.4466513429538              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.405714285714286             |
# | rollout/episodes               | 175                            |
# | rollout/return                 | 8.793687424768476e-05          |
# | rollout/return_history         | 6.10436814594557e-05           |
# | total/duration                 | 133.50198698043823             |
# | total/episodes                 | 4601                           |
# | total/epochs                   | 27                             |
# | total/steps                    | 54000                          |
# | total/steps_per_second         | 404.48836171938405             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.695906432748538             |
# | rollout/episodes               | 171                            |
# | rollout/return                 | 5.870449893265274e-05          |
# | rollout/return_history         | 4.3563268124935357e-05         |
# | total/duration                 | 138.07349300384521             |
# | total/episodes                 | 4772                           |
# | total/epochs                   | 28                             |
# | total/steps                    | 56000                          |
# | total/steps_per_second         | 405.581105987088               |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.633720930232558             |
# | rollout/episodes               | 172                            |
# | rollout/return                 | 7.588441044640591e-05          |
# | rollout/return_history         | 9.908377522270489e-05          |
# | total/duration                 | 142.606342792511               |
# | total/episodes                 | 4944                           |
# | total/epochs                   | 29                             |
# | total/steps                    | 58000                          |
# | total/steps_per_second         | 406.71402733038803             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.880952380952381             |
# | rollout/episodes               | 168                            |
# | rollout/return                 | 8.834152374657966e-05          |
# | rollout/return_history         | 0.00010301525284019504         |
# | total/duration                 | 147.1073808670044              |
# | total/episodes                 | 5112                           |
# | total/epochs                   | 30                             |
# | total/steps                    | 60000                          |
# | total/steps_per_second         | 407.86532699025                |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.916666666666666             |
# | rollout/episodes               | 168                            |
# | rollout/return                 | 0.00010001608487664998         |
# | rollout/return_history         | 0.00011375003662137187         |
# | total/duration                 | 151.93628001213074             |
# | total/episodes                 | 5280                           |
# | total/epochs                   | 31                             |
# | total/steps                    | 62000                          |
# | total/steps_per_second         | 408.0658022892877              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.468571428571428             |
# | rollout/episodes               | 175                            |
# | rollout/return                 | 5.767113958127298e-05          |
# | rollout/return_history         | 5.434494410477253e-05          |
# | total/duration                 | 156.92571997642517             |
# | total/episodes                 | 5455                           |
# | total/epochs                   | 32                             |
# | total/steps                    | 64000                          |
# | total/steps_per_second         | 407.83626807393125             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.408045977011493             |
# | rollout/episodes               | 174                            |
# | rollout/return                 | 9.78791124569953e-05           |
# | rollout/return_history         | 9.956491943506244e-05          |
# | total/duration                 | 161.83586192131042             |
# | total/episodes                 | 5629                           |
# | total/epochs                   | 33                             |
# | total/steps                    | 66000                          |
# | total/steps_per_second         | 407.8206104410358              |
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.771929824561404             |
# | rollout/episodes               | 171                            |
# | rollout/return                 | 0.00012187519757945667         |
# | rollout/return_history         | 9.661966950003513e-05          |
# | total/duration                 | 166.50430297851562             |
# | total/episodes                 | 5800                           |
# | total/epochs                   | 34                             |
# | total/steps                    | 68000                          |
# | total/steps_per_second         | 408.39785389074405             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.705882352941176             |
# | rollout/episodes               | 170                            |
# | rollout/return                 | 9.363539003944008e-05          |
# | rollout/return_history         | 9.46077003828139e-05           |
# | total/duration                 | 171.1009919643402              |
# | total/episodes                 | 5970                           |
# | total/epochs                   | 35                             |
# | total/steps                    | 70000                          |
# | total/steps_per_second         | 409.1151032870047              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.794117647058824             |
# | rollout/episodes               | 170                            |
# | rollout/return                 | 9.14868575019162e-05           |
# | rollout/return_history         | 9.550787467090267e-05          |
# | total/duration                 | 175.92632007598877             |
# | total/episodes                 | 6140                           |
# | total/epochs                   | 36                             |
# | total/steps                    | 72000                          |
# | total/steps_per_second         | 409.2622409705419              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.601156069364162             |
# | rollout/episodes               | 173                            |
# | rollout/return                 | 8.845581307958534e-05          |
# | rollout/return_history         | 7.56112286420384e-05           |
# | total/duration                 | 180.62214708328247             |
# | total/episodes                 | 6313                           |
# | total/epochs                   | 37                             |
# | total/steps                    | 74000                          |
# | total/steps_per_second         | 409.69505232312173             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.76923076923077              |
# | rollout/episodes               | 169                            |
# | rollout/return                 | 0.00010201706694671412         |
# | rollout/return_history         | 0.0001293354484533604          |
# | total/duration                 | 185.14407992362976             |
# | total/episodes                 | 6482                           |
# | total/epochs                   | 38                             |
# | total/steps                    | 76000                          |
# | total/steps_per_second         | 410.49111606133613             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.300613496932515             |
# | rollout/episodes               | 163                            |
# | rollout/return                 | 0.00014267072443276938         |
# | rollout/return_history         | 0.00012761842295757304         |
# | total/duration                 | 189.6547179222107              |
# | total/episodes                 | 6645                           |
# | total/epochs                   | 39                             |
# | total/steps                    | 78000                          |
# | total/steps_per_second         | 411.27371285323204             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.21951219512195              |
# | rollout/episodes               | 164                            |
# | rollout/return                 | 0.0001033854701853428          |
# | rollout/return_history         | 0.0001009736576259333          |
# | total/duration                 | 194.1722800731659              |
# | total/episodes                 | 6809                           |
# | total/epochs                   | 40                             |
# | total/steps                    | 80000                          |
# | total/steps_per_second         | 412.0052562078133              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.012048192771084             |
# | rollout/episodes               | 166                            |
# | rollout/return                 | 0.00010933890455096457         |
# | rollout/return_history         | 0.00010577807015565177         |
# | total/duration                 | 198.7698769569397              |
# | total/episodes                 | 6975                           |
# | total/epochs                   | 41                             |
# | total/steps                    | 82000                          |
# | total/steps_per_second         | 412.53735855440505             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.892857142857142             |
# | rollout/episodes               | 168                            |
# | rollout/return                 | 0.0001564344573099022          |
# | rollout/return_history         | 0.00016548035372477527         |
# | total/duration                 | 203.35769391059875             |
# | total/episodes                 | 7143                           |
# | total/epochs                   | 42                             |
# | total/steps                    | 84000                          |
# | total/steps_per_second         | 413.06526635244273             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.462857142857143             |
# | rollout/episodes               | 175                            |
# | rollout/return                 | 0.00015075710066355343         |
# | rollout/return_history         | 0.00017978459096856092         |
# | total/duration                 | 208.01975393295288             |
# | total/episodes                 | 7318                           |
# | total/epochs                   | 43                             |
# | total/steps                    | 86000                          |
# | total/steps_per_second         | 413.4222754042809              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.517241379310345             |
# | rollout/episodes               | 174                            |
# | rollout/return                 | 0.00012639314407073026         |
# | rollout/return_history         | 0.00015129713113565973         |
# | total/duration                 | 212.75146794319153             |
# | total/episodes                 | 7492                           |
# | total/epochs                   | 44                             |
# | total/steps                    | 88000                          |
# | total/steps_per_second         | 413.6281683541548              |
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.792899408284024             |
# | rollout/episodes               | 169                            |
# | rollout/return                 | 0.0001254963741863831          |
# | rollout/return_history         | 0.00011714518180564322         |
# | total/duration                 | 217.502014875412               |
# | total/episodes                 | 7661                           |
# | total/epochs                   | 45                             |
# | total/steps                    | 90000                          |
# | total/steps_per_second         | 413.7892701893046              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.482758620689655             |
# | rollout/episodes               | 174                            |
# | rollout/return                 | 0.00012746011801182913         |
# | rollout/return_history         | 0.00014472296114690343         |
# | total/duration                 | 222.39894485473633             |
# | total/episodes                 | 7835                           |
# | total/epochs                   | 46                             |
# | total/steps                    | 92000                          |
# | total/steps_per_second         | 413.67102735173216             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.306748466257668             |
# | rollout/episodes               | 163                            |
# | rollout/return                 | 0.000135417769964842           |
# | rollout/return_history         | 9.249682407879293e-05          |
# | total/duration                 | 227.11346983909607             |
# | total/episodes                 | 7998                           |
# | total/epochs                   | 47                             |
# | total/steps                    | 94000                          |
# | total/steps_per_second         | 413.8900262789192              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.363636363636363             |
# | rollout/episodes               | 176                            |
# | rollout/return                 | 0.00010427360239032116         |
# | rollout/return_history         | 0.00010287765034169065         |
# | total/duration                 | 231.70269107818604             |
# | total/episodes                 | 8174                           |
# | total/epochs                   | 48                             |
# | total/steps                    | 96000                          |
# | total/steps_per_second         | 414.324061379182               |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.604651162790697             |
# | rollout/episodes               | 172                            |
# | rollout/return                 | 0.00010479446155202224         |
# | rollout/return_history         | 0.00010801145003370668         |
# | total/duration                 | 236.2473168373108              |
# | total/episodes                 | 8346                           |
# | total/epochs                   | 49                             |
# | total/steps                    | 98000                          |
# | total/steps_per_second         | 414.81952604560865             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.060240963855422             |
# | rollout/episodes               | 166                            |
# | rollout/return                 | 8.774759389577926e-05          |
# | rollout/return_history         | 9.89027729352834e-05           |
# | total/duration                 | 240.79747200012207             |
# | total/episodes                 | 8512                           |
# | total/epochs                   | 50                             |
# | total/steps                    | 100000                         |
# | total/steps_per_second         | 415.28675184741684             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.904761904761905             |
# | rollout/episodes               | 168                            |
# | rollout/return                 | 0.00011939643644840031         |
# | rollout/return_history         | 0.00012705322754814812         |
# | total/duration                 | 245.48267698287964             |
# | total/episodes                 | 8680                           |
# | total/epochs                   | 51                             |
# | total/steps                    | 102000                         |
# | total/steps_per_second         | 415.5079342201961              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.898809523809524             |
# | rollout/episodes               | 168                            |
# | rollout/return                 | 0.00010275309673862455         |
# | rollout/return_history         | 8.659186962579093e-05          |
# | total/duration                 | 250.86495685577393             |
# | total/episodes                 | 8848                           |
# | total/epochs                   | 52                             |
# | total/steps                    | 104000                         |
# | total/steps_per_second         | 414.56567431134346             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.011976047904191             |
# | rollout/episodes               | 167                            |
# | rollout/return                 | 0.00012876367021919105         |
# | rollout/return_history         | 0.00013055835189749714         |
# | total/duration                 | 255.3790078163147              |
# | total/episodes                 | 9015                           |
# | total/epochs                   | 53                             |
# | total/steps                    | 106000                         |
# | total/steps_per_second         | 415.069354785191               |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.857142857142858             |
# | rollout/episodes               | 168                            |
# | rollout/return                 | 0.00011855936371609561         |
# | rollout/return_history         | 0.00010588211691551492         |
# | total/duration                 | 260.40195393562317             |
# | total/episodes                 | 9183                           |
# | total/epochs                   | 54                             |
# | total/steps                    | 108000                         |
# | total/steps_per_second         | 414.7434317128813              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.494252873563218             |
# | rollout/episodes               | 174                            |
# | rollout/return                 | 0.00010904843436670056         |
# | rollout/return_history         | 0.00011440552811971322         |
# | total/duration                 | 265.38348484039307             |
# | total/episodes                 | 9357                           |
# | total/epochs                   | 55                             |
# | total/steps                    | 110000                         |
# | total/steps_per_second         | 414.4945193788385              |
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.85207100591716              |
# | rollout/episodes               | 169                            |
# | rollout/return                 | 0.00013797949323945456         |
# | rollout/return_history         | 0.00011271930747174964         |
# | total/duration                 | 270.21827507019043             |
# | total/episodes                 | 9526                           |
# | total/epochs                   | 56                             |
# | total/steps                    | 112000                         |
# | total/steps_per_second         | 414.47973854065754             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.54913294797688              |
# | rollout/episodes               | 173                            |
# | rollout/return                 | 0.00013154564385942173         |
# | rollout/return_history         | 0.00012629143644340884         |
# | total/duration                 | 275.0410008430481              |
# | total/episodes                 | 9699                           |
# | total/epochs                   | 57                             |
# | total/steps                    | 114000                         |
# | total/steps_per_second         | 414.48365752949684             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 12.294478527607362             |
# | rollout/episodes               | 163                            |
# | rollout/return                 | 0.0001256469952729156          |
# | rollout/return_history         | 0.00010267144125641782         |
# | total/duration                 | 279.56528782844543             |
# | total/episodes                 | 9862                           |
# | total/epochs                   | 58                             |
# | total/steps                    | 116000                         |
# | total/steps_per_second         | 414.9299110094924              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.520231213872833             |
# | rollout/episodes               | 173                            |
# | rollout/return                 | 0.0001348876294176593          |
# | rollout/return_history         | 0.00010992799296867623         |
# | total/duration                 | 284.4599528312683              |
# | total/episodes                 | 10035                          |
# | total/epochs                   | 59                             |
# | total/steps                    | 118000                         |
# | total/steps_per_second         | 414.8211332580564              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.970059880239521             |
# | rollout/episodes               | 167                            |
# | rollout/return                 | 0.00011669722514418609         |
# | rollout/return_history         | 0.00013439938524734647         |
# | total/duration                 | 289.1883919239044              |
# | total/episodes                 | 10202                          |
# | total/epochs                   | 60                             |
# | total/steps                    | 120000                         |
# | total/steps_per_second         | 414.95441501530325             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.557471264367816             |
# | rollout/episodes               | 174                            |
# | rollout/return                 | 0.00011870472604508398         |
# | rollout/return_history         | 0.0001118065978403901          |
# | total/duration                 | 294.3271269798279              |
# | total/episodes                 | 10376                          |
# | total/epochs                   | 61                             |
# | total/steps                    | 122000                         |
# | total/steps_per_second         | 414.5047765453214              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.554913294797688             |
# | rollout/episodes               | 173                            |
# | rollout/return                 | 0.00012829624677017875         |
# | rollout/return_history         | 0.00011392635005007499         |
# | total/duration                 | 299.546089887619               |
# | total/episodes                 | 10549                          |
# | total/epochs                   | 62                             |
# | total/steps                    | 124000                         |
# | total/steps_per_second         | 413.9596682651447              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.514450867052023             |
# | rollout/episodes               | 173                            |
# | rollout/return                 | 0.00014595862969926074         |
# | rollout/return_history         | 0.00015419244260285564         |
# | total/duration                 | 304.6118688583374              |
# | total/episodes                 | 10722                          |
# | total/epochs                   | 63                             |
# | total/steps                    | 126000                         |
# | total/steps_per_second         | 413.6411377279507              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 11.397727272727273             |
# | rollout/episodes               | 176                            |
# | rollout/return                 | 0.0001245960128178587          |
# | rollout/return_history         | 0.0001158004387197808          |
# | total/duration                 | 309.6837718486786              |
# | total/episodes                 | 10898                          |
# | total/epochs                   | 64                             |
# | total/steps                    | 128000                         |
# | total/steps_per_second         | 413.3248546925633              |
# -------------------------------------------------------------------
#
# ...
# | total/epochs                   | 979                            |
# | total/steps                    | 1958000                        |
# | total/steps_per_second         | 378.73892141454746             |
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.831932773109244             |
# | rollout/episodes               | 119                            |
# | rollout/return                 | 0.0008561395521992746          |
# | rollout/return_history         | 0.00087555829529223            |
# | total/duration                 | 5174.988433837891              |
# | total/episodes                 | 127862                         |
# | total/epochs                   | 980                            |
# | total/steps                    | 1960000                        |
# | total/steps_per_second         | 378.7448078500185              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.641666666666666             |
# | rollout/episodes               | 120                            |
# | rollout/return                 | 0.000725296637300697           |
# | rollout/return_history         | 0.0007669509822410199          |
# | total/duration                 | 5180.269592046738              |
# | total/episodes                 | 127982                         |
# | total/epochs                   | 981                            |
# | total/steps                    | 1962000                        |
# | total/steps_per_second         | 378.74476707008773             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.756302521008404             |
# | rollout/episodes               | 119                            |
# | rollout/return                 | 0.0009097389875844032          |
# | rollout/return_history         | 0.0009024716141191618          |
# | total/duration                 | 5185.111436843872              |
# | total/episodes                 | 128101                         |
# | total/epochs                   | 982                            |
# | total/steps                    | 1964000                        |
# | total/steps_per_second         | 378.77681587408046             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.475409836065573             |
# | rollout/episodes               | 122                            |
# | rollout/return                 | 0.0009467576413579934          |
# | rollout/return_history         | 0.0008673307884677191          |
# | total/duration                 | 5190.018320798874              |
# | total/episodes                 | 128223                         |
# | total/epochs                   | 983                            |
# | total/steps                    | 1966000                        |
# | total/steps_per_second         | 378.8040578048255              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.520661157024794             |
# | rollout/episodes               | 121                            |
# | rollout/return                 | 0.000766088932370062           |
# | rollout/return_history         | 0.0007964596234991563          |
# | total/duration                 | 5195.138397932053              |
# | total/episodes                 | 128344                         |
# | total/epochs                   | 984                            |
# | total/steps                    | 1968000                        |
# | total/steps_per_second         | 378.8157021540313              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.49586776859504              |
# | rollout/episodes               | 121                            |
# | rollout/return                 | 0.0008036481937047999          |
# | rollout/return_history         | 0.0008178032830606679          |
# | total/duration                 | 5200.021080970764              |
# | total/episodes                 | 128465                         |
# | total/epochs                   | 985                            |
# | total/steps                    | 1970000                        |
# | total/steps_per_second         | 378.84461799763153             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.683333333333334             |
# | rollout/episodes               | 120                            |
# | rollout/return                 | 0.0008056669463208494          |
# | rollout/return_history         | 0.0008194884447963868          |
# | total/duration                 | 5205.143637895584              |
# | total/episodes                 | 128585                         |
# | total/epochs                   | 986                            |
# | total/steps                    | 1972000                        |
# | total/steps_per_second         | 378.85601958090643             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.764705882352942             |
# | rollout/episodes               | 119                            |
# | rollout/return                 | 0.0008942718354598274          |
# | rollout/return_history         | 0.0008291006384832862          |
# | total/duration                 | 5210.280775785446              |
# | total/episodes                 | 128704                         |
# | total/epochs                   | 987                            |
# | total/steps                    | 1974000                        |
# | total/steps_per_second         | 378.8663384848815              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.636363636363637             |
# | rollout/episodes               | 121                            |
# | rollout/return                 | 0.0008394083871257874          |
# | rollout/return_history         | 0.0007841872267009467          |
# | total/duration                 | 5215.341110944748              |
# | total/episodes                 | 128825                         |
# | total/epochs                   | 988                            |
# | total/steps                    | 1976000                        |
# | total/steps_per_second         | 378.88221651566175             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.838983050847457             |
# | rollout/episodes               | 118                            |
# | rollout/return                 | 0.0009336301649119262          |
# | rollout/return_history         | 0.0009227022757181963          |
# | total/duration                 | 5220.37583398819               |
# | total/episodes                 | 128943                         |
# | total/epochs                   | 989                            |
# | total/steps                    | 1978000                        |
# | total/steps_per_second         | 378.8999227070736              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.75                          |
# | rollout/episodes               | 120                            |
# | rollout/return                 | 0.000836781338606489           |
# | rollout/return_history         | 0.0008642268524026221          |
# | total/duration                 | 5225.439982891083              |
# | total/episodes                 | 129063                         |
# | total/epochs                   | 990                            |
# | total/steps                    | 1980000                        |
# | total/steps_per_second         | 378.915460991387               |
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.705882352941178             |
# | rollout/episodes               | 119                            |
# | rollout/return                 | 0.0008061315897052323          |
# | rollout/return_history         | 0.0008244071327871058          |
# | total/duration                 | 5230.670986890793              |
# | total/episodes                 | 129182                         |
# | total/epochs                   | 991                            |
# | total/steps                    | 1982000                        |
# | total/steps_per_second         | 378.9188815292199              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.97457627118644              |
# | rollout/episodes               | 118                            |
# | rollout/return                 | 0.001011554193911447           |
# | rollout/return_history         | 0.0010319568706197652          |
# | total/duration                 | 5235.69615483284               |
# | total/episodes                 | 129300                         |
# | total/epochs                   | 992                            |
# | total/steps                    | 1984000                        |
# | total/steps_per_second         | 378.9371921761841              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.95762711864407              |
# | rollout/episodes               | 118                            |
# | rollout/return                 | 0.0007290735241431803          |
# | rollout/return_history         | 0.000717010898082858           |
# | total/duration                 | 5240.989048957825              |
# | total/episodes                 | 129418                         |
# | total/epochs                   | 993                            |
# | total/steps                    | 1986000                        |
# | total/steps_per_second         | 378.9361094724893              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.915254237288135             |
# | rollout/episodes               | 118                            |
# | rollout/return                 | 0.0007545086599989681          |
# | rollout/return_history         | 0.0007064984982626693          |
# | total/duration                 | 5246.082926988602              |
# | total/episodes                 | 129536                         |
# | total/epochs                   | 994                            |
# | total/steps                    | 1988000                        |
# | total/steps_per_second         | 378.949404282705               |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.932773109243698             |
# | rollout/episodes               | 119                            |
# | rollout/return                 | 0.0010124853450773276          |
# | rollout/return_history         | 0.0010297705352372956          |
# | total/duration                 | 5251.1363298892975             |
# | total/episodes                 | 129655                         |
# | total/epochs                   | 995                            |
# | total/steps                    | 1990000                        |
# | total/steps_per_second         | 378.96559429870155             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.965811965811966             |
# | rollout/episodes               | 117                            |
# | rollout/return                 | 0.0008812376489596948          |
# | rollout/return_history         | 0.0008923487601322484          |
# | total/duration                 | 5256.770308971405              |
# | total/episodes                 | 129772                         |
# | total/epochs                   | 996                            |
# | total/steps                    | 1992000                        |
# | total/steps_per_second         | 378.93989710761696             |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.831932773109244             |
# | rollout/episodes               | 119                            |
# | rollout/return                 | 0.000995972102056284           |
# | rollout/return_history         | 0.0009968946388981504          |
# | total/duration                 | 5262.30597281456               |
# | total/episodes                 | 129891                         |
# | total/epochs                   | 997                            |
# | total/steps                    | 1994000                        |
# | total/steps_per_second         | 378.9213341643651              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.873949579831933             |
# | rollout/episodes               | 119                            |
# | rollout/return                 | 0.0009176846522853222          |
# | rollout/return_history         | 0.0009225362902989327          |
# | total/duration                 | 5267.343697786331              |
# | total/episodes                 | 130010                         |
# | total/epochs                   | 998                            |
# | total/steps                    | 1996000                        |
# | total/steps_per_second         | 378.9386291308169              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.80672268907563              |
# | rollout/episodes               | 119                            |
# | rollout/return                 | 0.0008925963757429575          |
# | rollout/return_history         | 0.0008613837401525721          |
# | total/duration                 | 5272.483650922775              |
# | total/episodes                 | 130129                         |
# | total/epochs                   | 999                            |
# | total/steps                    | 1998000                        |
# | total/steps_per_second         | 378.9485434725465              |
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# | rollout/episode_steps          | 16.966101694915253             |
# | rollout/episodes               | 118                            |
# | rollout/return                 | 0.0007122031523040576          |
# | rollout/return_history         | 0.000692133541636162           |
# | total/duration                 | 5277.520752906799              |
# | total/episodes                 | 130247                         |
# | total/epochs                   | 1000                           |
# | total/steps                    | 2000000                        |
# | total/steps_per_second         | 378.9658238479541              |
# -------------------------------------------------------------------

# %%
obs = env.reset()
done = False
while not done:
    action = alg._policy(
                    obs=obs,
                    context=None
                )
    obs, reward, done, info = env.step(action)
env.render()
# Out:
# Final Cantilever rl_beam design:

# %%
np.mean(alg._evaluate(env)[0])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 1.741023840304485e-05
