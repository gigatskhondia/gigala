# %%
import time
import os
import random
import numpy as np                                                
import matplotlib.pyplot as plt                                   
import autograd, autograd.core, autograd.extend, autograd.tracer  
import autograd.numpy as anp      
import scipy, scipy.ndimage, scipy.sparse, scipy.sparse.linalg    
                                                     
import gym
from gymnasium import spaces

from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common import results_plotter

# %% [markdown]
# The below code is my RL extension to https://www.researchgate.net/publication/360698153_A_Tutorial_on_Structural_Optimization

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d
    
def get_args(normals, forces, density=1e-4):  # Manage the problem setup parameters
    width = normals.shape[0] - 1
    height = normals.shape[1] - 1
    fixdofs = np.flatnonzero(normals.ravel())
    alldofs = np.arange(2 * (width + 1) * (height + 1))
    freedofs = np.sort(list(set(alldofs) - set(fixdofs)))
    params = {
      # material properties
      'young': 1, 'young_min': 1e-9, 'poisson': 0.3, 'g': 0,
      # constraints
      'density': density, 'xmin': 0.001, 'xmax': 1.0,
      # input parameters
      'nelx': width, 'nely': height, 'mask': 1, 'penal': 3.0, 'filter_width': 1,
      'freedofs': freedofs, 'fixdofs': fixdofs, 'forces': forces.ravel(),
      # optimization parameters
      'opt_steps': 80, 'print_every': 10}
    return ObjectView(params)

def mbb_beam(width = 80, height = 25, density=1e-4, y=1, x=0, rd=-1):  # textbook beam example
    normals = np.zeros((width + 1, height + 1, 2))
    normals[0, 0, x] = 1
    normals[0, 0, y] = 1
    normals[0, -1, x] = 1
    normals[0, -1, y] = 1
    forces = np.zeros((width + 1, height + 1, 2))
    forces[-1, rd, y] = -1
    return normals, forces, density

# %%
def young_modulus(x, e_0, e_min, p=3):
    return e_min + x ** p * (e_0 - e_min)

def physical_density(x, args, volume_contraint=False, use_filter=True):
    x = args.mask * x.reshape(args.nely, args.nelx)  # reshape from 1D to 2D
    return gaussian_filter(x, args.filter_width) if use_filter else x  # maybe filter

def mean_density(x, args, volume_contraint=False, use_filter=True):
    return anp.mean(physical_density(x, args, volume_contraint, use_filter)) / anp.mean(args.mask)

# %%
def objective(x, args, volume_contraint=False, use_filter=True):
    kwargs = dict(penal=args.penal, e_min=args.young_min, e_0=args.young)
    x_phys = physical_density(x, args, volume_contraint=volume_contraint, use_filter=use_filter)
    ke     = get_stiffness_matrix(args.young, args.poisson)  # stiffness matrix
    u      = displace(x_phys, ke, args.forces, args.freedofs, args.fixdofs, **kwargs)
    c      = compliance(x_phys, u, ke, **kwargs)
    return c

# %%
@autograd.extend.primitive
def gaussian_filter(x, width): # 2D gaussian blur/filter
    return scipy.ndimage.gaussian_filter(x, width, mode='reflect')

def _gaussian_filter_vjp(ans, x, width): # gives the gradient of orig. function w.r.t. x
    del ans, x  # unused
    return lambda g: gaussian_filter(g, width)
autograd.extend.defvjp(gaussian_filter, _gaussian_filter_vjp)

# %%
def compliance(x_phys, u, ke, *, penal=3, e_min=1e-9, e_0=1):
    nely, nelx = x_phys.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords for the index map

    n1 = (nely+1)*(elx+0) + (ely+0)  # nodes
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    all_ixs = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    u_selected = u[all_ixs]  # select from u matrix

    ke_u = anp.einsum('ij,jkl->ikl', ke, u_selected)  # compute x^penal * U.T @ ke @ U
    ce = anp.einsum('ijk,ijk->jk', u_selected, ke_u)
    C = young_modulus(x_phys, e_0, e_min, p=penal) * ce.T
    return anp.sum(C)

def get_stiffness_matrix(e, nu):  # e=young's modulus, nu=poisson coefficient
    k = anp.array([1/2-nu/6, 1/8+nu/8, -1/4-nu/12, -1/8+3*nu/8,
                -1/4+nu/12, -1/8-nu/8, nu/6, 1/8-3*nu/8])
    return e/(1-nu**2)*anp.array([[k[0], k[1], k[2], k[3], k[4], k[5], k[6], k[7]],
                               [k[1], k[0], k[7], k[6], k[5], k[4], k[3], k[2]],
                               [k[2], k[7], k[0], k[5], k[6], k[3], k[4], k[1]],
                               [k[3], k[6], k[5], k[0], k[7], k[2], k[1], k[4]],
                               [k[4], k[5], k[6], k[7], k[0], k[1], k[2], k[3]],
                               [k[5], k[4], k[3], k[2], k[1], k[0], k[7], k[6]],
                               [k[6], k[3], k[4], k[1], k[2], k[7], k[0], k[5]],
                               [k[7], k[2], k[1], k[4], k[3], k[6], k[5], k[0]]])

# %%
def get_k(stiffness, ke):
    # Constructs sparse stiffness matrix k (used in the displace fn)
    # First, get position of the nodes of each element in the stiffness matrix
    nely, nelx = stiffness.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords
    ely, elx = ely.reshape(-1, 1), elx.reshape(-1, 1)

    n1 = (nely+1)*(elx+0) + (ely+0)
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    edof = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    edof = edof.T[0]
    x_list = anp.repeat(edof, 8)  # flat list pointer of each node in an element
    y_list = anp.tile(edof, 8).flatten()  # flat list pointer of each node in elem

    # make the global stiffness matrix K
    kd = stiffness.T.reshape(nelx*nely, 1, 1)
    value_list = (kd * anp.tile(ke, kd.shape)).flatten()
    return value_list, y_list, x_list

def displace(x_phys, ke, forces, freedofs, fixdofs, *, penal=3, e_min=1e-9, e_0=1):
    # Displaces the load x using finite element techniques (solve_coo=most of runtime)
    stiffness = young_modulus(x_phys, e_0, e_min, p=penal)
    k_entries, k_ylist, k_xlist = get_k(stiffness, ke)

    index_map, keep, indices = _get_dof_indices(freedofs, fixdofs, k_ylist, k_xlist)

    u_nonzero = solve_coo(k_entries[keep], indices, forces[freedofs], sym_pos=True)
    u_values = anp.concatenate([u_nonzero, anp.zeros(len(fixdofs))])
    return u_values[index_map]

# %%
def _get_dof_indices(freedofs, fixdofs, k_xlist, k_ylist):
    index_map = inverse_permutation(anp.concatenate([freedofs, fixdofs]))
    keep = anp.isin(k_xlist, freedofs) & anp.isin(k_ylist, freedofs)
    # Now we index an indexing array that is being indexed by the indices of k
    i = index_map[k_ylist][keep]
    j = index_map[k_xlist][keep]
    return index_map, keep, anp.stack([i, j])

def inverse_permutation(indices):  # reverses an index operation
    inverse_perm = np.zeros(len(indices), dtype=anp.int64)
    inverse_perm[indices] = np.arange(len(indices), dtype=anp.int64)
    return inverse_perm

# %%
def _get_solver(a_entries, a_indices, size, sym_pos):
    # a is (usu.) symmetric positive; could solve 2x faster w/sksparse.cholmod.cholesky(a).solve_A
    a = scipy.sparse.coo_matrix((a_entries, a_indices), shape=(size,)*2).tocsc()
    return scipy.sparse.linalg.splu(a).solve

@autograd.primitive
def solve_coo(a_entries, a_indices, b, sym_pos=False):
    solver = _get_solver(a_entries, a_indices, b.size, sym_pos)
    return solver(b)

def grad_solve_coo_entries(ans, a_entries, a_indices, b, sym_pos=False):
    def jvp(grad_ans):
        lambda_ = solve_coo(a_entries, a_indices if sym_pos else a_indices[::-1],
                            grad_ans, sym_pos)
        i, j = a_indices
        return -lambda_[i] * ans[j]
    return jvp

autograd.extend.defvjp(solve_coo, grad_solve_coo_entries,
                       lambda: print('err: gradient undefined'),
                       lambda: print('err: gradient not implemented'))

# %%
class Model:
    def __init__(self, x):
        self.flag_ = True
#         self.flag_ = False
        self.n, self.m = x.shape
        self.actions_dic={} 
    
        k=0
        for i in range(self.n):
            for j in range(self.m):
                self.actions_dic[k]=(i,j)
                k+=1
        
    def action_space_(self, action, X):
        x,y=self.actions_dic[action]
        X[x][y]=1
        
    def draw(self,X):  
        plt.figure(dpi=50) 
        print('\nFinal Cantilever beam design:')
        plt.imshow(X) 
        plt.show()

# %%
def fast_stopt(args, x):

    reshape = lambda x: x.reshape(args.nely, args.nelx)
    objective_fn = lambda x: objective(reshape(x), args)
#     constraint = lambda params: mean_density(reshape(params), args) - args.density
    constraint = lambda params: mean_density(reshape(params), args) 
    value = objective_fn(x)
    const = constraint(x)
    return value, const

# %%
class CantileverEnv(gym.Env):
    
    metadata = {"render.modes": ["human"]}

    def __init__(self):
        super().__init__()
        
        
        self.rd=0
        self.args = get_args(*mbb_beam(rd=self.rd))
        
        DIM=self.args.nelx*self.args.nely
        N_DISCRETE_ACTIONS=self.args.nelx*self.args.nely
        
        self.action_space = spaces.Discrete(N_DISCRETE_ACTIONS)
        self.observation_space = spaces.Box(low=np.array([-1e10 for x in range(DIM)]),
                                            high=np.array([1e10 for y in range(DIM)]),
                                            shape=(DIM,),
                                           dtype=np.float64)
        
 
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density 
    
        self.M=Model(self.x)
        
        self.reward=0
        self.step_=0
        self.needs_reset = True
        
    def step(self, action):
        
        self.args = get_args(*mbb_beam(rd=self.rd))
        
        self.M.action_space_(action, self.x)
        
        tmp, const = fast_stopt(self.args, self.x)
        
        self.step_+=1
        
        self.reward+=(1/tmp)**2
       
        done=False
                  
        if self.step_>self.M.n*self.M.m:
            done=True
            
        if const>0.7:
#             self.reward-=1
            done=True
            
        if self.needs_reset:
            raise RuntimeError("Tried to step environment that needs reset")
            
        if done:
            self.needs_reset = True
                         
      
        return self.x.reshape(self.x.shape[0]*self.x.shape[1]), self.reward, done, False, dict()

    def reset(self, seed=0):
        
        if not self.M.flag_:
            self.rd=random.choice([0,2,-2])
        else:
            self.rd=-1
           
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density 

        self.reward=0
        self.needs_reset = False
        self.step_=0

        return self.x.reshape(self.x.shape[0]*self.x.shape[1]), {}

    def render(self, mode="human"):
        self.M.draw(self.x)    

    def close(self):
        pass

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %%
# ts=5e6
ts=55e6

# %%
# Create log dir
log_dir = "/tmp/gym7/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = CantileverEnv()
# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)
check_env(env)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.render_mode to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.render_mode` for environment variables or `env.get_wrapper_attr('render_mode')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:77: UserWarning: The `render_mode` attribute is not defined in your environment. It will be set to None.
#   warnings.warn("The `render_mode` attribute is not defined in your environment. It will be set to None.")

# %%
# callback = SaveOnBestTrainingRewardCallback(check_freq=5000, log_dir=log_dir)
callback = SaveOnBestTrainingRewardCallback(check_freq = 100000, log_dir = log_dir)

# %%
start = time.time()
# model = PPO("MlpPolicy", env).learn(total_timesteps=ts, callback=callback)
model = PPO.load(log_dir + "best_model.zip", env=env).learn(total_timesteps=ts, callback=callback)
end = time.time()
# Out:
# Num timesteps: 100000
# Best mean reward: -inf - Last mean reward per episode: 0.01
# Saving new best model to /tmp/gym7/best_model.zip
# Num timesteps: 200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 1000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 1100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 1200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 1300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 1400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 1500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 1600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 1700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 1800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 1900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 2000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 2100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 2200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 2300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 2400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 2500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 2600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 2700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 2800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 2900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 3000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 3100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 3200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 3300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 3400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 3500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 3600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 3700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 3800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 3900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 4000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 4100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 4200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 4300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 4400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 4500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 4600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 4700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 4800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 4900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 5000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 5100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 5200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 5300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 5400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 5500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 5600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 5700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 5800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 5900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 6000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 6100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 6200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 6300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 6400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 6500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 6600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 6700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 6800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 6900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 7000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 7100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 7200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 7300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 7400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 7500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 7600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 7700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 7800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 7900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 8000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 8100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 8200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 8300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 8400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 8500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 8600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 8700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 8800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 8900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 9000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 9100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 9200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 9300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 9400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 9500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 9600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 9700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 9800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 9900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 10000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 10100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 10200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 10300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 10400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 10500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 10600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 10700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 10800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 10900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 11000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 11100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 11200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 11300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 11400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 11500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 11600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 11700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 11800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 11900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 12000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 12100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 12200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 12300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 12400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 12500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 12600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 12700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 12800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 12900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 13000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 13100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 13200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 13300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 13400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 13500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 13600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 13700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 13800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 13900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 14000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 14100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 14200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 14300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 14400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 14500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 14600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 14700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 14800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 14900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 15000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 15100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 15200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 15300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 15400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 15500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 15600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 15700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 15800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 15900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 16000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 16100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 16200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 16300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 16400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 16500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 16600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 16700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 16800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 16900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 17000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 17100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 17200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 17300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 17400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 17500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 17600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 17700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 17800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 17900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 18000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 18100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 18200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 18300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 18400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 18500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 18600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 18700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 18800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 18900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 19000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 19100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 19200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 19300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 19400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 19500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 19600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 19700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 19800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 19900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 20000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 20100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 20200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 20300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 20400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 20500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 20600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 20700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 20800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 20900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 21000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 21100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 21200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 21300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 21400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 21500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 21600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 21700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 21800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 21900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 22000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 22100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 22200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 22300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 22400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 22500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 22600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 22700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 22800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 22900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 23000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 23100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 23200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 23300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 23400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 23500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 23600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 23700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 23800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 23900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 24000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 24100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 24200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 24300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 24400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 24500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 24600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 24700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 24800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 24900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 25000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 25100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 25200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 25300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 25400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 25500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 25600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 25700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 25800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 25900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 26000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 26100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 26200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 26300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 26400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 26500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 26600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 26700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 26800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 26900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 27000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 27100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 27200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 27300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 27400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 27500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 27600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 27700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 27800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 27900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 28000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 28100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 28200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 28300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 28400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 28500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 28600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 28700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 28800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 28900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 29000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 29100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 29200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 29300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 29400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 29500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 29600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 29700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 29800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 29900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 30000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 30100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 30200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 30300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 30400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 30500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 30600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 30700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 30800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 30900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 31000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 31100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 31200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 31300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 31400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 31500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 31600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 31700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 31800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 31900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 32000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 32100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 32200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 32300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 32400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 32500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 32600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 32700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 32800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 32900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 33000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 33100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 33200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 33300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 33400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 33500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 33600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 33700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 33800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 33900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 34000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 34100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 34200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 34300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 34400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 34500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 34600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 34700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 34800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 34900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 35000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 35100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 35200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 35300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 35400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 35500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 35600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 35700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 35800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 35900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 36000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 36100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 36200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 36300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 36400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 36500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 36600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 36700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 36800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 36900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 37000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 37100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 37200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 37300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 37400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 37500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 37600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 37700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 37800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 37900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 38000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 38100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 38200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 38300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 38400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 38500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 38600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 38700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 38800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 38900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 39000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 39100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 39200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 39300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 39400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 39500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 39600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 39700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 39800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 39900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 40000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 40100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 40200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 40300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 40400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 40500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 40600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 40700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 40800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 40900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 41000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 41100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 41200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 41300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 41400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 41500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 41600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 41700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 41800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 41900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 42000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 42100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 42200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 42300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 42400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 42500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 42600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 42700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 42800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 42900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 43000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 43100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 43200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 43300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 43400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 43500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 43600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 43700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 43800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 43900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 44000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 44100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 44200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 44300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 44400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 44500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 44600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 44700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 44800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 44900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 45000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 45100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 45200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 45300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 45400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 45500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 45600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 45700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 45800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 45900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 46000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 46100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 46200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 46300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 46400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 46500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 46600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 46700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 46800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 46900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 47000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 47100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 47200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 47300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 47400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 47500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 47600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 47700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 47800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 47900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 48000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 48100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 48200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 48300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 48400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 48500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 48600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 48700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 48800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 48900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 49000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 49100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 49200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 49300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 49400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 49500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 49600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 49700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 49800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 49900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 50000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 50100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 50200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 50300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 50400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 50500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 50600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 50700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 50800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 50900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 51000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 51100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 51200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 51300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 51400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 51500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 51600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 51700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 51800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 51900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 52000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 52100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 52200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 52300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 52400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 52500000
# Best mean reward: 0.01 - Last mean reward per episode: nan
# Num timesteps: 52600000
# Best mean reward: 0.01 - Last mean reward per episode: nan
# Num timesteps: 52700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 52800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 52900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 53000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 53100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 53200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 53300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 53400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 53500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 53600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 53700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 53800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 53900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 54000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 54100000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 54200000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 54300000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 54400000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 54500000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 54600000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 54700000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 54800000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 54900000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00
# Num timesteps: 55000000
# Best mean reward: 0.01 - Last mean reward per episode: 0.00

# %%
print('Total time taken: {} min'.format((end - start)/60))
# Out:
# Total time taken: 24399.78358589808 min

# %% [markdown]
# ### Inference

# %%
# env.M.flag_=True
env.M.flag_=False
obs=env.reset()
obs=obs[0]

# %%
i=0
while i<2000:
    action, _states = model.predict(obs)
    obs, rewards, dones, _ , info = env.step(int(action))
    if dones: 
        break
    i+=1

# %%
print(i)
# Out:
# 2000

# %%
env.render()
# Out:
# Final Cantilever beam design:

# %%
results_plotter.plot_results([log_dir], ts, results_plotter.X_TIMESTEPS, "CantileverEnv")

# %%
obs=env.reset()
obs=obs[0]

# %%
# Load the agent
model_best = PPO.load(log_dir + "best_model", env=env)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/6q/zp3bjthx3zv4n0bl2l835qdw0000gn/T/ipykernel_23690/3864315308.py", line 2, in <module>
#     model_best = PPO.load(log_dir + "best_model", env=env)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/base_class.py", line 677, in load
#     data, params, pytorch_variables = load_from_zip_file(
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/save_util.py", line 402, in load_from_zip_file
#     file = open_path(load_path, "r", verbose=verbose, suffix="zip")
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/functools.py", line 877, in wrapper
#     return dispatch(args[0].__class__)(*args, **kw)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/save_util.py", line 239, in open_path_str
#     return open_path_pathlib(pathlib.Path(path), mode, verbose, suffix)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/save_util.py", line 290, in open_path_pathlib
#     return open_path_pathlib(path, mode, verbose, suffix)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/save_util.py", line 271, in open_path_pathlib
#     raise error
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/save_util.py", line 263, in open_path_pathlib
#     return open_path(path.open("rb"), mode, verbose, suffix)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/pathlib.py", line 1242, in open
#     return io.open(self, mode, buffering, encoding, errors, newline,
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/pathlib.py", line 1110, in _opener
#     return self._accessor.open(self, flags, mode)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/gym7/best_model.zip'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/IPython/core/ultratb.py", line 1428, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/IPython/core/ultratb.py", line 1319, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/IPython/core/ultratb.py", line 1172, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/IPython/core/ultratb.py", line 1087, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/IPython/core/ultratb.py", line 969, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/stack_data/core.py", line 677, in included_pieces
#     scope_pieces = self.scope_pieces
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/stack_data/core.py", line 614, in scope_pieces
#     scope_start, scope_end = self.source.line_range(self.scope)
#   File "/Users/giga/Library/Python/3.9/lib/python/site-packages/stack_data/core.py", line 178, in line_range
#     return line_range(self.asttext(), node)
# AttributeError: 'Source' object has no attribute 'asttext'

# %%
i=0
while i<2000:
    action, _states = model_best.predict(obs)
    
    obs, rewards, dones, _ , info = env.step(int(action))
    if dones:
        break
    i+=1

# %%
i

# %%
env.render()

# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/save_format.html
