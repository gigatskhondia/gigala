# %%
import time
import os
import random
import numpy as np                                                
import matplotlib.pyplot as plt                                   
import autograd, autograd.core, autograd.extend, autograd.tracer  
import autograd.numpy as anp      
import scipy, scipy.ndimage, scipy.sparse, scipy.sparse.linalg    
                                                     
import gym
# from gym import spaces
from gymnasium import spaces


from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common import results_plotter

# %% [markdown]
# The below code is my RL extension to and rework of https://www.researchgate.net/publication/360698153_A_Tutorial_on_Structural_Optimization

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d
    
def get_args(normals, forces, density=1e-4):  # Manage the problem setup parameters
    width = normals.shape[0] - 1
    height = normals.shape[1] - 1
    fixdofs = np.flatnonzero(normals.ravel())
    alldofs = np.arange(2 * (width + 1) * (height + 1))
    freedofs = np.sort(list(set(alldofs) - set(fixdofs)))
    params = {
      # material properties
      'young': 1, 'young_min': 1e-9, 'poisson': 0.3, 'g': 0,
      # constraints
      'density': density, 'xmin': 0.001, 'xmax': 1.0,
      # input parameters
      'nelx': width, 'nely': height, 'mask': 1, 'penal': 3.0, 'filter_width': 1,
      'freedofs': freedofs, 'fixdofs': fixdofs, 'forces': forces.ravel(),
      # optimization parameters
      'opt_steps': 80, 'print_every': 10}
    return ObjectView(params)

def mbb_beam(width=6, height=6, density=1e-4, y=1, x=0, rd=-1):  # textbook beam example
    normals = np.zeros((width + 1, height + 1, 2))
    normals[0, 0, x] = 1
    normals[0, 0, y] = 1
    normals[0, -1, x] = 1
    normals[0, -1, y] = 1
    forces = np.zeros((width + 1, height + 1, 2))
    forces[-1, rd, y] = -1
    return normals, forces, density

# %%
def young_modulus(x, e_0, e_min, p=3):
    return e_min + x ** p * (e_0 - e_min)

def physical_density(x, args, volume_contraint=False, use_filter=True):
    x = args.mask * x.reshape(args.nely, args.nelx)  # reshape from 1D to 2D
    return gaussian_filter(x, args.filter_width) if use_filter else x  # maybe filter

def mean_density(x, args, volume_contraint=False, use_filter=True):
    return anp.mean(physical_density(x, args, volume_contraint, use_filter)) / anp.mean(args.mask)

# %%
def objective(x, args, volume_contraint=False, use_filter=True):
    kwargs = dict(penal=args.penal, e_min=args.young_min, e_0=args.young)
    x_phys = physical_density(x, args, volume_contraint=volume_contraint, use_filter=use_filter)
    ke     = get_stiffness_matrix(args.young, args.poisson)  # stiffness matrix
    u      = displace(x_phys, ke, args.forces, args.freedofs, args.fixdofs, **kwargs)
    c      = compliance(x_phys, u, ke, **kwargs)
    return c

# %%
@autograd.extend.primitive
def gaussian_filter(x, width): # 2D gaussian blur/filter
    return scipy.ndimage.gaussian_filter(x, width, mode='reflect')

def _gaussian_filter_vjp(ans, x, width): # gives the gradient of orig. function w.r.t. x
    del ans, x  # unused
    return lambda g: gaussian_filter(g, width)
autograd.extend.defvjp(gaussian_filter, _gaussian_filter_vjp)

# %%
def compliance(x_phys, u, ke, *, penal=3, e_min=1e-9, e_0=1):
    nely, nelx = x_phys.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords for the index map

    n1 = (nely+1)*(elx+0) + (ely+0)  # nodes
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    all_ixs = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    u_selected = u[all_ixs]  # select from u matrix

    ke_u = anp.einsum('ij,jkl->ikl', ke, u_selected)  # compute x^penal * U.T @ ke @ U
    ce = anp.einsum('ijk,ijk->jk', u_selected, ke_u)
    C = young_modulus(x_phys, e_0, e_min, p=penal) * ce.T
    return anp.sum(C)

def get_stiffness_matrix(e, nu):  # e=young's modulus, nu=poisson coefficient
    k = anp.array([1/2-nu/6, 1/8+nu/8, -1/4-nu/12, -1/8+3*nu/8,
                -1/4+nu/12, -1/8-nu/8, nu/6, 1/8-3*nu/8])
    return e/(1-nu**2)*anp.array([[k[0], k[1], k[2], k[3], k[4], k[5], k[6], k[7]],
                               [k[1], k[0], k[7], k[6], k[5], k[4], k[3], k[2]],
                               [k[2], k[7], k[0], k[5], k[6], k[3], k[4], k[1]],
                               [k[3], k[6], k[5], k[0], k[7], k[2], k[1], k[4]],
                               [k[4], k[5], k[6], k[7], k[0], k[1], k[2], k[3]],
                               [k[5], k[4], k[3], k[2], k[1], k[0], k[7], k[6]],
                               [k[6], k[3], k[4], k[1], k[2], k[7], k[0], k[5]],
                               [k[7], k[2], k[1], k[4], k[3], k[6], k[5], k[0]]])

# %%
def get_k(stiffness, ke):
    # Constructs sparse stiffness matrix k (used in the displace fn)
    # First, get position of the nodes of each element in the stiffness matrix
    nely, nelx = stiffness.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords
    ely, elx = ely.reshape(-1, 1), elx.reshape(-1, 1)

    n1 = (nely+1)*(elx+0) + (ely+0)
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    edof = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    edof = edof.T[0]
    x_list = anp.repeat(edof, 8)  # flat list pointer of each node in an element
    y_list = anp.tile(edof, 8).flatten()  # flat list pointer of each node in elem

    # make the global stiffness matrix K
    kd = stiffness.T.reshape(nelx*nely, 1, 1)
    value_list = (kd * anp.tile(ke, kd.shape)).flatten()
    return value_list, y_list, x_list

def displace(x_phys, ke, forces, freedofs, fixdofs, *, penal=3, e_min=1e-9, e_0=1):
    # Displaces the load x using finite element techniques (solve_coo=most of runtime)
    stiffness = young_modulus(x_phys, e_0, e_min, p=penal)
    k_entries, k_ylist, k_xlist = get_k(stiffness, ke)

    index_map, keep, indices = _get_dof_indices(freedofs, fixdofs, k_ylist, k_xlist)

    u_nonzero = solve_coo(k_entries[keep], indices, forces[freedofs], sym_pos=True)
    u_values = anp.concatenate([u_nonzero, anp.zeros(len(fixdofs))])
    return u_values[index_map]

# %%
def _get_dof_indices(freedofs, fixdofs, k_xlist, k_ylist):
    index_map = inverse_permutation(anp.concatenate([freedofs, fixdofs]))
    keep = anp.isin(k_xlist, freedofs) & anp.isin(k_ylist, freedofs)
    # Now we index an indexing array that is being indexed by the indices of k
    i = index_map[k_ylist][keep]
    j = index_map[k_xlist][keep]
    return index_map, keep, anp.stack([i, j])

def inverse_permutation(indices):  # reverses an index operation
    inverse_perm = np.zeros(len(indices), dtype=anp.int64)
    inverse_perm[indices] = np.arange(len(indices), dtype=anp.int64)
    return inverse_perm

# %%
def _get_solver(a_entries, a_indices, size, sym_pos):
    # a is (usu.) symmetric positive; could solve 2x faster w/sksparse.cholmod.cholesky(a).solve_A
    a = scipy.sparse.coo_matrix((a_entries, a_indices), shape=(size,)*2).tocsc()
    return scipy.sparse.linalg.splu(a).solve

@autograd.primitive
def solve_coo(a_entries, a_indices, b, sym_pos=False):
    solver = _get_solver(a_entries, a_indices, b.size, sym_pos)
    return solver(b)

def grad_solve_coo_entries(ans, a_entries, a_indices, b, sym_pos=False):
    def jvp(grad_ans):
        lambda_ = solve_coo(a_entries, a_indices if sym_pos else a_indices[::-1],
                            grad_ans, sym_pos)
        i, j = a_indices
        return -lambda_[i] * ans[j]
    return jvp

autograd.extend.defvjp(solve_coo, grad_solve_coo_entries,
                       lambda: print('err: gradient undefined'),
                       lambda: print('err: gradient not implemented'))

# %%
class Model:
    def __init__(self, x):
        self.flag_ = True
#         self.flag_ = False
        self.n, self.m = x.shape
        self.actions_dic={} 
    
        k=0
        for i in range(self.n):
            for j in range(self.m):
                self.actions_dic[k]=(i,j)
                k+=1
        
    def action_space_(self, action, X):
        x,y=self.actions_dic[action]
        X[x][y]=1
        
    def draw(self,X):  
        plt.figure(dpi=50) 
        print('\nFinal Cantilever beam design:')
        plt.imshow(X) 
        plt.show()

# %%
def fast_stopt(args, x):

    reshape = lambda x: x.reshape(args.nely, args.nelx)
    objective_fn = lambda x: objective(reshape(x), args)
#     constraint = lambda params: mean_density(reshape(params), args) - args.density
    constraint = lambda params: mean_density(reshape(params), args) 
    value = objective_fn(x)
    const = constraint(x)
    return value, const

# %%
class CantileverEnv(gym.Env):
    
    metadata = {"render.modes": ["human"]}

    def __init__(self):
        super().__init__()
        
        
        self.rd=0
        self.args = get_args(*mbb_beam(rd=self.rd))
        
        DIM=self.args.nelx*self.args.nely
        N_DISCRETE_ACTIONS=self.args.nelx*self.args.nely
        
        self.action_space = spaces.Discrete(N_DISCRETE_ACTIONS)
        self.observation_space = spaces.Box(low=np.array([-1e10 for x in range(DIM)]),
                                            high=np.array([1e10 for y in range(DIM)]),
                                            shape=(DIM,),
                                           dtype=np.float64)
        
 
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density 
    
        self.M=Model(self.x)
        
        self.reward=0
        self.step_=0
        self.needs_reset = True
        
    def step(self, action):
        
        self.args = get_args(*mbb_beam(rd=self.rd))
        
        self.M.action_space_(action, self.x)
        
        tmp, const = fast_stopt(self.args, self.x)
        
        self.step_+=1
        
        self.reward = (1/tmp+1/const)**2
       
        done=False
                  
        if self.step_>self.M.n*self.M.m:
            done=True
            
        if const>0.7:
#             self.reward-=1
            done=True
            
        if self.needs_reset:
            raise RuntimeError("Tried to step environment that needs reset")
            
        if done:
            self.needs_reset = True
                         
      
        return self.x.reshape(self.x.shape[0]*self.x.shape[1]), self.reward, done,False, dict()

    def reset(self,seed=0):
        
        if not self.M.flag_:
            self.rd=random.choice([0,2,-2])
        else:
            self.rd=-1
           
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density 

        self.reward=0
        self.needs_reset = False
        self.step_=0

        return self.x.reshape(self.x.shape[0]*self.x.shape[1]),{}

    def render(self, mode="human"):
        self.M.draw(self.x)    

    def close(self):
        pass

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %%
# ts=5e6
ts=1e6

# %%
# Create log dir
log_dir = "/tmp/gym6_2bc/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = CantileverEnv()
# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)
check_env(env)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.render_mode to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.render_mode` for environment variables or `env.get_wrapper_attr('render_mode')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:77: UserWarning: The `render_mode` attribute is not defined in your environment. It will be set to None.
#   warnings.warn("The `render_mode` attribute is not defined in your environment. It will be set to None.")

# %%
# callback = SaveOnBestTrainingRewardCallback(check_freq=5000, log_dir=log_dir)
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)

# %%
start=time.time()
model = PPO("MlpPolicy", env).learn(total_timesteps=ts, callback=callback)
end=time.time()
# Out:
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: 2195.30
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 2000
# Best mean reward: 2195.30 - Last mean reward per episode: 2224.77
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 3000
# Best mean reward: 2224.77 - Last mean reward per episode: 2220.07
# Num timesteps: 4000
# Best mean reward: 2224.77 - Last mean reward per episode: 2216.98
# Num timesteps: 5000
# Best mean reward: 2224.77 - Last mean reward per episode: 2245.86
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 6000
# Best mean reward: 2245.86 - Last mean reward per episode: 2239.31
# Num timesteps: 7000
# Best mean reward: 2245.86 - Last mean reward per episode: 2249.02
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 8000
# Best mean reward: 2249.02 - Last mean reward per episode: 2232.88
# Num timesteps: 9000
# Best mean reward: 2249.02 - Last mean reward per episode: 2210.63
# Num timesteps: 10000
# Best mean reward: 2249.02 - Last mean reward per episode: 2211.97
# Num timesteps: 11000
# Best mean reward: 2249.02 - Last mean reward per episode: 2231.68
# Num timesteps: 12000
# Best mean reward: 2249.02 - Last mean reward per episode: 2246.39
# Num timesteps: 13000
# Best mean reward: 2249.02 - Last mean reward per episode: 2276.25
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 14000
# Best mean reward: 2276.25 - Last mean reward per episode: 2261.54
# Num timesteps: 15000
# Best mean reward: 2276.25 - Last mean reward per episode: 2242.67
# Num timesteps: 16000
# Best mean reward: 2276.25 - Last mean reward per episode: 2235.69
# Num timesteps: 17000
# Best mean reward: 2276.25 - Last mean reward per episode: 2247.83
# Num timesteps: 18000
# Best mean reward: 2276.25 - Last mean reward per episode: 2244.71
# Num timesteps: 19000
# Best mean reward: 2276.25 - Last mean reward per episode: 2255.67
# Num timesteps: 20000
# Best mean reward: 2276.25 - Last mean reward per episode: 2239.38
# Num timesteps: 21000
# Best mean reward: 2276.25 - Last mean reward per episode: 2229.82
# Num timesteps: 22000
# Best mean reward: 2276.25 - Last mean reward per episode: 2247.67
# Num timesteps: 23000
# Best mean reward: 2276.25 - Last mean reward per episode: 2267.61
# Num timesteps: 24000
# Best mean reward: 2276.25 - Last mean reward per episode: 2292.26
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 25000
# Best mean reward: 2292.26 - Last mean reward per episode: 2293.91
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 26000
# Best mean reward: 2293.91 - Last mean reward per episode: 2289.94
# Num timesteps: 27000
# Best mean reward: 2293.91 - Last mean reward per episode: 2234.65
# Num timesteps: 28000
# Best mean reward: 2293.91 - Last mean reward per episode: 2239.04
# Num timesteps: 29000
# Best mean reward: 2293.91 - Last mean reward per episode: 2254.93
# Num timesteps: 30000
# Best mean reward: 2293.91 - Last mean reward per episode: 2256.29
# Num timesteps: 31000
# Best mean reward: 2293.91 - Last mean reward per episode: 2256.58
# Num timesteps: 32000
# Best mean reward: 2293.91 - Last mean reward per episode: 2255.90
# Num timesteps: 33000
# Best mean reward: 2293.91 - Last mean reward per episode: 2238.32
# Num timesteps: 34000
# Best mean reward: 2293.91 - Last mean reward per episode: 2231.58
# Num timesteps: 35000
# Best mean reward: 2293.91 - Last mean reward per episode: 2244.97
# Num timesteps: 36000
# Best mean reward: 2293.91 - Last mean reward per episode: 2277.55
# Num timesteps: 37000
# Best mean reward: 2293.91 - Last mean reward per episode: 2256.52
# Num timesteps: 38000
# Best mean reward: 2293.91 - Last mean reward per episode: 2276.26
# Num timesteps: 39000
# Best mean reward: 2293.91 - Last mean reward per episode: 2262.38
# Num timesteps: 40000
# Best mean reward: 2293.91 - Last mean reward per episode: 2240.08
# Num timesteps: 41000
# Best mean reward: 2293.91 - Last mean reward per episode: 2227.40
# Num timesteps: 42000
# Best mean reward: 2293.91 - Last mean reward per episode: 2277.01
# Num timesteps: 43000
# Best mean reward: 2293.91 - Last mean reward per episode: 2303.98
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 44000
# Best mean reward: 2303.98 - Last mean reward per episode: 2313.38
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 45000
# Best mean reward: 2313.38 - Last mean reward per episode: 2315.07
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 46000
# Best mean reward: 2315.07 - Last mean reward per episode: 2263.83
# Num timesteps: 47000
# Best mean reward: 2315.07 - Last mean reward per episode: 2232.71
# Num timesteps: 48000
# Best mean reward: 2315.07 - Last mean reward per episode: 2218.94
# Num timesteps: 49000
# Best mean reward: 2315.07 - Last mean reward per episode: 2208.06
# Num timesteps: 50000
# Best mean reward: 2315.07 - Last mean reward per episode: 2211.95
# Num timesteps: 51000
# Best mean reward: 2315.07 - Last mean reward per episode: 2230.91
# Num timesteps: 52000
# Best mean reward: 2315.07 - Last mean reward per episode: 2246.54
# Num timesteps: 53000
# Best mean reward: 2315.07 - Last mean reward per episode: 2257.72
# Num timesteps: 54000
# Best mean reward: 2315.07 - Last mean reward per episode: 2268.22
# Num timesteps: 55000
# Best mean reward: 2315.07 - Last mean reward per episode: 2246.73
# Num timesteps: 56000
# Best mean reward: 2315.07 - Last mean reward per episode: 2268.03
# Num timesteps: 57000
# Best mean reward: 2315.07 - Last mean reward per episode: 2261.77
# Num timesteps: 58000
# Best mean reward: 2315.07 - Last mean reward per episode: 2283.88
# Num timesteps: 59000
# Best mean reward: 2315.07 - Last mean reward per episode: 2279.98
# Num timesteps: 60000
# Best mean reward: 2315.07 - Last mean reward per episode: 2255.18
# Num timesteps: 61000
# Best mean reward: 2315.07 - Last mean reward per episode: 2317.55
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 62000
# Best mean reward: 2317.55 - Last mean reward per episode: 2285.61
# Num timesteps: 63000
# Best mean reward: 2317.55 - Last mean reward per episode: 2294.30
# Num timesteps: 64000
# Best mean reward: 2317.55 - Last mean reward per episode: 2291.58
# Num timesteps: 65000
# Best mean reward: 2317.55 - Last mean reward per episode: 2246.43
# Num timesteps: 66000
# Best mean reward: 2317.55 - Last mean reward per episode: 2267.25
# Num timesteps: 67000
# Best mean reward: 2317.55 - Last mean reward per episode: 2293.83
# Num timesteps: 68000
# Best mean reward: 2317.55 - Last mean reward per episode: 2278.32
# Num timesteps: 69000
# Best mean reward: 2317.55 - Last mean reward per episode: 2292.63
# Num timesteps: 70000
# Best mean reward: 2317.55 - Last mean reward per episode: 2317.21
# Num timesteps: 71000
# Best mean reward: 2317.55 - Last mean reward per episode: 2288.13
# Num timesteps: 72000
# Best mean reward: 2317.55 - Last mean reward per episode: 2278.13
# Num timesteps: 73000
# Best mean reward: 2317.55 - Last mean reward per episode: 2222.99
# Num timesteps: 74000
# Best mean reward: 2317.55 - Last mean reward per episode: 2232.54
# Num timesteps: 75000
# Best mean reward: 2317.55 - Last mean reward per episode: 2248.38
# Num timesteps: 76000
# Best mean reward: 2317.55 - Last mean reward per episode: 2254.11
# Num timesteps: 77000
# Best mean reward: 2317.55 - Last mean reward per episode: 2256.45
# Num timesteps: 78000
# Best mean reward: 2317.55 - Last mean reward per episode: 2242.63
# Num timesteps: 79000
# Best mean reward: 2317.55 - Last mean reward per episode: 2213.94
# Num timesteps: 80000
# Best mean reward: 2317.55 - Last mean reward per episode: 2215.87
# Num timesteps: 81000
# Best mean reward: 2317.55 - Last mean reward per episode: 2236.16
# Num timesteps: 82000
# Best mean reward: 2317.55 - Last mean reward per episode: 2253.34
# Num timesteps: 83000
# Best mean reward: 2317.55 - Last mean reward per episode: 2281.38
# Num timesteps: 84000
# Best mean reward: 2317.55 - Last mean reward per episode: 2291.70
# Num timesteps: 85000
# Best mean reward: 2317.55 - Last mean reward per episode: 2319.90
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 86000
# Best mean reward: 2319.90 - Last mean reward per episode: 2326.54
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 87000
# Best mean reward: 2326.54 - Last mean reward per episode: 2326.90
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 88000
# Best mean reward: 2326.90 - Last mean reward per episode: 2301.71
# Num timesteps: 89000
# Best mean reward: 2326.90 - Last mean reward per episode: 2294.29
# Num timesteps: 90000
# Best mean reward: 2326.90 - Last mean reward per episode: 2270.92
# Num timesteps: 91000
# Best mean reward: 2326.90 - Last mean reward per episode: 2261.79
# Num timesteps: 92000
# Best mean reward: 2326.90 - Last mean reward per episode: 2241.88
# Num timesteps: 93000
# Best mean reward: 2326.90 - Last mean reward per episode: 2234.46
# Num timesteps: 94000
# Best mean reward: 2326.90 - Last mean reward per episode: 2256.82
# Num timesteps: 95000
# Best mean reward: 2326.90 - Last mean reward per episode: 2284.74
# Num timesteps: 96000
# Best mean reward: 2326.90 - Last mean reward per episode: 2275.05
# Num timesteps: 97000
# Best mean reward: 2326.90 - Last mean reward per episode: 2297.43
# Num timesteps: 98000
# Best mean reward: 2326.90 - Last mean reward per episode: 2293.72
# Num timesteps: 99000
# Best mean reward: 2326.90 - Last mean reward per episode: 2283.36
# Num timesteps: 100000
# Best mean reward: 2326.90 - Last mean reward per episode: 2283.94
# Num timesteps: 101000
# Best mean reward: 2326.90 - Last mean reward per episode: 2261.95
# Num timesteps: 102000
# Best mean reward: 2326.90 - Last mean reward per episode: 2284.22
# Num timesteps: 103000
# Best mean reward: 2326.90 - Last mean reward per episode: 2302.77
# Num timesteps: 104000
# Best mean reward: 2326.90 - Last mean reward per episode: 2325.08
# Num timesteps: 105000
# Best mean reward: 2326.90 - Last mean reward per episode: 2313.82
# Num timesteps: 106000
# Best mean reward: 2326.90 - Last mean reward per episode: 2302.29
# Num timesteps: 107000
# Best mean reward: 2326.90 - Last mean reward per episode: 2340.63
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 108000
# Best mean reward: 2340.63 - Last mean reward per episode: 2372.95
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 109000
# Best mean reward: 2372.95 - Last mean reward per episode: 2378.07
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 110000
# Best mean reward: 2378.07 - Last mean reward per episode: 2392.15
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 111000
# Best mean reward: 2392.15 - Last mean reward per episode: 2353.46
# Num timesteps: 112000
# Best mean reward: 2392.15 - Last mean reward per episode: 2376.13
# Num timesteps: 113000
# Best mean reward: 2392.15 - Last mean reward per episode: 2416.74
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 114000
# Best mean reward: 2416.74 - Last mean reward per episode: 2433.42
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 115000
# Best mean reward: 2433.42 - Last mean reward per episode: 2423.66
# Num timesteps: 116000
# Best mean reward: 2433.42 - Last mean reward per episode: 2383.08
# Num timesteps: 117000
# Best mean reward: 2433.42 - Last mean reward per episode: 2353.44
# Num timesteps: 118000
# Best mean reward: 2433.42 - Last mean reward per episode: 2340.38
# Num timesteps: 119000
# Best mean reward: 2433.42 - Last mean reward per episode: 2350.10
# Num timesteps: 120000
# Best mean reward: 2433.42 - Last mean reward per episode: 2379.73
# Num timesteps: 121000
# Best mean reward: 2433.42 - Last mean reward per episode: 2373.92
# Num timesteps: 122000
# Best mean reward: 2433.42 - Last mean reward per episode: 2372.18
# Num timesteps: 123000
# Best mean reward: 2433.42 - Last mean reward per episode: 2403.79
# Num timesteps: 124000
# Best mean reward: 2433.42 - Last mean reward per episode: 2402.11
# Num timesteps: 125000
# Best mean reward: 2433.42 - Last mean reward per episode: 2437.66
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 126000
# Best mean reward: 2437.66 - Last mean reward per episode: 2460.89
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 127000
# Best mean reward: 2460.89 - Last mean reward per episode: 2448.40
# Num timesteps: 128000
# Best mean reward: 2460.89 - Last mean reward per episode: 2473.34
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 129000
# Best mean reward: 2473.34 - Last mean reward per episode: 2464.44
# Num timesteps: 130000
# Best mean reward: 2473.34 - Last mean reward per episode: 2441.18
# Num timesteps: 131000
# Best mean reward: 2473.34 - Last mean reward per episode: 2426.80
# Num timesteps: 132000
# Best mean reward: 2473.34 - Last mean reward per episode: 2461.41
# Num timesteps: 133000
# Best mean reward: 2473.34 - Last mean reward per episode: 2469.05
# Num timesteps: 134000
# Best mean reward: 2473.34 - Last mean reward per episode: 2501.00
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 135000
# Best mean reward: 2501.00 - Last mean reward per episode: 2538.70
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 136000
# Best mean reward: 2538.70 - Last mean reward per episode: 2550.03
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 137000
# Best mean reward: 2550.03 - Last mean reward per episode: 2558.21
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 138000
# Best mean reward: 2558.21 - Last mean reward per episode: 2648.48
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 139000
# Best mean reward: 2648.48 - Last mean reward per episode: 2674.57
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 140000
# Best mean reward: 2674.57 - Last mean reward per episode: 2715.77
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 141000
# Best mean reward: 2715.77 - Last mean reward per episode: 2719.52
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 142000
# Best mean reward: 2719.52 - Last mean reward per episode: 2689.36
# Num timesteps: 143000
# Best mean reward: 2719.52 - Last mean reward per episode: 2726.98
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 144000
# Best mean reward: 2726.98 - Last mean reward per episode: 2776.48
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 145000
# Best mean reward: 2776.48 - Last mean reward per episode: 2841.99
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 146000
# Best mean reward: 2841.99 - Last mean reward per episode: 2916.40
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 147000
# Best mean reward: 2916.40 - Last mean reward per episode: 3010.62
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 148000
# Best mean reward: 3010.62 - Last mean reward per episode: 3126.97
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 149000
# Best mean reward: 3126.97 - Last mean reward per episode: 3086.04
# Num timesteps: 150000
# Best mean reward: 3126.97 - Last mean reward per episode: 3052.41
# Num timesteps: 151000
# Best mean reward: 3126.97 - Last mean reward per episode: 2851.24
# Num timesteps: 152000
# Best mean reward: 3126.97 - Last mean reward per episode: 2787.38
# Num timesteps: 153000
# Best mean reward: 3126.97 - Last mean reward per episode: 2875.70
# Num timesteps: 154000
# Best mean reward: 3126.97 - Last mean reward per episode: 2939.66
# Num timesteps: 155000
# Best mean reward: 3126.97 - Last mean reward per episode: 2968.94
# Num timesteps: 156000
# Best mean reward: 3126.97 - Last mean reward per episode: 3014.35
# Num timesteps: 157000
# Best mean reward: 3126.97 - Last mean reward per episode: 3004.99
# Num timesteps: 158000
# Best mean reward: 3126.97 - Last mean reward per episode: 3001.28
# Num timesteps: 159000
# Best mean reward: 3126.97 - Last mean reward per episode: 3065.43
# Num timesteps: 160000
# Best mean reward: 3126.97 - Last mean reward per episode: 3063.22
# Num timesteps: 161000
# Best mean reward: 3126.97 - Last mean reward per episode: 3167.24
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 162000
# Best mean reward: 3167.24 - Last mean reward per episode: 3110.36
# Num timesteps: 163000
# Best mean reward: 3167.24 - Last mean reward per episode: 3348.74
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 164000
# Best mean reward: 3348.74 - Last mean reward per episode: 3339.34
# Num timesteps: 165000
# Best mean reward: 3348.74 - Last mean reward per episode: 3484.83
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 166000
# Best mean reward: 3484.83 - Last mean reward per episode: 3543.38
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 167000
# Best mean reward: 3543.38 - Last mean reward per episode: 3663.69
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 168000
# Best mean reward: 3663.69 - Last mean reward per episode: 3719.83
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 169000
# Best mean reward: 3719.83 - Last mean reward per episode: 3696.85
# Num timesteps: 170000
# Best mean reward: 3719.83 - Last mean reward per episode: 3577.05
# Num timesteps: 171000
# Best mean reward: 3719.83 - Last mean reward per episode: 3576.14
# Num timesteps: 172000
# Best mean reward: 3719.83 - Last mean reward per episode: 3657.85
# Num timesteps: 173000
# Best mean reward: 3719.83 - Last mean reward per episode: 3718.79
# Num timesteps: 174000
# Best mean reward: 3719.83 - Last mean reward per episode: 3744.35
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 175000
# Best mean reward: 3744.35 - Last mean reward per episode: 3866.61
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 176000
# Best mean reward: 3866.61 - Last mean reward per episode: 3891.85
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 177000
# Best mean reward: 3891.85 - Last mean reward per episode: 3894.28
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 178000
# Best mean reward: 3894.28 - Last mean reward per episode: 3942.14
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 179000
# Best mean reward: 3942.14 - Last mean reward per episode: 4096.54
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 180000
# Best mean reward: 4096.54 - Last mean reward per episode: 4405.77
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 181000
# Best mean reward: 4405.77 - Last mean reward per episode: 4385.39
# Num timesteps: 182000
# Best mean reward: 4405.77 - Last mean reward per episode: 4688.36
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 183000
# Best mean reward: 4688.36 - Last mean reward per episode: 4832.89
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 184000
# Best mean reward: 4832.89 - Last mean reward per episode: 4930.96
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 185000
# Best mean reward: 4930.96 - Last mean reward per episode: 5072.37
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 186000
# Best mean reward: 5072.37 - Last mean reward per episode: 5198.05
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 187000
# Best mean reward: 5198.05 - Last mean reward per episode: 5349.25
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 188000
# Best mean reward: 5349.25 - Last mean reward per episode: 5745.86
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 189000
# Best mean reward: 5745.86 - Last mean reward per episode: 6133.78
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 190000
# Best mean reward: 6133.78 - Last mean reward per episode: 6494.56
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 191000
# Best mean reward: 6494.56 - Last mean reward per episode: 7048.37
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 192000
# Best mean reward: 7048.37 - Last mean reward per episode: 7373.52
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 193000
# Best mean reward: 7373.52 - Last mean reward per episode: 8137.78
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 194000
# Best mean reward: 8137.78 - Last mean reward per episode: 8423.79
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 195000
# Best mean reward: 8423.79 - Last mean reward per episode: 8933.33
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 196000
# Best mean reward: 8933.33 - Last mean reward per episode: 9419.29
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 197000
# Best mean reward: 9419.29 - Last mean reward per episode: 8988.59
# Num timesteps: 198000
# Best mean reward: 9419.29 - Last mean reward per episode: 9885.70
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 199000
# Best mean reward: 9885.70 - Last mean reward per episode: 10305.84
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 200000
# Best mean reward: 10305.84 - Last mean reward per episode: 11191.22
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 201000
# Best mean reward: 11191.22 - Last mean reward per episode: 12622.02
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 202000
# Best mean reward: 12622.02 - Last mean reward per episode: 13553.93
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 203000
# Best mean reward: 13553.93 - Last mean reward per episode: 15113.31
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 204000
# Best mean reward: 15113.31 - Last mean reward per episode: 14679.09
# Num timesteps: 205000
# Best mean reward: 15113.31 - Last mean reward per episode: 14692.45
# Num timesteps: 206000
# Best mean reward: 15113.31 - Last mean reward per episode: 15287.83
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 207000
# Best mean reward: 15287.83 - Last mean reward per episode: 15593.53
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 208000
# Best mean reward: 15593.53 - Last mean reward per episode: 16974.73
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 209000
# Best mean reward: 16974.73 - Last mean reward per episode: 16643.56
# Num timesteps: 210000
# Best mean reward: 16974.73 - Last mean reward per episode: 18739.17
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 211000
# Best mean reward: 18739.17 - Last mean reward per episode: 18216.39
# Num timesteps: 212000
# Best mean reward: 18739.17 - Last mean reward per episode: 18471.04
# Num timesteps: 213000
# Best mean reward: 18739.17 - Last mean reward per episode: 20335.52
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 214000
# Best mean reward: 20335.52 - Last mean reward per episode: 20013.21
# Num timesteps: 215000
# Best mean reward: 20335.52 - Last mean reward per episode: 21128.25
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 216000
# Best mean reward: 21128.25 - Last mean reward per episode: 21637.97
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 217000
# Best mean reward: 21637.97 - Last mean reward per episode: 22884.26
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 218000
# Best mean reward: 22884.26 - Last mean reward per episode: 21922.27
# Num timesteps: 219000
# Best mean reward: 22884.26 - Last mean reward per episode: 21658.18
# Num timesteps: 220000
# Best mean reward: 22884.26 - Last mean reward per episode: 21895.44
# Num timesteps: 221000
# Best mean reward: 22884.26 - Last mean reward per episode: 22505.48
# Num timesteps: 222000
# Best mean reward: 22884.26 - Last mean reward per episode: 25261.18
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 223000
# Best mean reward: 25261.18 - Last mean reward per episode: 24727.14
# Num timesteps: 224000
# Best mean reward: 25261.18 - Last mean reward per episode: 23948.59
# Num timesteps: 225000
# Best mean reward: 25261.18 - Last mean reward per episode: 22650.98
# Num timesteps: 226000
# Best mean reward: 25261.18 - Last mean reward per episode: 22516.74
# Num timesteps: 227000
# Best mean reward: 25261.18 - Last mean reward per episode: 24829.01
# Num timesteps: 228000
# Best mean reward: 25261.18 - Last mean reward per episode: 25765.46
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 229000
# Best mean reward: 25765.46 - Last mean reward per episode: 27780.00
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 230000
# Best mean reward: 27780.00 - Last mean reward per episode: 27089.84
# Num timesteps: 231000
# Best mean reward: 27780.00 - Last mean reward per episode: 26936.23
# Num timesteps: 232000
# Best mean reward: 27780.00 - Last mean reward per episode: 26688.23
# Num timesteps: 233000
# Best mean reward: 27780.00 - Last mean reward per episode: 28497.50
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 234000
# Best mean reward: 28497.50 - Last mean reward per episode: 29806.30
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 235000
# Best mean reward: 29806.30 - Last mean reward per episode: 29261.45
# Num timesteps: 236000
# Best mean reward: 29806.30 - Last mean reward per episode: 30725.73
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 237000
# Best mean reward: 30725.73 - Last mean reward per episode: 28017.60
# Num timesteps: 238000
# Best mean reward: 30725.73 - Last mean reward per episode: 26723.45
# Num timesteps: 239000
# Best mean reward: 30725.73 - Last mean reward per episode: 26603.36
# Num timesteps: 240000
# Best mean reward: 30725.73 - Last mean reward per episode: 28169.20
# Num timesteps: 241000
# Best mean reward: 30725.73 - Last mean reward per episode: 27122.16
# Num timesteps: 242000
# Best mean reward: 30725.73 - Last mean reward per episode: 27823.34
# Num timesteps: 243000
# Best mean reward: 30725.73 - Last mean reward per episode: 28685.96
# Num timesteps: 244000
# Best mean reward: 30725.73 - Last mean reward per episode: 28939.03
# Num timesteps: 245000
# Best mean reward: 30725.73 - Last mean reward per episode: 31279.01
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 246000
# Best mean reward: 31279.01 - Last mean reward per episode: 32688.23
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 247000
# Best mean reward: 32688.23 - Last mean reward per episode: 32849.65
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 248000
# Best mean reward: 32849.65 - Last mean reward per episode: 34056.97
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 249000
# Best mean reward: 34056.97 - Last mean reward per episode: 33816.69
# Num timesteps: 250000
# Best mean reward: 34056.97 - Last mean reward per episode: 34057.22
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 251000
# Best mean reward: 34057.22 - Last mean reward per episode: 33572.15
# Num timesteps: 252000
# Best mean reward: 34057.22 - Last mean reward per episode: 33355.54
# Num timesteps: 253000
# Best mean reward: 34057.22 - Last mean reward per episode: 33187.32
# Num timesteps: 254000
# Best mean reward: 34057.22 - Last mean reward per episode: 34363.68
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 255000
# Best mean reward: 34363.68 - Last mean reward per episode: 33047.53
# Num timesteps: 256000
# Best mean reward: 34363.68 - Last mean reward per episode: 32178.14
# Num timesteps: 257000
# Best mean reward: 34363.68 - Last mean reward per episode: 32683.10
# Num timesteps: 258000
# Best mean reward: 34363.68 - Last mean reward per episode: 30837.02
# Num timesteps: 259000
# Best mean reward: 34363.68 - Last mean reward per episode: 35665.80
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 260000
# Best mean reward: 35665.80 - Last mean reward per episode: 36562.33
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 261000
# Best mean reward: 36562.33 - Last mean reward per episode: 36771.21
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 262000
# Best mean reward: 36771.21 - Last mean reward per episode: 35783.40
# Num timesteps: 263000
# Best mean reward: 36771.21 - Last mean reward per episode: 34833.24
# Num timesteps: 264000
# Best mean reward: 36771.21 - Last mean reward per episode: 35942.41
# Num timesteps: 265000
# Best mean reward: 36771.21 - Last mean reward per episode: 38544.55
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 266000
# Best mean reward: 38544.55 - Last mean reward per episode: 38367.31
# Num timesteps: 267000
# Best mean reward: 38544.55 - Last mean reward per episode: 36678.38
# Num timesteps: 268000
# Best mean reward: 38544.55 - Last mean reward per episode: 35847.86
# Num timesteps: 269000
# Best mean reward: 38544.55 - Last mean reward per episode: 33073.67
# Num timesteps: 270000
# Best mean reward: 38544.55 - Last mean reward per episode: 33167.30
# Num timesteps: 271000
# Best mean reward: 38544.55 - Last mean reward per episode: 34768.59
# Num timesteps: 272000
# Best mean reward: 38544.55 - Last mean reward per episode: 34614.84
# Num timesteps: 273000
# Best mean reward: 38544.55 - Last mean reward per episode: 35813.31
# Num timesteps: 274000
# Best mean reward: 38544.55 - Last mean reward per episode: 37405.52
# Num timesteps: 275000
# Best mean reward: 38544.55 - Last mean reward per episode: 37420.78
# Num timesteps: 276000
# Best mean reward: 38544.55 - Last mean reward per episode: 37645.67
# Num timesteps: 277000
# Best mean reward: 38544.55 - Last mean reward per episode: 37660.19
# Num timesteps: 278000
# Best mean reward: 38544.55 - Last mean reward per episode: 37540.49
# Num timesteps: 279000
# Best mean reward: 38544.55 - Last mean reward per episode: 38426.26
# Num timesteps: 280000
# Best mean reward: 38544.55 - Last mean reward per episode: 39289.05
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 281000
# Best mean reward: 39289.05 - Last mean reward per episode: 40111.29
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 282000
# Best mean reward: 40111.29 - Last mean reward per episode: 39439.04
# Num timesteps: 283000
# Best mean reward: 40111.29 - Last mean reward per episode: 38674.76
# Num timesteps: 284000
# Best mean reward: 40111.29 - Last mean reward per episode: 38445.98
# Num timesteps: 285000
# Best mean reward: 40111.29 - Last mean reward per episode: 35907.74
# Num timesteps: 286000
# Best mean reward: 40111.29 - Last mean reward per episode: 34774.27
# Num timesteps: 287000
# Best mean reward: 40111.29 - Last mean reward per episode: 36326.62
# Num timesteps: 288000
# Best mean reward: 40111.29 - Last mean reward per episode: 37755.68
# Num timesteps: 289000
# Best mean reward: 40111.29 - Last mean reward per episode: 38864.36
# Num timesteps: 290000
# Best mean reward: 40111.29 - Last mean reward per episode: 39623.69
# Num timesteps: 291000
# Best mean reward: 40111.29 - Last mean reward per episode: 39986.95
# Num timesteps: 292000
# Best mean reward: 40111.29 - Last mean reward per episode: 38955.39
# Num timesteps: 293000
# Best mean reward: 40111.29 - Last mean reward per episode: 38521.99
# Num timesteps: 294000
# Best mean reward: 40111.29 - Last mean reward per episode: 39183.12
# Num timesteps: 295000
# Best mean reward: 40111.29 - Last mean reward per episode: 38107.62
# Num timesteps: 296000
# Best mean reward: 40111.29 - Last mean reward per episode: 38783.15
# Num timesteps: 297000
# Best mean reward: 40111.29 - Last mean reward per episode: 38060.35
# Num timesteps: 298000
# Best mean reward: 40111.29 - Last mean reward per episode: 38030.74
# Num timesteps: 299000
# Best mean reward: 40111.29 - Last mean reward per episode: 39356.90
# Num timesteps: 300000
# Best mean reward: 40111.29 - Last mean reward per episode: 38796.87
# Num timesteps: 301000
# Best mean reward: 40111.29 - Last mean reward per episode: 39953.52
# Num timesteps: 302000
# Best mean reward: 40111.29 - Last mean reward per episode: 38647.13
# Num timesteps: 303000
# Best mean reward: 40111.29 - Last mean reward per episode: 38912.62
# Num timesteps: 304000
# Best mean reward: 40111.29 - Last mean reward per episode: 39500.90
# Num timesteps: 305000
# Best mean reward: 40111.29 - Last mean reward per episode: 39013.05
# Num timesteps: 306000
# Best mean reward: 40111.29 - Last mean reward per episode: 37947.38
# Num timesteps: 307000
# Best mean reward: 40111.29 - Last mean reward per episode: 38005.22
# Num timesteps: 308000
# Best mean reward: 40111.29 - Last mean reward per episode: 38258.41
# Num timesteps: 309000
# Best mean reward: 40111.29 - Last mean reward per episode: 40645.49
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 310000
# Best mean reward: 40645.49 - Last mean reward per episode: 41799.29
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 311000
# Best mean reward: 41799.29 - Last mean reward per episode: 40788.12
# Num timesteps: 312000
# Best mean reward: 41799.29 - Last mean reward per episode: 38946.40
# Num timesteps: 313000
# Best mean reward: 41799.29 - Last mean reward per episode: 38605.46
# Num timesteps: 314000
# Best mean reward: 41799.29 - Last mean reward per episode: 38828.49
# Num timesteps: 315000
# Best mean reward: 41799.29 - Last mean reward per episode: 38654.96
# Num timesteps: 316000
# Best mean reward: 41799.29 - Last mean reward per episode: 40372.58
# Num timesteps: 317000
# Best mean reward: 41799.29 - Last mean reward per episode: 41875.36
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 318000
# Best mean reward: 41875.36 - Last mean reward per episode: 41441.53
# Num timesteps: 319000
# Best mean reward: 41875.36 - Last mean reward per episode: 41480.09
# Num timesteps: 320000
# Best mean reward: 41875.36 - Last mean reward per episode: 40782.80
# Num timesteps: 321000
# Best mean reward: 41875.36 - Last mean reward per episode: 40202.57
# Num timesteps: 322000
# Best mean reward: 41875.36 - Last mean reward per episode: 39305.98
# Num timesteps: 323000
# Best mean reward: 41875.36 - Last mean reward per episode: 41822.21
# Num timesteps: 324000
# Best mean reward: 41875.36 - Last mean reward per episode: 42503.62
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 325000
# Best mean reward: 42503.62 - Last mean reward per episode: 42513.26
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 326000
# Best mean reward: 42513.26 - Last mean reward per episode: 41655.23
# Num timesteps: 327000
# Best mean reward: 42513.26 - Last mean reward per episode: 40696.04
# Num timesteps: 328000
# Best mean reward: 42513.26 - Last mean reward per episode: 39317.41
# Num timesteps: 329000
# Best mean reward: 42513.26 - Last mean reward per episode: 39751.24
# Num timesteps: 330000
# Best mean reward: 42513.26 - Last mean reward per episode: 39819.66
# Num timesteps: 331000
# Best mean reward: 42513.26 - Last mean reward per episode: 41246.49
# Num timesteps: 332000
# Best mean reward: 42513.26 - Last mean reward per episode: 41371.82
# Num timesteps: 333000
# Best mean reward: 42513.26 - Last mean reward per episode: 41892.42
# Num timesteps: 334000
# Best mean reward: 42513.26 - Last mean reward per episode: 41814.36
# Num timesteps: 335000
# Best mean reward: 42513.26 - Last mean reward per episode: 41563.70
# Num timesteps: 336000
# Best mean reward: 42513.26 - Last mean reward per episode: 41120.23
# Num timesteps: 337000
# Best mean reward: 42513.26 - Last mean reward per episode: 40064.51
# Num timesteps: 338000
# Best mean reward: 42513.26 - Last mean reward per episode: 41921.15
# Num timesteps: 339000
# Best mean reward: 42513.26 - Last mean reward per episode: 41689.78
# Num timesteps: 340000
# Best mean reward: 42513.26 - Last mean reward per episode: 40522.81
# Num timesteps: 341000
# Best mean reward: 42513.26 - Last mean reward per episode: 38722.68
# Num timesteps: 342000
# Best mean reward: 42513.26 - Last mean reward per episode: 38172.72
# Num timesteps: 343000
# Best mean reward: 42513.26 - Last mean reward per episode: 39112.64
# Num timesteps: 344000
# Best mean reward: 42513.26 - Last mean reward per episode: 40853.28
# Num timesteps: 345000
# Best mean reward: 42513.26 - Last mean reward per episode: 42547.37
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 346000
# Best mean reward: 42547.37 - Last mean reward per episode: 41613.82
# Num timesteps: 347000
# Best mean reward: 42547.37 - Last mean reward per episode: 41749.66
# Num timesteps: 348000
# Best mean reward: 42547.37 - Last mean reward per episode: 39804.27
# Num timesteps: 349000
# Best mean reward: 42547.37 - Last mean reward per episode: 40227.60
# Num timesteps: 350000
# Best mean reward: 42547.37 - Last mean reward per episode: 39671.28
# Num timesteps: 351000
# Best mean reward: 42547.37 - Last mean reward per episode: 38468.16
# Num timesteps: 352000
# Best mean reward: 42547.37 - Last mean reward per episode: 39249.06
# Num timesteps: 353000
# Best mean reward: 42547.37 - Last mean reward per episode: 39698.16
# Num timesteps: 354000
# Best mean reward: 42547.37 - Last mean reward per episode: 41221.40
# Num timesteps: 355000
# Best mean reward: 42547.37 - Last mean reward per episode: 42407.21
# Num timesteps: 356000
# Best mean reward: 42547.37 - Last mean reward per episode: 44089.58
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 357000
# Best mean reward: 44089.58 - Last mean reward per episode: 44851.20
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 358000
# Best mean reward: 44851.20 - Last mean reward per episode: 44176.35
# Num timesteps: 359000
# Best mean reward: 44851.20 - Last mean reward per episode: 43453.29
# Num timesteps: 360000
# Best mean reward: 44851.20 - Last mean reward per episode: 42932.69
# Num timesteps: 361000
# Best mean reward: 44851.20 - Last mean reward per episode: 41496.22
# Num timesteps: 362000
# Best mean reward: 44851.20 - Last mean reward per episode: 42045.74
# Num timesteps: 363000
# Best mean reward: 44851.20 - Last mean reward per episode: 42450.65
# Num timesteps: 364000
# Best mean reward: 44851.20 - Last mean reward per episode: 43424.37
# Num timesteps: 365000
# Best mean reward: 44851.20 - Last mean reward per episode: 43132.92
# Num timesteps: 366000
# Best mean reward: 44851.20 - Last mean reward per episode: 43460.71
# Num timesteps: 367000
# Best mean reward: 44851.20 - Last mean reward per episode: 42429.15
# Num timesteps: 368000
# Best mean reward: 44851.20 - Last mean reward per episode: 41966.02
# Num timesteps: 369000
# Best mean reward: 44851.20 - Last mean reward per episode: 43097.57
# Num timesteps: 370000
# Best mean reward: 44851.20 - Last mean reward per episode: 42374.52
# Num timesteps: 371000
# Best mean reward: 44851.20 - Last mean reward per episode: 43685.66
# Num timesteps: 372000
# Best mean reward: 44851.20 - Last mean reward per episode: 44176.35
# Num timesteps: 373000
# Best mean reward: 44851.20 - Last mean reward per episode: 43270.12
# Num timesteps: 374000
# Best mean reward: 44851.20 - Last mean reward per episode: 43925.69
# Num timesteps: 375000
# Best mean reward: 44851.20 - Last mean reward per episode: 43067.66
# Num timesteps: 376000
# Best mean reward: 44851.20 - Last mean reward per episode: 43519.92
# Num timesteps: 377000
# Best mean reward: 44851.20 - Last mean reward per episode: 43037.88
# Num timesteps: 378000
# Best mean reward: 44851.20 - Last mean reward per episode: 42729.38
# Num timesteps: 379000
# Best mean reward: 44851.20 - Last mean reward per episode: 42884.31
# Num timesteps: 380000
# Best mean reward: 44851.20 - Last mean reward per episode: 42711.63
# Num timesteps: 381000
# Best mean reward: 44851.20 - Last mean reward per episode: 42660.34
# Num timesteps: 382000
# Best mean reward: 44851.20 - Last mean reward per episode: 43113.45
# Num timesteps: 383000
# Best mean reward: 44851.20 - Last mean reward per episode: 44452.84
# Num timesteps: 384000
# Best mean reward: 44851.20 - Last mean reward per episode: 45175.89
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 385000
# Best mean reward: 45175.89 - Last mean reward per episode: 45564.61
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 386000
# Best mean reward: 45564.61 - Last mean reward per episode: 44764.43
# Num timesteps: 387000
# Best mean reward: 45564.61 - Last mean reward per episode: 44012.45
# Num timesteps: 388000
# Best mean reward: 45564.61 - Last mean reward per episode: 43096.58
# Num timesteps: 389000
# Best mean reward: 45564.61 - Last mean reward per episode: 43376.16
# Num timesteps: 390000
# Best mean reward: 45564.61 - Last mean reward per episode: 43096.58
# Num timesteps: 391000
# Best mean reward: 45564.61 - Last mean reward per episode: 43472.57
# Num timesteps: 392000
# Best mean reward: 45564.61 - Last mean reward per episode: 43810.00
# Num timesteps: 393000
# Best mean reward: 45564.61 - Last mean reward per episode: 44022.09
# Num timesteps: 394000
# Best mean reward: 45564.61 - Last mean reward per episode: 43665.39
# Num timesteps: 395000
# Best mean reward: 45564.61 - Last mean reward per episode: 43009.82
# Num timesteps: 396000
# Best mean reward: 45564.61 - Last mean reward per episode: 42682.03
# Num timesteps: 397000
# Best mean reward: 45564.61 - Last mean reward per episode: 42614.54
# Num timesteps: 398000
# Best mean reward: 45564.61 - Last mean reward per episode: 43723.23
# Num timesteps: 399000
# Best mean reward: 45564.61 - Last mean reward per episode: 44436.65
# Num timesteps: 400000
# Best mean reward: 45564.61 - Last mean reward per episode: 45265.75
# Num timesteps: 401000
# Best mean reward: 45564.61 - Last mean reward per episode: 44320.96
# Num timesteps: 402000
# Best mean reward: 45564.61 - Last mean reward per episode: 44157.06
# Num timesteps: 403000
# Best mean reward: 45564.61 - Last mean reward per episode: 44060.66
# Num timesteps: 404000
# Best mean reward: 45564.61 - Last mean reward per episode: 43058.02
# Num timesteps: 405000
# Best mean reward: 45564.61 - Last mean reward per episode: 44330.60
# Num timesteps: 406000
# Best mean reward: 45564.61 - Last mean reward per episode: 44181.10
# Num timesteps: 407000
# Best mean reward: 45564.61 - Last mean reward per episode: 44846.32
# Num timesteps: 408000
# Best mean reward: 45564.61 - Last mean reward per episode: 45685.06
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 409000
# Best mean reward: 45685.06 - Last mean reward per episode: 45532.79
# Num timesteps: 410000
# Best mean reward: 45685.06 - Last mean reward per episode: 45089.31
# Num timesteps: 411000
# Best mean reward: 45685.06 - Last mean reward per episode: 44510.87
# Num timesteps: 412000
# Best mean reward: 45685.06 - Last mean reward per episode: 44298.77
# Num timesteps: 413000
# Best mean reward: 45685.06 - Last mean reward per episode: 45030.35
# Num timesteps: 414000
# Best mean reward: 45685.06 - Last mean reward per episode: 45473.83
# Num timesteps: 415000
# Best mean reward: 45685.06 - Last mean reward per episode: 44770.05
# Num timesteps: 416000
# Best mean reward: 45685.06 - Last mean reward per episode: 45294.67
# Num timesteps: 417000
# Best mean reward: 45685.06 - Last mean reward per episode: 44696.95
# Num timesteps: 418000
# Best mean reward: 45685.06 - Last mean reward per episode: 43568.98
# Num timesteps: 419000
# Best mean reward: 45685.06 - Last mean reward per episode: 44320.96
# Num timesteps: 420000
# Best mean reward: 45685.06 - Last mean reward per episode: 44451.04
# Num timesteps: 421000
# Best mean reward: 45685.06 - Last mean reward per episode: 45019.85
# Num timesteps: 422000
# Best mean reward: 45685.06 - Last mean reward per episode: 45251.23
# Num timesteps: 423000
# Best mean reward: 45685.06 - Last mean reward per episode: 45651.38
# Num timesteps: 424000
# Best mean reward: 45685.06 - Last mean reward per episode: 45207.90
# Num timesteps: 425000
# Best mean reward: 45685.06 - Last mean reward per episode: 45207.90
# Num timesteps: 426000
# Best mean reward: 45685.06 - Last mean reward per episode: 44455.93
# Num timesteps: 427000
# Best mean reward: 45685.06 - Last mean reward per episode: 44301.67
# Num timesteps: 428000
# Best mean reward: 45685.06 - Last mean reward per episode: 43829.28
# Num timesteps: 429000
# Best mean reward: 45685.06 - Last mean reward per episode: 45150.06
# Num timesteps: 430000
# Best mean reward: 45685.06 - Last mean reward per episode: 44714.43
# Num timesteps: 431000
# Best mean reward: 45685.06 - Last mean reward per episode: 43605.75
# Num timesteps: 432000
# Best mean reward: 45685.06 - Last mean reward per episode: 42964.58
# Num timesteps: 433000
# Best mean reward: 45685.06 - Last mean reward per episode: 43583.38
# Num timesteps: 434000
# Best mean reward: 45685.06 - Last mean reward per episode: 44682.42
# Num timesteps: 435000
# Best mean reward: 45685.06 - Last mean reward per episode: 44566.73
# Num timesteps: 436000
# Best mean reward: 45685.06 - Last mean reward per episode: 44205.27
# Num timesteps: 437000
# Best mean reward: 45685.06 - Last mean reward per episode: 44359.52
# Num timesteps: 438000
# Best mean reward: 45685.06 - Last mean reward per episode: 42391.70
# Num timesteps: 439000
# Best mean reward: 45685.06 - Last mean reward per episode: 43317.21
# Num timesteps: 440000
# Best mean reward: 45685.06 - Last mean reward per episode: 42931.58
# Num timesteps: 441000
# Best mean reward: 45685.06 - Last mean reward per episode: 43395.45
# Num timesteps: 442000
# Best mean reward: 45685.06 - Last mean reward per episode: 44677.66
# Num timesteps: 443000
# Best mean reward: 45685.06 - Last mean reward per episode: 44369.16
# Num timesteps: 444000
# Best mean reward: 45685.06 - Last mean reward per episode: 43954.61
# Num timesteps: 445000
# Best mean reward: 45685.06 - Last mean reward per episode: 42604.90
# Num timesteps: 446000
# Best mean reward: 45685.06 - Last mean reward per episode: 42865.20
# Num timesteps: 447000
# Best mean reward: 45685.06 - Last mean reward per episode: 43086.94
# Num timesteps: 448000
# Best mean reward: 45685.06 - Last mean reward per episode: 44783.71
# Num timesteps: 449000
# Best mean reward: 45685.06 - Last mean reward per episode: 45477.85
# Num timesteps: 450000
# Best mean reward: 45685.06 - Last mean reward per episode: 45776.71
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 451000
# Best mean reward: 45776.71 - Last mean reward per episode: 46644.38
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 452000
# Best mean reward: 46644.38 - Last mean reward per episode: 45699.58
# Num timesteps: 453000
# Best mean reward: 46644.38 - Last mean reward per episode: 46451.56
# Num timesteps: 454000
# Best mean reward: 46644.38 - Last mean reward per episode: 46046.65
# Num timesteps: 455000
# Best mean reward: 46644.38 - Last mean reward per episode: 44880.12
# Num timesteps: 456000
# Best mean reward: 46644.38 - Last mean reward per episode: 45728.50
# Num timesteps: 457000
# Best mean reward: 46644.38 - Last mean reward per episode: 44928.32
# Num timesteps: 458000
# Best mean reward: 46644.38 - Last mean reward per episode: 45265.75
# Num timesteps: 459000
# Best mean reward: 46644.38 - Last mean reward per episode: 45429.64
# Num timesteps: 460000
# Best mean reward: 46644.38 - Last mean reward per episode: 45005.45
# Num timesteps: 461000
# Best mean reward: 46644.38 - Last mean reward per episode: 45795.99
# Num timesteps: 462000
# Best mean reward: 46644.38 - Last mean reward per episode: 45940.60
# Num timesteps: 463000
# Best mean reward: 46644.38 - Last mean reward per episode: 45795.99
# Num timesteps: 464000
# Best mean reward: 46644.38 - Last mean reward per episode: 45863.47
# Num timesteps: 465000
# Best mean reward: 46644.38 - Last mean reward per episode: 46316.59
# Num timesteps: 466000
# Best mean reward: 46644.38 - Last mean reward per episode: 45979.16
# Num timesteps: 467000
# Best mean reward: 46644.38 - Last mean reward per episode: 45824.91
# Num timesteps: 468000
# Best mean reward: 46644.38 - Last mean reward per episode: 45285.03
# Num timesteps: 469000
# Best mean reward: 46644.38 - Last mean reward per episode: 44928.32
# Num timesteps: 470000
# Best mean reward: 46644.38 - Last mean reward per episode: 45182.38
# Num timesteps: 471000
# Best mean reward: 46644.38 - Last mean reward per episode: 44324.36
# Num timesteps: 472000
# Best mean reward: 46644.38 - Last mean reward per episode: 43678.43
# Num timesteps: 473000
# ...
# Best mean reward: 47618.09 - Last mean reward per episode: 46413.00
# Num timesteps: 825000
# Best mean reward: 47618.09 - Last mean reward per episode: 45988.80
# Num timesteps: 826000
# Best mean reward: 47618.09 - Last mean reward per episode: 46335.87
# Num timesteps: 827000
# Best mean reward: 47618.09 - Last mean reward per episode: 46827.55
# Num timesteps: 828000
# Best mean reward: 47618.09 - Last mean reward per episode: 46654.02
# Num timesteps: 829000
# Best mean reward: 47618.09 - Last mean reward per episode: 46654.02
# Num timesteps: 830000
# Best mean reward: 47618.09 - Last mean reward per episode: 46403.36
# Num timesteps: 831000
# Best mean reward: 47618.09 - Last mean reward per episode: 46403.36
# Num timesteps: 832000
# Best mean reward: 47618.09 - Last mean reward per episode: 46326.23
# Num timesteps: 833000
# Best mean reward: 47618.09 - Last mean reward per episode: 46923.96
# Num timesteps: 834000
# Best mean reward: 47618.09 - Last mean reward per episode: 47126.41
# Num timesteps: 835000
# Best mean reward: 47618.09 - Last mean reward per episode: 46779.35
# Num timesteps: 836000
# Best mean reward: 47618.09 - Last mean reward per episode: 46345.51
# Num timesteps: 837000
# Best mean reward: 47618.09 - Last mean reward per episode: 46490.12
# Num timesteps: 838000
# Best mean reward: 47618.09 - Last mean reward per episode: 45930.96
# Num timesteps: 839000
# Best mean reward: 47618.09 - Last mean reward per episode: 45930.96
# Num timesteps: 840000
# Best mean reward: 47618.09 - Last mean reward per episode: 46364.79
# Num timesteps: 841000
# Best mean reward: 47618.09 - Last mean reward per episode: 45670.66
# Num timesteps: 842000
# Best mean reward: 47618.09 - Last mean reward per episode: 45689.94
# Num timesteps: 843000
# Best mean reward: 47618.09 - Last mean reward per episode: 45362.16
# Num timesteps: 844000
# Best mean reward: 47618.09 - Last mean reward per episode: 45362.16
# Num timesteps: 845000
# Best mean reward: 47618.09 - Last mean reward per episode: 45659.47
# Num timesteps: 846000
# Best mean reward: 47618.09 - Last mean reward per episode: 45852.29
# Num timesteps: 847000
# Best mean reward: 47618.09 - Last mean reward per episode: 46180.07
# Num timesteps: 848000
# Best mean reward: 47618.09 - Last mean reward per episode: 46209.00
# Num timesteps: 849000
# Best mean reward: 47618.09 - Last mean reward per episode: 46798.63
# Num timesteps: 850000
# Best mean reward: 47618.09 - Last mean reward per episode: 47145.69
# Num timesteps: 851000
# Best mean reward: 47618.09 - Last mean reward per episode: 47164.98
# Num timesteps: 852000
# Best mean reward: 47618.09 - Last mean reward per episode: 46933.60
# Num timesteps: 853000
# Best mean reward: 47618.09 - Last mean reward per episode: 46692.58
# Num timesteps: 854000
# Best mean reward: 47618.09 - Last mean reward per episode: 46692.58
# Num timesteps: 855000
# Best mean reward: 47618.09 - Last mean reward per episode: 46673.30
# Num timesteps: 856000
# Best mean reward: 47618.09 - Last mean reward per episode: 46576.89
# Num timesteps: 857000
# Best mean reward: 47618.09 - Last mean reward per episode: 46576.89
# Num timesteps: 858000
# Best mean reward: 47618.09 - Last mean reward per episode: 46335.87
# Num timesteps: 859000
# Best mean reward: 47618.09 - Last mean reward per episode: 46885.39
# Num timesteps: 860000
# Best mean reward: 47618.09 - Last mean reward per episode: 46788.99
# Num timesteps: 861000
# Best mean reward: 47618.09 - Last mean reward per episode: 46788.99
# Num timesteps: 862000
# Best mean reward: 47618.09 - Last mean reward per episode: 47030.00
# Num timesteps: 863000
# Best mean reward: 47618.09 - Last mean reward per episode: 47174.62
# Num timesteps: 864000
# Best mean reward: 47618.09 - Last mean reward per episode: 47618.09
# Num timesteps: 865000
# Best mean reward: 47618.09 - Last mean reward per episode: 46923.96
# Num timesteps: 866000
# Best mean reward: 47618.09 - Last mean reward per episode: 46923.96
# Num timesteps: 867000
# Best mean reward: 47618.09 - Last mean reward per episode: 46634.73
# Num timesteps: 868000
# Best mean reward: 47618.09 - Last mean reward per episode: 46306.95
# Num timesteps: 869000
# Best mean reward: 47618.09 - Last mean reward per episode: 46654.02
# Num timesteps: 870000
# Best mean reward: 47618.09 - Last mean reward per episode: 46509.40
# Num timesteps: 871000
# Best mean reward: 47618.09 - Last mean reward per episode: 46798.63
# Num timesteps: 872000
# Best mean reward: 47618.09 - Last mean reward per episode: 47386.71
# Num timesteps: 873000
# Best mean reward: 47618.09 - Last mean reward per episode: 47213.18
# Num timesteps: 874000
# Best mean reward: 47618.09 - Last mean reward per episode: 47357.79
# Num timesteps: 875000
# Best mean reward: 47618.09 - Last mean reward per episode: 46663.66
# Num timesteps: 876000
# Best mean reward: 47618.09 - Last mean reward per episode: 46181.62
# Num timesteps: 877000
# Best mean reward: 47618.09 - Last mean reward per episode: 46355.15
# Num timesteps: 878000
# Best mean reward: 47618.09 - Last mean reward per episode: 47049.29
# Num timesteps: 879000
# Best mean reward: 47618.09 - Last mean reward per episode: 46827.55
# Num timesteps: 880000
# Best mean reward: 47618.09 - Last mean reward per episode: 47174.62
# Num timesteps: 881000
# Best mean reward: 47618.09 - Last mean reward per episode: 46538.33
# Num timesteps: 882000
# Best mean reward: 47618.09 - Last mean reward per episode: 46355.15
# Num timesteps: 883000
# Best mean reward: 47618.09 - Last mean reward per episode: 46335.87
# Num timesteps: 884000
# Best mean reward: 47618.09 - Last mean reward per episode: 46499.76
# Num timesteps: 885000
# Best mean reward: 47618.09 - Last mean reward per episode: 46152.70
# Num timesteps: 886000
# Best mean reward: 47618.09 - Last mean reward per episode: 46625.09
# Num timesteps: 887000
# Best mean reward: 47618.09 - Last mean reward per episode: 46278.03
# Num timesteps: 888000
# Best mean reward: 47618.09 - Last mean reward per episode: 46403.36
# Num timesteps: 889000
# Best mean reward: 47618.09 - Last mean reward per episode: 46413.00
# Num timesteps: 890000
# Best mean reward: 47618.09 - Last mean reward per episode: 46933.60
# Num timesteps: 891000
# Best mean reward: 47618.09 - Last mean reward per episode: 46586.53
# Num timesteps: 892000
# Best mean reward: 47618.09 - Last mean reward per episode: 45892.40
# Num timesteps: 893000
# Best mean reward: 47618.09 - Last mean reward per episode: 46229.82
# Num timesteps: 894000
# Best mean reward: 47618.09 - Last mean reward per episode: 46229.82
# Num timesteps: 895000
# Best mean reward: 47618.09 - Last mean reward per episode: 46094.85
# Num timesteps: 896000
# Best mean reward: 47618.09 - Last mean reward per episode: 46441.92
# Num timesteps: 897000
# Best mean reward: 47618.09 - Last mean reward per episode: 46094.85
# Num timesteps: 898000
# Best mean reward: 47618.09 - Last mean reward per episode: 46788.99
# Num timesteps: 899000
# Best mean reward: 47618.09 - Last mean reward per episode: 46808.27
# Num timesteps: 900000
# Best mean reward: 47618.09 - Last mean reward per episode: 46846.83
# Num timesteps: 901000
# Best mean reward: 47618.09 - Last mean reward per episode: 46499.76
# Num timesteps: 902000
# Best mean reward: 47618.09 - Last mean reward per episode: 46152.70
# Num timesteps: 903000
# Best mean reward: 47618.09 - Last mean reward per episode: 46654.02
# Num timesteps: 904000
# Best mean reward: 47618.09 - Last mean reward per episode: 46654.02
# Num timesteps: 905000
# Best mean reward: 47618.09 - Last mean reward per episode: 46306.95
# Num timesteps: 906000
# Best mean reward: 47618.09 - Last mean reward per episode: 46654.02
# Num timesteps: 907000
# Best mean reward: 47618.09 - Last mean reward per episode: 46923.96
# Num timesteps: 908000
# Best mean reward: 47618.09 - Last mean reward per episode: 47618.09
# Num timesteps: 909000
# Best mean reward: 47618.09 - Last mean reward per episode: 47618.09
# Num timesteps: 910000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 911000
# Best mean reward: 47618.09 - Last mean reward per episode: 47078.21
# Num timesteps: 912000
# Best mean reward: 47618.09 - Last mean reward per episode: 46384.08
# Num timesteps: 913000
# Best mean reward: 47618.09 - Last mean reward per episode: 46384.08
# Num timesteps: 914000
# Best mean reward: 47618.09 - Last mean reward per episode: 46866.11
# Num timesteps: 915000
# Best mean reward: 47618.09 - Last mean reward per episode: 46923.96
# Num timesteps: 916000
# Best mean reward: 47618.09 - Last mean reward per episode: 47483.12
# Num timesteps: 917000
# Best mean reward: 47618.09 - Last mean reward per episode: 47483.12
# Num timesteps: 918000
# Best mean reward: 47618.09 - Last mean reward per episode: 47155.33
# Num timesteps: 919000
# Best mean reward: 47618.09 - Last mean reward per episode: 47290.30
# Num timesteps: 920000
# Best mean reward: 47618.09 - Last mean reward per episode: 46249.10
# Num timesteps: 921000
# Best mean reward: 47618.09 - Last mean reward per episode: 46249.10
# Num timesteps: 922000
# Best mean reward: 47618.09 - Last mean reward per episode: 46538.33
# Num timesteps: 923000
# Best mean reward: 47618.09 - Last mean reward per episode: 46634.73
# Num timesteps: 924000
# Best mean reward: 47618.09 - Last mean reward per episode: 46981.80
# Num timesteps: 925000
# Best mean reward: 47618.09 - Last mean reward per episode: 46634.73
# Num timesteps: 926000
# Best mean reward: 47618.09 - Last mean reward per episode: 46576.89
# Num timesteps: 927000
# Best mean reward: 47618.09 - Last mean reward per episode: 46576.89
# Num timesteps: 928000
# Best mean reward: 47618.09 - Last mean reward per episode: 46576.89
# Num timesteps: 929000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 930000
# Best mean reward: 47618.09 - Last mean reward per episode: 46663.66
# Num timesteps: 931000
# Best mean reward: 47618.09 - Last mean reward per episode: 46316.59
# Num timesteps: 932000
# Best mean reward: 47618.09 - Last mean reward per episode: 46085.21
# Num timesteps: 933000
# Best mean reward: 47618.09 - Last mean reward per episode: 46692.58
# Num timesteps: 934000
# Best mean reward: 47618.09 - Last mean reward per episode: 46692.58
# Num timesteps: 935000
# Best mean reward: 47618.09 - Last mean reward per episode: 47618.09
# Num timesteps: 936000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 937000
# Best mean reward: 47618.09 - Last mean reward per episode: 47126.41
# Num timesteps: 938000
# Best mean reward: 47618.09 - Last mean reward per episode: 47126.41
# Num timesteps: 939000
# Best mean reward: 47618.09 - Last mean reward per episode: 46779.35
# Num timesteps: 940000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 941000
# Best mean reward: 47618.09 - Last mean reward per episode: 46923.96
# Num timesteps: 942000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 943000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 944000
# Best mean reward: 47618.09 - Last mean reward per episode: 46923.96
# Num timesteps: 945000
# Best mean reward: 47618.09 - Last mean reward per episode: 46654.02
# Num timesteps: 946000
# Best mean reward: 47618.09 - Last mean reward per episode: 46654.02
# Num timesteps: 947000
# Best mean reward: 47618.09 - Last mean reward per episode: 46654.02
# Num timesteps: 948000
# Best mean reward: 47618.09 - Last mean reward per episode: 46625.09
# Num timesteps: 949000
# Best mean reward: 47618.09 - Last mean reward per episode: 47242.10
# Num timesteps: 950000
# Best mean reward: 47618.09 - Last mean reward per episode: 47242.10
# Num timesteps: 951000
# Best mean reward: 47618.09 - Last mean reward per episode: 47242.10
# Num timesteps: 952000
# Best mean reward: 47618.09 - Last mean reward per episode: 47618.09
# Num timesteps: 953000
# Best mean reward: 47618.09 - Last mean reward per episode: 47521.68
# Num timesteps: 954000
# Best mean reward: 47618.09 - Last mean reward per episode: 47521.68
# Num timesteps: 955000
# Best mean reward: 47618.09 - Last mean reward per episode: 47521.68
# Num timesteps: 956000
# Best mean reward: 47618.09 - Last mean reward per episode: 47213.18
# Num timesteps: 957000
# Best mean reward: 47618.09 - Last mean reward per episode: 46962.52
# Num timesteps: 958000
# Best mean reward: 47618.09 - Last mean reward per episode: 46345.51
# Num timesteps: 959000
# Best mean reward: 47618.09 - Last mean reward per episode: 46345.51
# Num timesteps: 960000
# Best mean reward: 47618.09 - Last mean reward per episode: 46779.35
# Num timesteps: 961000
# Best mean reward: 47618.09 - Last mean reward per episode: 47396.35
# Num timesteps: 962000
# Best mean reward: 47618.09 - Last mean reward per episode: 47396.35
# Num timesteps: 963000
# Best mean reward: 47618.09 - Last mean reward per episode: 47618.09
# Num timesteps: 964000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 965000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 966000
# Best mean reward: 47618.09 - Last mean reward per episode: 46923.96
# Num timesteps: 967000
# Best mean reward: 47618.09 - Last mean reward per episode: 46923.96
# Num timesteps: 968000
# Best mean reward: 47618.09 - Last mean reward per episode: 47049.29
# Num timesteps: 969000
# Best mean reward: 47618.09 - Last mean reward per episode: 46702.22
# Num timesteps: 970000
# Best mean reward: 47618.09 - Last mean reward per episode: 47049.29
# Num timesteps: 971000
# Best mean reward: 47618.09 - Last mean reward per episode: 46981.80
# Num timesteps: 972000
# Best mean reward: 47618.09 - Last mean reward per episode: 46981.80
# Num timesteps: 973000
# Best mean reward: 47618.09 - Last mean reward per episode: 46981.80
# Num timesteps: 974000
# Best mean reward: 47618.09 - Last mean reward per episode: 46625.09
# Num timesteps: 975000
# Best mean reward: 47618.09 - Last mean reward per episode: 46549.33
# Num timesteps: 976000
# Best mean reward: 47618.09 - Last mean reward per episode: 46665.02
# Num timesteps: 977000
# Best mean reward: 47618.09 - Last mean reward per episode: 46327.59
# Num timesteps: 978000
# Best mean reward: 47618.09 - Last mean reward per episode: 46264.86
# Num timesteps: 979000
# Best mean reward: 47618.09 - Last mean reward per episode: 46629.85
# Num timesteps: 980000
# Best mean reward: 47618.09 - Last mean reward per episode: 46861.23
# Num timesteps: 981000
# Best mean reward: 47618.09 - Last mean reward per episode: 47208.30
# Num timesteps: 982000
# Best mean reward: 47618.09 - Last mean reward per episode: 47618.09
# Num timesteps: 983000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 984000
# Best mean reward: 47618.09 - Last mean reward per episode: 46788.99
# Num timesteps: 985000
# Best mean reward: 47618.09 - Last mean reward per episode: 46788.99
# Num timesteps: 986000
# Best mean reward: 47618.09 - Last mean reward per episode: 47136.05
# Num timesteps: 987000
# Best mean reward: 47618.09 - Last mean reward per episode: 46788.99
# Num timesteps: 988000
# Best mean reward: 47618.09 - Last mean reward per episode: 46596.17
# Num timesteps: 989000
# Best mean reward: 47618.09 - Last mean reward per episode: 46441.92
# Num timesteps: 990000
# Best mean reward: 47618.09 - Last mean reward per episode: 46441.92
# Num timesteps: 991000
# Best mean reward: 47618.09 - Last mean reward per episode: 46788.99
# Num timesteps: 992000
# Best mean reward: 47618.09 - Last mean reward per episode: 46952.88
# Num timesteps: 993000
# Best mean reward: 47618.09 - Last mean reward per episode: 46605.81
# Num timesteps: 994000
# Best mean reward: 47618.09 - Last mean reward per episode: 46605.81
# Num timesteps: 995000
# Best mean reward: 47618.09 - Last mean reward per episode: 46605.81
# Num timesteps: 996000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 997000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 998000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 999000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 1000000
# Best mean reward: 47618.09 - Last mean reward per episode: 47271.02
# Num timesteps: 1001000
# Best mean reward: 47618.09 - Last mean reward per episode: 47116.77

# %%
print('Total time taken: {} min'.format((end - start)/60))
# Out:
# Total time taken: 19.00903176466624 min

# %% [markdown]
# ### Inference

# %%
env.M.flag_=True
# env.M.flag_=False
obs=env.reset()
obs=obs[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.M to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.M` for environment variables or `env.get_wrapper_attr('M')` that will search the reminding wrappers.
#   logger.warn(

# %%
i=0
while i<1000:
    action, _states = model.predict(obs)
    obs, rewards, dones, _, info = env.step(int(action))
    if dones:
        break
    i+=1

# %%
env.args = get_args(*mbb_beam(rd=env.rd))
t__, c__ = fast_stopt(env.args, env.x)
t__
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.rd to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.rd` for environment variables or `env.get_wrapper_attr('rd')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.x to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.x` for environment variables or `env.get_wrapper_attr('x')` that will search the reminding wrappers.
#   logger.warn(
# 4587738847.362389

# %%
c__
# Out:
# 0.027875000000000007

# %%
print(i)
# Out:
# 36

# %%
env.render()
# Out:
# Final Cantilever beam design:

# %%
results_plotter.plot_results([log_dir], ts, results_plotter.X_TIMESTEPS, "CantileverEnv")

# %%
env.M.flag_=False
obs=env.reset()
obs=obs[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.M to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.M` for environment variables or `env.get_wrapper_attr('M')` that will search the reminding wrappers.
#   logger.warn(

# %%
# Load the agent
model_best = PPO.load(log_dir + "best_model.zip",env=env)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.render_mode to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.render_mode` for environment variables or `env.get_wrapper_attr('render_mode')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:77: UserWarning: The `render_mode` attribute is not defined in your environment. It will be set to None.
#   warnings.warn("The `render_mode` attribute is not defined in your environment. It will be set to None.")

# %%
i=0
while i<1000:
    action, _states = model_best.predict(obs)
    
    obs, rewards, dones, _,info = env.step(int(action))
    if dones:
        break
    i+=1

# %%
i
# Out:
# 36

# %%
env.render()
# Out:
# Final Cantilever beam design:

# %%
env.args = get_args(*mbb_beam(rd=env.rd))
t__, c__ = fast_stopt(env.args, env.x)
t__
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.rd to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.rd` for environment variables or `env.get_wrapper_attr('rd')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.x to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.x` for environment variables or `env.get_wrapper_attr('x')` that will search the reminding wrappers.
#   logger.warn(
# 2790076383.419832

# %%
c__
# Out:
# 0.027875000000000007
