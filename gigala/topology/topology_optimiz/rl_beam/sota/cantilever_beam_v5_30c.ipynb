# %%
import time
import os
import random
import numpy as np                                                
import matplotlib.pyplot as plt                                   
import autograd, autograd.core, autograd.extend, autograd.tracer  
import autograd.numpy as anp      
import scipy, scipy.ndimage, scipy.sparse, scipy.sparse.linalg    
                                                     
import gym
# from gym import spaces
from gymnasium import spaces


from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common import results_plotter

# %% [markdown]
# The below code is my RL extension to and rework of https://www.researchgate.net/publication/360698153_A_Tutorial_on_Structural_Optimization

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d
    
def get_args(normals, forces, density=1e-4):  # Manage the problem setup parameters
    width = normals.shape[0] - 1
    height = normals.shape[1] - 1
    fixdofs = np.flatnonzero(normals.ravel())
    alldofs = np.arange(2 * (width + 1) * (height + 1))
    freedofs = np.sort(list(set(alldofs) - set(fixdofs)))
    params = {
      # material properties
      'young': 1, 'young_min': 1e-9, 'poisson': 0.3, 'g': 0,
      # constraints
      'density': density, 'xmin': 0.001, 'xmax': 1.0,
      # input parameters
      'nelx': width, 'nely': height, 'mask': 1, 'penal': 3.0, 'filter_width': 1,
      'freedofs': freedofs, 'fixdofs': fixdofs, 'forces': forces.ravel(),
      # optimization parameters
      'opt_steps': 80, 'print_every': 10}
    return ObjectView(params)

def mbb_beam(width=6, height=6, density=1e-4, y=1, x=0, rd=-1):  # textbook beam example
    normals = np.zeros((width + 1, height + 1, 2))
    normals[0, 0, x] = 1
    normals[0, 0, y] = 1
    normals[0, -1, x] = 1
    normals[0, -1, y] = 1
    forces = np.zeros((width + 1, height + 1, 2))
    forces[-1, rd, y] = -1
    return normals, forces, density

# %%
def young_modulus(x, e_0, e_min, p=3):
    return e_min + x ** p * (e_0 - e_min)

def physical_density(x, args, volume_contraint=False, use_filter=True):
    x = args.mask * x.reshape(args.nely, args.nelx)  # reshape from 1D to 2D
    return gaussian_filter(x, args.filter_width) if use_filter else x  # maybe filter

def mean_density(x, args, volume_contraint=False, use_filter=True):
    return anp.mean(physical_density(x, args, volume_contraint, use_filter)) / anp.mean(args.mask)

# %%
def objective(x, args, volume_contraint=False, use_filter=True):
    kwargs = dict(penal=args.penal, e_min=args.young_min, e_0=args.young)
    x_phys = physical_density(x, args, volume_contraint=volume_contraint, use_filter=use_filter)
    ke     = get_stiffness_matrix(args.young, args.poisson)  # stiffness matrix
    u      = displace(x_phys, ke, args.forces, args.freedofs, args.fixdofs, **kwargs)
    c      = compliance(x_phys, u, ke, **kwargs)
    return c

# %%
@autograd.extend.primitive
def gaussian_filter(x, width): # 2D gaussian blur/filter
    return scipy.ndimage.gaussian_filter(x, width, mode='reflect')

def _gaussian_filter_vjp(ans, x, width): # gives the gradient of orig. function w.r.t. x
    del ans, x  # unused
    return lambda g: gaussian_filter(g, width)
autograd.extend.defvjp(gaussian_filter, _gaussian_filter_vjp)

# %%
def compliance(x_phys, u, ke, *, penal=3, e_min=1e-9, e_0=1):
    nely, nelx = x_phys.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords for the index map

    n1 = (nely+1)*(elx+0) + (ely+0)  # nodes
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    all_ixs = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    u_selected = u[all_ixs]  # select from u matrix

    ke_u = anp.einsum('ij,jkl->ikl', ke, u_selected)  # compute x^penal * U.T @ ke @ U
    ce = anp.einsum('ijk,ijk->jk', u_selected, ke_u)
    C = young_modulus(x_phys, e_0, e_min, p=penal) * ce.T
    return anp.sum(C)

def get_stiffness_matrix(e, nu):  # e=young's modulus, nu=poisson coefficient
    k = anp.array([1/2-nu/6, 1/8+nu/8, -1/4-nu/12, -1/8+3*nu/8,
                -1/4+nu/12, -1/8-nu/8, nu/6, 1/8-3*nu/8])
    return e/(1-nu**2)*anp.array([[k[0], k[1], k[2], k[3], k[4], k[5], k[6], k[7]],
                               [k[1], k[0], k[7], k[6], k[5], k[4], k[3], k[2]],
                               [k[2], k[7], k[0], k[5], k[6], k[3], k[4], k[1]],
                               [k[3], k[6], k[5], k[0], k[7], k[2], k[1], k[4]],
                               [k[4], k[5], k[6], k[7], k[0], k[1], k[2], k[3]],
                               [k[5], k[4], k[3], k[2], k[1], k[0], k[7], k[6]],
                               [k[6], k[3], k[4], k[1], k[2], k[7], k[0], k[5]],
                               [k[7], k[2], k[1], k[4], k[3], k[6], k[5], k[0]]])

# %%
def get_k(stiffness, ke):
    # Constructs sparse stiffness matrix k (used in the displace fn)
    # First, get position of the nodes of each element in the stiffness matrix
    nely, nelx = stiffness.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords
    ely, elx = ely.reshape(-1, 1), elx.reshape(-1, 1)

    n1 = (nely+1)*(elx+0) + (ely+0)
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    edof = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    edof = edof.T[0]
    x_list = anp.repeat(edof, 8)  # flat list pointer of each node in an element
    y_list = anp.tile(edof, 8).flatten()  # flat list pointer of each node in elem

    # make the global stiffness matrix K
    kd = stiffness.T.reshape(nelx*nely, 1, 1)
    value_list = (kd * anp.tile(ke, kd.shape)).flatten()
    return value_list, y_list, x_list

def displace(x_phys, ke, forces, freedofs, fixdofs, *, penal=3, e_min=1e-9, e_0=1):
    # Displaces the load x using finite element techniques (solve_coo=most of runtime)
    stiffness = young_modulus(x_phys, e_0, e_min, p=penal)
    k_entries, k_ylist, k_xlist = get_k(stiffness, ke)

    index_map, keep, indices = _get_dof_indices(freedofs, fixdofs, k_ylist, k_xlist)

    u_nonzero = solve_coo(k_entries[keep], indices, forces[freedofs], sym_pos=True)
    u_values = anp.concatenate([u_nonzero, anp.zeros(len(fixdofs))])
    return u_values[index_map]

# %%
def _get_dof_indices(freedofs, fixdofs, k_xlist, k_ylist):
    index_map = inverse_permutation(anp.concatenate([freedofs, fixdofs]))
    keep = anp.isin(k_xlist, freedofs) & anp.isin(k_ylist, freedofs)
    # Now we index an indexing array that is being indexed by the indices of k
    i = index_map[k_ylist][keep]
    j = index_map[k_xlist][keep]
    return index_map, keep, anp.stack([i, j])

def inverse_permutation(indices):  # reverses an index operation
    inverse_perm = np.zeros(len(indices), dtype=anp.int64)
    inverse_perm[indices] = np.arange(len(indices), dtype=anp.int64)
    return inverse_perm

# %%
def _get_solver(a_entries, a_indices, size, sym_pos):
    # a is (usu.) symmetric positive; could solve 2x faster w/sksparse.cholmod.cholesky(a).solve_A
    a = scipy.sparse.coo_matrix((a_entries, a_indices), shape=(size,)*2).tocsc()
    return scipy.sparse.linalg.splu(a).solve

@autograd.primitive
def solve_coo(a_entries, a_indices, b, sym_pos=False):
    solver = _get_solver(a_entries, a_indices, b.size, sym_pos)
    return solver(b)

def grad_solve_coo_entries(ans, a_entries, a_indices, b, sym_pos=False):
    def jvp(grad_ans):
        lambda_ = solve_coo(a_entries, a_indices if sym_pos else a_indices[::-1],
                            grad_ans, sym_pos)
        i, j = a_indices
        return -lambda_[i] * ans[j]
    return jvp

autograd.extend.defvjp(solve_coo, grad_solve_coo_entries,
                       lambda: print('err: gradient undefined'),
                       lambda: print('err: gradient not implemented'))

# %%
class Model:
    def __init__(self, x):
        self.flag_ = True
#         self.flag_ = False
        self.n, self.m = x.shape
        self.actions_dic={} 
    
        k=0
        for i in range(self.n):
            for j in range(self.m):
                self.actions_dic[k]=(i,j)
                k+=1
        
    def action_space_(self, action, X):
        x,y=self.actions_dic[action]
        X[x][y]=1
        
    def draw(self,X):  
        plt.figure(dpi=50) 
        print('\nFinal Cantilever beam design:')
        plt.imshow(X) 
        plt.show()

# %%
def fast_stopt(args, x):

    reshape = lambda x: x.reshape(args.nely, args.nelx)
    objective_fn = lambda x: objective(reshape(x), args)
#     constraint = lambda params: mean_density(reshape(params), args) - args.density
    constraint = lambda params: mean_density(reshape(params), args) 
    value = objective_fn(x)
    const = constraint(x)
    return value, const

# %%
class CantileverEnv(gym.Env):
    
    metadata = {"render.modes": ["human"]}

    def __init__(self):
        super().__init__()
        
        
        self.rd=0
        self.args = get_args(*mbb_beam(rd=self.rd))
        
        DIM=self.args.nelx*self.args.nely
        N_DISCRETE_ACTIONS=self.args.nelx*self.args.nely
        
        self.action_space = spaces.Discrete(N_DISCRETE_ACTIONS)
        self.observation_space = spaces.Box(low=np.array([-1e10 for x in range(DIM)]),
                                            high=np.array([1e10 for y in range(DIM)]),
                                            shape=(DIM,),
                                           dtype=np.float64)
        
 
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density 
    
        self.M=Model(self.x)
        
        self.reward=0
        self.step_=0
        self.needs_reset = True
        
    def step(self, action):
        
        self.args = get_args(*mbb_beam(rd=self.rd))
        
        self.M.action_space_(action, self.x)
        
        tmp, const = fast_stopt(self.args, self.x)
        
        self.step_+=1
        
        
        a1=1/tmp
        a2=1/const
        
        self.reward = 2*a1*a2/(a1+a2)
       
        done=False
                  
        if self.step_>self.M.n*self.M.m:
            done=True
            
        if const>0.7:
#             self.reward-=1
            done=True
            
        if self.needs_reset:
            raise RuntimeError("Tried to step environment that needs reset")
            
        if done:
            self.needs_reset = True
                         
      
        return self.x.reshape(self.x.shape[0]*self.x.shape[1]), self.reward, done,False, dict()

    def reset(self,seed=0):
        
        if not self.M.flag_:
            self.rd=random.choice([0,2,-2])
        else:
            self.rd=-1
           
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density 

        self.reward=0
        self.needs_reset = False
        self.step_=0

        return self.x.reshape(self.x.shape[0]*self.x.shape[1]),{}

    def render(self, mode="human"):
        self.M.draw(self.x)    

    def close(self):
        pass

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %%
# ts=5e6
ts=1e6

# %%
# Create log dir
log_dir = "/tmp/gym6_2bc/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = CantileverEnv()
# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)
check_env(env)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.render_mode to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.render_mode` for environment variables or `env.get_wrapper_attr('render_mode')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:77: UserWarning: The `render_mode` attribute is not defined in your environment. It will be set to None.
#   warnings.warn("The `render_mode` attribute is not defined in your environment. It will be set to None.")

# %%
# callback = SaveOnBestTrainingRewardCallback(check_freq=5000, log_dir=log_dir)
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)

# %%
start=time.time()
model = PPO("MlpPolicy", env).learn(total_timesteps=ts, callback=callback)
end=time.time()
# Out:
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: 0.19
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 2000
# Best mean reward: 0.19 - Last mean reward per episode: 0.24
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 3000
# Best mean reward: 0.24 - Last mean reward per episode: 0.26
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 4000
# Best mean reward: 0.26 - Last mean reward per episode: 0.25
# Num timesteps: 5000
# Best mean reward: 0.26 - Last mean reward per episode: 0.27
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 6000
# Best mean reward: 0.27 - Last mean reward per episode: 0.26
# Num timesteps: 7000
# Best mean reward: 0.27 - Last mean reward per episode: 0.28
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 8000
# Best mean reward: 0.28 - Last mean reward per episode: 0.30
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 9000
# Best mean reward: 0.30 - Last mean reward per episode: 0.33
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 10000
# Best mean reward: 0.33 - Last mean reward per episode: 0.36
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 11000
# Best mean reward: 0.36 - Last mean reward per episode: 0.36
# Num timesteps: 12000
# Best mean reward: 0.36 - Last mean reward per episode: 0.38
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 13000
# Best mean reward: 0.38 - Last mean reward per episode: 0.40
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 14000
# Best mean reward: 0.40 - Last mean reward per episode: 0.39
# Num timesteps: 15000
# Best mean reward: 0.40 - Last mean reward per episode: 0.42
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 16000
# Best mean reward: 0.42 - Last mean reward per episode: 0.44
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 17000
# Best mean reward: 0.44 - Last mean reward per episode: 0.48
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 18000
# Best mean reward: 0.48 - Last mean reward per episode: 0.50
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 19000
# Best mean reward: 0.50 - Last mean reward per episode: 0.51
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 20000
# Best mean reward: 0.51 - Last mean reward per episode: 0.54
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 21000
# Best mean reward: 0.54 - Last mean reward per episode: 0.54
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 22000
# Best mean reward: 0.54 - Last mean reward per episode: 0.53
# Num timesteps: 23000
# Best mean reward: 0.54 - Last mean reward per episode: 0.53
# Num timesteps: 24000
# Best mean reward: 0.54 - Last mean reward per episode: 0.54
# Num timesteps: 25000
# Best mean reward: 0.54 - Last mean reward per episode: 0.55
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 26000
# Best mean reward: 0.55 - Last mean reward per episode: 0.57
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 27000
# Best mean reward: 0.57 - Last mean reward per episode: 0.57
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 28000
# Best mean reward: 0.57 - Last mean reward per episode: 0.59
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 29000
# Best mean reward: 0.59 - Last mean reward per episode: 0.61
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 30000
# Best mean reward: 0.61 - Last mean reward per episode: 0.61
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 31000
# Best mean reward: 0.61 - Last mean reward per episode: 0.62
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 32000
# Best mean reward: 0.62 - Last mean reward per episode: 0.60
# Num timesteps: 33000
# Best mean reward: 0.62 - Last mean reward per episode: 0.61
# Num timesteps: 34000
# Best mean reward: 0.62 - Last mean reward per episode: 0.60
# Num timesteps: 35000
# Best mean reward: 0.62 - Last mean reward per episode: 0.61
# Num timesteps: 36000
# Best mean reward: 0.62 - Last mean reward per episode: 0.62
# Num timesteps: 37000
# Best mean reward: 0.62 - Last mean reward per episode: 0.63
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 38000
# Best mean reward: 0.63 - Last mean reward per episode: 0.63
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 39000
# Best mean reward: 0.63 - Last mean reward per episode: 0.64
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 40000
# Best mean reward: 0.64 - Last mean reward per episode: 0.64
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 41000
# Best mean reward: 0.64 - Last mean reward per episode: 0.66
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 42000
# Best mean reward: 0.66 - Last mean reward per episode: 0.69
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 43000
# Best mean reward: 0.69 - Last mean reward per episode: 0.71
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 44000
# Best mean reward: 0.71 - Last mean reward per episode: 0.72
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 45000
# Best mean reward: 0.72 - Last mean reward per episode: 0.71
# Num timesteps: 46000
# Best mean reward: 0.72 - Last mean reward per episode: 0.70
# Num timesteps: 47000
# Best mean reward: 0.72 - Last mean reward per episode: 0.70
# Num timesteps: 48000
# Best mean reward: 0.72 - Last mean reward per episode: 0.71
# Num timesteps: 49000
# Best mean reward: 0.72 - Last mean reward per episode: 0.71
# Num timesteps: 50000
# Best mean reward: 0.72 - Last mean reward per episode: 0.73
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 51000
# Best mean reward: 0.73 - Last mean reward per episode: 0.73
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 52000
# Best mean reward: 0.73 - Last mean reward per episode: 0.74
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 53000
# Best mean reward: 0.74 - Last mean reward per episode: 0.74
# Num timesteps: 54000
# Best mean reward: 0.74 - Last mean reward per episode: 0.74
# Num timesteps: 55000
# Best mean reward: 0.74 - Last mean reward per episode: 0.73
# Num timesteps: 56000
# Best mean reward: 0.74 - Last mean reward per episode: 0.76
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 57000
# Best mean reward: 0.76 - Last mean reward per episode: 0.76
# Num timesteps: 58000
# Best mean reward: 0.76 - Last mean reward per episode: 0.78
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 59000
# Best mean reward: 0.78 - Last mean reward per episode: 0.77
# Num timesteps: 60000
# Best mean reward: 0.78 - Last mean reward per episode: 0.77
# Num timesteps: 61000
# Best mean reward: 0.78 - Last mean reward per episode: 0.78
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 62000
# Best mean reward: 0.78 - Last mean reward per episode: 0.80
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 63000
# Best mean reward: 0.80 - Last mean reward per episode: 0.80
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 64000
# Best mean reward: 0.80 - Last mean reward per episode: 0.80
# Num timesteps: 65000
# Best mean reward: 0.80 - Last mean reward per episode: 0.83
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 66000
# Best mean reward: 0.83 - Last mean reward per episode: 0.85
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 67000
# Best mean reward: 0.85 - Last mean reward per episode: 0.84
# Num timesteps: 68000
# Best mean reward: 0.85 - Last mean reward per episode: 0.83
# Num timesteps: 69000
# Best mean reward: 0.85 - Last mean reward per episode: 0.84
# Num timesteps: 70000
# Best mean reward: 0.85 - Last mean reward per episode: 0.83
# Num timesteps: 71000
# Best mean reward: 0.85 - Last mean reward per episode: 0.84
# Num timesteps: 72000
# Best mean reward: 0.85 - Last mean reward per episode: 0.85
# Num timesteps: 73000
# Best mean reward: 0.85 - Last mean reward per episode: 0.85
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 74000
# Best mean reward: 0.85 - Last mean reward per episode: 0.84
# Num timesteps: 75000
# Best mean reward: 0.85 - Last mean reward per episode: 0.86
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 76000
# Best mean reward: 0.86 - Last mean reward per episode: 0.86
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 77000
# Best mean reward: 0.86 - Last mean reward per episode: 0.86
# Num timesteps: 78000
# Best mean reward: 0.86 - Last mean reward per episode: 0.89
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 79000
# Best mean reward: 0.89 - Last mean reward per episode: 0.89
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 80000
# Best mean reward: 0.89 - Last mean reward per episode: 0.86
# Num timesteps: 81000
# Best mean reward: 0.89 - Last mean reward per episode: 0.86
# Num timesteps: 82000
# Best mean reward: 0.89 - Last mean reward per episode: 0.86
# Num timesteps: 83000
# Best mean reward: 0.89 - Last mean reward per episode: 0.89
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 84000
# Best mean reward: 0.89 - Last mean reward per episode: 0.91
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 85000
# Best mean reward: 0.91 - Last mean reward per episode: 0.93
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 86000
# Best mean reward: 0.93 - Last mean reward per episode: 0.93
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 87000
# Best mean reward: 0.93 - Last mean reward per episode: 0.93
# Num timesteps: 88000
# Best mean reward: 0.93 - Last mean reward per episode: 0.92
# Num timesteps: 89000
# Best mean reward: 0.93 - Last mean reward per episode: 0.91
# Num timesteps: 90000
# Best mean reward: 0.93 - Last mean reward per episode: 0.92
# Num timesteps: 91000
# Best mean reward: 0.93 - Last mean reward per episode: 0.93
# Num timesteps: 92000
# Best mean reward: 0.93 - Last mean reward per episode: 0.95
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 93000
# Best mean reward: 0.95 - Last mean reward per episode: 0.97
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 94000
# Best mean reward: 0.97 - Last mean reward per episode: 0.98
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 95000
# Best mean reward: 0.98 - Last mean reward per episode: 0.99
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 96000
# Best mean reward: 0.99 - Last mean reward per episode: 0.99
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 97000
# Best mean reward: 0.99 - Last mean reward per episode: 0.99
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 98000
# Best mean reward: 0.99 - Last mean reward per episode: 1.00
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 99000
# Best mean reward: 1.00 - Last mean reward per episode: 1.00
# Num timesteps: 100000
# Best mean reward: 1.00 - Last mean reward per episode: 1.01
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 101000
# Best mean reward: 1.01 - Last mean reward per episode: 1.00
# Num timesteps: 102000
# Best mean reward: 1.01 - Last mean reward per episode: 1.01
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 103000
# Best mean reward: 1.01 - Last mean reward per episode: 1.01
# Num timesteps: 104000
# Best mean reward: 1.01 - Last mean reward per episode: 1.01
# Num timesteps: 105000
# Best mean reward: 1.01 - Last mean reward per episode: 1.00
# Num timesteps: 106000
# Best mean reward: 1.01 - Last mean reward per episode: 1.03
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 107000
# Best mean reward: 1.03 - Last mean reward per episode: 1.02
# Num timesteps: 108000
# Best mean reward: 1.03 - Last mean reward per episode: 1.02
# Num timesteps: 109000
# Best mean reward: 1.03 - Last mean reward per episode: 1.04
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 110000
# Best mean reward: 1.04 - Last mean reward per episode: 1.03
# Num timesteps: 111000
# Best mean reward: 1.04 - Last mean reward per episode: 1.01
# Num timesteps: 112000
# Best mean reward: 1.04 - Last mean reward per episode: 1.01
# Num timesteps: 113000
# Best mean reward: 1.04 - Last mean reward per episode: 1.02
# Num timesteps: 114000
# Best mean reward: 1.04 - Last mean reward per episode: 1.03
# Num timesteps: 115000
# Best mean reward: 1.04 - Last mean reward per episode: 1.06
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 116000
# Best mean reward: 1.06 - Last mean reward per episode: 1.05
# Num timesteps: 117000
# Best mean reward: 1.06 - Last mean reward per episode: 1.05
# Num timesteps: 118000
# Best mean reward: 1.06 - Last mean reward per episode: 1.05
# Num timesteps: 119000
# Best mean reward: 1.06 - Last mean reward per episode: 1.05
# Num timesteps: 120000
# Best mean reward: 1.06 - Last mean reward per episode: 1.06
# Num timesteps: 121000
# Best mean reward: 1.06 - Last mean reward per episode: 1.08
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 122000
# Best mean reward: 1.08 - Last mean reward per episode: 1.08
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 123000
# Best mean reward: 1.08 - Last mean reward per episode: 1.04
# Num timesteps: 124000
# Best mean reward: 1.08 - Last mean reward per episode: 1.05
# Num timesteps: 125000
# Best mean reward: 1.08 - Last mean reward per episode: 1.05
# Num timesteps: 126000
# Best mean reward: 1.08 - Last mean reward per episode: 1.06
# Num timesteps: 127000
# Best mean reward: 1.08 - Last mean reward per episode: 1.07
# Num timesteps: 128000
# Best mean reward: 1.08 - Last mean reward per episode: 1.06
# Num timesteps: 129000
# Best mean reward: 1.08 - Last mean reward per episode: 1.09
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 130000
# Best mean reward: 1.09 - Last mean reward per episode: 1.09
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 131000
# Best mean reward: 1.09 - Last mean reward per episode: 1.11
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 132000
# Best mean reward: 1.11 - Last mean reward per episode: 1.13
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 133000
# Best mean reward: 1.13 - Last mean reward per episode: 1.12
# Num timesteps: 134000
# Best mean reward: 1.13 - Last mean reward per episode: 1.12
# Num timesteps: 135000
# Best mean reward: 1.13 - Last mean reward per episode: 1.11
# Num timesteps: 136000
# Best mean reward: 1.13 - Last mean reward per episode: 1.11
# Num timesteps: 137000
# Best mean reward: 1.13 - Last mean reward per episode: 1.10
# Num timesteps: 138000
# Best mean reward: 1.13 - Last mean reward per episode: 1.12
# Num timesteps: 139000
# Best mean reward: 1.13 - Last mean reward per episode: 1.12
# Num timesteps: 140000
# Best mean reward: 1.13 - Last mean reward per episode: 1.11
# Num timesteps: 141000
# Best mean reward: 1.13 - Last mean reward per episode: 1.10
# Num timesteps: 142000
# Best mean reward: 1.13 - Last mean reward per episode: 1.10
# Num timesteps: 143000
# Best mean reward: 1.13 - Last mean reward per episode: 1.10
# Num timesteps: 144000
# Best mean reward: 1.13 - Last mean reward per episode: 1.12
# Num timesteps: 145000
# Best mean reward: 1.13 - Last mean reward per episode: 1.14
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 146000
# Best mean reward: 1.14 - Last mean reward per episode: 1.18
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 147000
# Best mean reward: 1.18 - Last mean reward per episode: 1.18
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 148000
# Best mean reward: 1.18 - Last mean reward per episode: 1.21
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 149000
# Best mean reward: 1.21 - Last mean reward per episode: 1.20
# Num timesteps: 150000
# Best mean reward: 1.21 - Last mean reward per episode: 1.16
# Num timesteps: 151000
# Best mean reward: 1.21 - Last mean reward per episode: 1.17
# Num timesteps: 152000
# Best mean reward: 1.21 - Last mean reward per episode: 1.16
# Num timesteps: 153000
# Best mean reward: 1.21 - Last mean reward per episode: 1.15
# Num timesteps: 154000
# Best mean reward: 1.21 - Last mean reward per episode: 1.17
# Num timesteps: 155000
# Best mean reward: 1.21 - Last mean reward per episode: 1.18
# Num timesteps: 156000
# Best mean reward: 1.21 - Last mean reward per episode: 1.22
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 157000
# Best mean reward: 1.22 - Last mean reward per episode: 1.24
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 158000
# Best mean reward: 1.24 - Last mean reward per episode: 1.23
# Num timesteps: 159000
# Best mean reward: 1.24 - Last mean reward per episode: 1.23
# Num timesteps: 160000
# Best mean reward: 1.24 - Last mean reward per episode: 1.21
# Num timesteps: 161000
# Best mean reward: 1.24 - Last mean reward per episode: 1.21
# Num timesteps: 162000
# Best mean reward: 1.24 - Last mean reward per episode: 1.19
# Num timesteps: 163000
# Best mean reward: 1.24 - Last mean reward per episode: 1.20
# Num timesteps: 164000
# Best mean reward: 1.24 - Last mean reward per episode: 1.20
# Num timesteps: 165000
# Best mean reward: 1.24 - Last mean reward per episode: 1.23
# Num timesteps: 166000
# Best mean reward: 1.24 - Last mean reward per episode: 1.25
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 167000
# Best mean reward: 1.25 - Last mean reward per episode: 1.25
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 168000
# Best mean reward: 1.25 - Last mean reward per episode: 1.25
# Num timesteps: 169000
# Best mean reward: 1.25 - Last mean reward per episode: 1.24
# Num timesteps: 170000
# Best mean reward: 1.25 - Last mean reward per episode: 1.23
# Num timesteps: 171000
# Best mean reward: 1.25 - Last mean reward per episode: 1.23
# Num timesteps: 172000
# Best mean reward: 1.25 - Last mean reward per episode: 1.24
# Num timesteps: 173000
# Best mean reward: 1.25 - Last mean reward per episode: 1.24
# Num timesteps: 174000
# Best mean reward: 1.25 - Last mean reward per episode: 1.23
# Num timesteps: 175000
# Best mean reward: 1.25 - Last mean reward per episode: 1.22
# Num timesteps: 176000
# Best mean reward: 1.25 - Last mean reward per episode: 1.22
# Num timesteps: 177000
# Best mean reward: 1.25 - Last mean reward per episode: 1.22
# Num timesteps: 178000
# Best mean reward: 1.25 - Last mean reward per episode: 1.22
# Num timesteps: 179000
# Best mean reward: 1.25 - Last mean reward per episode: 1.21
# Num timesteps: 180000
# Best mean reward: 1.25 - Last mean reward per episode: 1.20
# Num timesteps: 181000
# Best mean reward: 1.25 - Last mean reward per episode: 1.20
# Num timesteps: 182000
# Best mean reward: 1.25 - Last mean reward per episode: 1.22
# Num timesteps: 183000
# Best mean reward: 1.25 - Last mean reward per episode: 1.24
# Num timesteps: 184000
# Best mean reward: 1.25 - Last mean reward per episode: 1.25
# Num timesteps: 185000
# Best mean reward: 1.25 - Last mean reward per episode: 1.24
# Num timesteps: 186000
# Best mean reward: 1.25 - Last mean reward per episode: 1.23
# Num timesteps: 187000
# Best mean reward: 1.25 - Last mean reward per episode: 1.23
# Num timesteps: 188000
# Best mean reward: 1.25 - Last mean reward per episode: 1.22
# Num timesteps: 189000
# Best mean reward: 1.25 - Last mean reward per episode: 1.23
# Num timesteps: 190000
# Best mean reward: 1.25 - Last mean reward per episode: 1.26
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 191000
# Best mean reward: 1.26 - Last mean reward per episode: 1.27
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 192000
# Best mean reward: 1.27 - Last mean reward per episode: 1.29
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 193000
# Best mean reward: 1.29 - Last mean reward per episode: 1.28
# Num timesteps: 194000
# Best mean reward: 1.29 - Last mean reward per episode: 1.28
# Num timesteps: 195000
# Best mean reward: 1.29 - Last mean reward per episode: 1.28
# Num timesteps: 196000
# Best mean reward: 1.29 - Last mean reward per episode: 1.28
# Num timesteps: 197000
# Best mean reward: 1.29 - Last mean reward per episode: 1.28
# Num timesteps: 198000
# Best mean reward: 1.29 - Last mean reward per episode: 1.27
# Num timesteps: 199000
# Best mean reward: 1.29 - Last mean reward per episode: 1.27
# Num timesteps: 200000
# Best mean reward: 1.29 - Last mean reward per episode: 1.26
# Num timesteps: 201000
# Best mean reward: 1.29 - Last mean reward per episode: 1.26
# Num timesteps: 202000
# Best mean reward: 1.29 - Last mean reward per episode: 1.28
# Num timesteps: 203000
# Best mean reward: 1.29 - Last mean reward per episode: 1.28
# Num timesteps: 204000
# Best mean reward: 1.29 - Last mean reward per episode: 1.28
# Num timesteps: 205000
# Best mean reward: 1.29 - Last mean reward per episode: 1.28
# Num timesteps: 206000
# Best mean reward: 1.29 - Last mean reward per episode: 1.29
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 207000
# Best mean reward: 1.29 - Last mean reward per episode: 1.29
# Num timesteps: 208000
# Best mean reward: 1.29 - Last mean reward per episode: 1.30
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 209000
# Best mean reward: 1.30 - Last mean reward per episode: 1.31
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 210000
# Best mean reward: 1.31 - Last mean reward per episode: 1.29
# Num timesteps: 211000
# Best mean reward: 1.31 - Last mean reward per episode: 1.28
# Num timesteps: 212000
# Best mean reward: 1.31 - Last mean reward per episode: 1.27
# Num timesteps: 213000
# Best mean reward: 1.31 - Last mean reward per episode: 1.28
# Num timesteps: 214000
# Best mean reward: 1.31 - Last mean reward per episode: 1.32
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 215000
# Best mean reward: 1.32 - Last mean reward per episode: 1.33
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 216000
# Best mean reward: 1.33 - Last mean reward per episode: 1.34
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 217000
# Best mean reward: 1.34 - Last mean reward per episode: 1.32
# Num timesteps: 218000
# Best mean reward: 1.34 - Last mean reward per episode: 1.32
# Num timesteps: 219000
# Best mean reward: 1.34 - Last mean reward per episode: 1.30
# Num timesteps: 220000
# Best mean reward: 1.34 - Last mean reward per episode: 1.30
# Num timesteps: 221000
# Best mean reward: 1.34 - Last mean reward per episode: 1.30
# Num timesteps: 222000
# Best mean reward: 1.34 - Last mean reward per episode: 1.30
# Num timesteps: 223000
# Best mean reward: 1.34 - Last mean reward per episode: 1.30
# Num timesteps: 224000
# Best mean reward: 1.34 - Last mean reward per episode: 1.31
# Num timesteps: 225000
# Best mean reward: 1.34 - Last mean reward per episode: 1.31
# Num timesteps: 226000
# Best mean reward: 1.34 - Last mean reward per episode: 1.32
# Num timesteps: 227000
# Best mean reward: 1.34 - Last mean reward per episode: 1.33
# Num timesteps: 228000
# Best mean reward: 1.34 - Last mean reward per episode: 1.33
# Num timesteps: 229000
# Best mean reward: 1.34 - Last mean reward per episode: 1.34
# Num timesteps: 230000
# Best mean reward: 1.34 - Last mean reward per episode: 1.34
# Num timesteps: 231000
# Best mean reward: 1.34 - Last mean reward per episode: 1.34
# Num timesteps: 232000
# Best mean reward: 1.34 - Last mean reward per episode: 1.35
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 233000
# Best mean reward: 1.35 - Last mean reward per episode: 1.35
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 234000
# Best mean reward: 1.35 - Last mean reward per episode: 1.37
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 235000
# Best mean reward: 1.37 - Last mean reward per episode: 1.38
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 236000
# Best mean reward: 1.38 - Last mean reward per episode: 1.39
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 237000
# Best mean reward: 1.39 - Last mean reward per episode: 1.39
# Num timesteps: 238000
# Best mean reward: 1.39 - Last mean reward per episode: 1.38
# Num timesteps: 239000
# Best mean reward: 1.39 - Last mean reward per episode: 1.39
# Num timesteps: 240000
# Best mean reward: 1.39 - Last mean reward per episode: 1.39
# Num timesteps: 241000
# Best mean reward: 1.39 - Last mean reward per episode: 1.39
# Num timesteps: 242000
# Best mean reward: 1.39 - Last mean reward per episode: 1.40
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 243000
# Best mean reward: 1.40 - Last mean reward per episode: 1.41
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 244000
# Best mean reward: 1.41 - Last mean reward per episode: 1.43
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 245000
# Best mean reward: 1.43 - Last mean reward per episode: 1.44
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 246000
# Best mean reward: 1.44 - Last mean reward per episode: 1.43
# Num timesteps: 247000
# Best mean reward: 1.44 - Last mean reward per episode: 1.43
# Num timesteps: 248000
# Best mean reward: 1.44 - Last mean reward per episode: 1.42
# Num timesteps: 249000
# Best mean reward: 1.44 - Last mean reward per episode: 1.42
# Num timesteps: 250000
# Best mean reward: 1.44 - Last mean reward per episode: 1.43
# Num timesteps: 251000
# Best mean reward: 1.44 - Last mean reward per episode: 1.42
# Num timesteps: 252000
# Best mean reward: 1.44 - Last mean reward per episode: 1.43
# Num timesteps: 253000
# Best mean reward: 1.44 - Last mean reward per episode: 1.43
# Num timesteps: 254000
# Best mean reward: 1.44 - Last mean reward per episode: 1.43
# Num timesteps: 255000
# Best mean reward: 1.44 - Last mean reward per episode: 1.42
# Num timesteps: 256000
# Best mean reward: 1.44 - Last mean reward per episode: 1.43
# Num timesteps: 257000
# Best mean reward: 1.44 - Last mean reward per episode: 1.44
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 258000
# Best mean reward: 1.44 - Last mean reward per episode: 1.47
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 259000
# Best mean reward: 1.47 - Last mean reward per episode: 1.50
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 260000
# Best mean reward: 1.50 - Last mean reward per episode: 1.50
# Num timesteps: 261000
# Best mean reward: 1.50 - Last mean reward per episode: 1.50
# Num timesteps: 262000
# Best mean reward: 1.50 - Last mean reward per episode: 1.48
# Num timesteps: 263000
# Best mean reward: 1.50 - Last mean reward per episode: 1.47
# Num timesteps: 264000
# Best mean reward: 1.50 - Last mean reward per episode: 1.48
# Num timesteps: 265000
# Best mean reward: 1.50 - Last mean reward per episode: 1.48
# Num timesteps: 266000
# Best mean reward: 1.50 - Last mean reward per episode: 1.51
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 267000
# Best mean reward: 1.51 - Last mean reward per episode: 1.50
# Num timesteps: 268000
# Best mean reward: 1.51 - Last mean reward per episode: 1.51
# Num timesteps: 269000
# Best mean reward: 1.51 - Last mean reward per episode: 1.49
# Num timesteps: 270000
# Best mean reward: 1.51 - Last mean reward per episode: 1.48
# Num timesteps: 271000
# Best mean reward: 1.51 - Last mean reward per episode: 1.50
# Num timesteps: 272000
# Best mean reward: 1.51 - Last mean reward per episode: 1.50
# Num timesteps: 273000
# Best mean reward: 1.51 - Last mean reward per episode: 1.51
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 274000
# Best mean reward: 1.51 - Last mean reward per episode: 1.51
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 275000
# Best mean reward: 1.51 - Last mean reward per episode: 1.52
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 276000
# Best mean reward: 1.52 - Last mean reward per episode: 1.53
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 277000
# Best mean reward: 1.53 - Last mean reward per episode: 1.54
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 278000
# Best mean reward: 1.54 - Last mean reward per episode: 1.56
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 279000
# Best mean reward: 1.56 - Last mean reward per episode: 1.55
# Num timesteps: 280000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 281000
# Best mean reward: 1.56 - Last mean reward per episode: 1.51
# Num timesteps: 282000
# Best mean reward: 1.56 - Last mean reward per episode: 1.51
# Num timesteps: 283000
# Best mean reward: 1.56 - Last mean reward per episode: 1.50
# Num timesteps: 284000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 285000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 286000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 287000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 288000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 289000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 290000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 291000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 292000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 293000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 294000
# Best mean reward: 1.56 - Last mean reward per episode: 1.51
# Num timesteps: 295000
# Best mean reward: 1.56 - Last mean reward per episode: 1.50
# Num timesteps: 296000
# Best mean reward: 1.56 - Last mean reward per episode: 1.51
# Num timesteps: 297000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 298000
# Best mean reward: 1.56 - Last mean reward per episode: 1.51
# Num timesteps: 299000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 300000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 301000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 302000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 303000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 304000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 305000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 306000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 307000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 308000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 309000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 310000
# Best mean reward: 1.56 - Last mean reward per episode: 1.55
# Num timesteps: 311000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 312000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 313000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 314000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 315000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 316000
# Best mean reward: 1.56 - Last mean reward per episode: 1.51
# Num timesteps: 317000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 318000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 319000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 320000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 321000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 322000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 323000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 324000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 325000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 326000
# Best mean reward: 1.56 - Last mean reward per episode: 1.50
# Num timesteps: 327000
# Best mean reward: 1.56 - Last mean reward per episode: 1.51
# Num timesteps: 328000
# Best mean reward: 1.56 - Last mean reward per episode: 1.51
# Num timesteps: 329000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 330000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 331000
# Best mean reward: 1.56 - Last mean reward per episode: 1.55
# Num timesteps: 332000
# Best mean reward: 1.56 - Last mean reward per episode: 1.56
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 333000
# Best mean reward: 1.56 - Last mean reward per episode: 1.56
# Num timesteps: 334000
# Best mean reward: 1.56 - Last mean reward per episode: 1.56
# Num timesteps: 335000
# Best mean reward: 1.56 - Last mean reward per episode: 1.55
# Num timesteps: 336000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 337000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 338000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 339000
# Best mean reward: 1.56 - Last mean reward per episode: 1.55
# Num timesteps: 340000
# Best mean reward: 1.56 - Last mean reward per episode: 1.55
# Num timesteps: 341000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 342000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 343000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 344000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 345000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 346000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 347000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 348000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 349000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 350000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 351000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 352000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 353000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 354000
# Best mean reward: 1.56 - Last mean reward per episode: 1.50
# Num timesteps: 355000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 356000
# Best mean reward: 1.56 - Last mean reward per episode: 1.50
# Num timesteps: 357000
# Best mean reward: 1.56 - Last mean reward per episode: 1.51
# Num timesteps: 358000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 359000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 360000
# Best mean reward: 1.56 - Last mean reward per episode: 1.52
# Num timesteps: 361000
# Best mean reward: 1.56 - Last mean reward per episode: 1.53
# Num timesteps: 362000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 363000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 364000
# Best mean reward: 1.56 - Last mean reward per episode: 1.54
# Num timesteps: 365000
# Best mean reward: 1.56 - Last mean reward per episode: 1.56
# Num timesteps: 366000
# Best mean reward: 1.56 - Last mean reward per episode: 1.55
# Num timesteps: 367000
# Best mean reward: 1.56 - Last mean reward per episode: 1.56
# Num timesteps: 368000
# Best mean reward: 1.56 - Last mean reward per episode: 1.56
# Num timesteps: 369000
# Best mean reward: 1.56 - Last mean reward per episode: 1.57
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 370000
# Best mean reward: 1.57 - Last mean reward per episode: 1.57
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 371000
# Best mean reward: 1.57 - Last mean reward per episode: 1.57
# Num timesteps: 372000
# Best mean reward: 1.57 - Last mean reward per episode: 1.56
# Num timesteps: 373000
# Best mean reward: 1.57 - Last mean reward per episode: 1.55
# Num timesteps: 374000
# Best mean reward: 1.57 - Last mean reward per episode: 1.53
# Num timesteps: 375000
# Best mean reward: 1.57 - Last mean reward per episode: 1.53
# Num timesteps: 376000
# Best mean reward: 1.57 - Last mean reward per episode: 1.52
# Num timesteps: 377000
# Best mean reward: 1.57 - Last mean reward per episode: 1.50
# Num timesteps: 378000
# Best mean reward: 1.57 - Last mean reward per episode: 1.51
# Num timesteps: 379000
# Best mean reward: 1.57 - Last mean reward per episode: 1.49
# Num timesteps: 380000
# Best mean reward: 1.57 - Last mean reward per episode: 1.48
# Num timesteps: 381000
# Best mean reward: 1.57 - Last mean reward per episode: 1.48
# Num timesteps: 382000
# Best mean reward: 1.57 - Last mean reward per episode: 1.47
# Num timesteps: 383000
# Best mean reward: 1.57 - Last mean reward per episode: 1.47
# Num timesteps: 384000
# Best mean reward: 1.57 - Last mean reward per episode: 1.47
# Num timesteps: 385000
# Best mean reward: 1.57 - Last mean reward per episode: 1.49
# Num timesteps: 386000
# Best mean reward: 1.57 - Last mean reward per episode: 1.49
# Num timesteps: 387000
# Best mean reward: 1.57 - Last mean reward per episode: 1.51
# Num timesteps: 388000
# Best mean reward: 1.57 - Last mean reward per episode: 1.52
# Num timesteps: 389000
# Best mean reward: 1.57 - Last mean reward per episode: 1.52
# Num timesteps: 390000
# Best mean reward: 1.57 - Last mean reward per episode: 1.53
# Num timesteps: 391000
# Best mean reward: 1.57 - Last mean reward per episode: 1.51
# Num timesteps: 392000
# Best mean reward: 1.57 - Last mean reward per episode: 1.52
# Num timesteps: 393000
# Best mean reward: 1.57 - Last mean reward per episode: 1.53
# Num timesteps: 394000
# Best mean reward: 1.57 - Last mean reward per episode: 1.53
# Num timesteps: 395000
# Best mean reward: 1.57 - Last mean reward per episode: 1.53
# Num timesteps: 396000
# Best mean reward: 1.57 - Last mean reward per episode: 1.54
# Num timesteps: 397000
# Best mean reward: 1.57 - Last mean reward per episode: 1.55
# Num timesteps: 398000
# Best mean reward: 1.57 - Last mean reward per episode: 1.56
# Num timesteps: 399000
# Best mean reward: 1.57 - Last mean reward per episode: 1.57
# Num timesteps: 400000
# Best mean reward: 1.57 - Last mean reward per episode: 1.57
# Num timesteps: 401000
# Best mean reward: 1.57 - Last mean reward per episode: 1.56
# Num timesteps: 402000
# Best mean reward: 1.57 - Last mean reward per episode: 1.57
# Num timesteps: 403000
# Best mean reward: 1.57 - Last mean reward per episode: 1.57
# Num timesteps: 404000
# Best mean reward: 1.57 - Last mean reward per episode: 1.57
# Num timesteps: 405000
# Best mean reward: 1.57 - Last mean reward per episode: 1.57
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 406000
# Best mean reward: 1.57 - Last mean reward per episode: 1.57
# Num timesteps: 407000
# Best mean reward: 1.57 - Last mean reward per episode: 1.57
# Num timesteps: 408000
# Best mean reward: 1.57 - Last mean reward per episode: 1.57
# Num timesteps: 409000
# Best mean reward: 1.57 - Last mean reward per episode: 1.57
# Num timesteps: 410000
# Best mean reward: 1.57 - Last mean reward per episode: 1.57
# Num timesteps: 411000
# Best mean reward: 1.57 - Last mean reward per episode: 1.58
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 412000
# Best mean reward: 1.58 - Last mean reward per episode: 1.58
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 413000
# Best mean reward: 1.58 - Last mean reward per episode: 1.59
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 414000
# Best mean reward: 1.59 - Last mean reward per episode: 1.58
# Num timesteps: 415000
# Best mean reward: 1.59 - Last mean reward per episode: 1.59
# Num timesteps: 416000
# Best mean reward: 1.59 - Last mean reward per episode: 1.57
# Num timesteps: 417000
# Best mean reward: 1.59 - Last mean reward per episode: 1.57
# Num timesteps: 418000
# Best mean reward: 1.59 - Last mean reward per episode: 1.58
# Num timesteps: 419000
# Best mean reward: 1.59 - Last mean reward per episode: 1.58
# Num timesteps: 420000
# Best mean reward: 1.59 - Last mean reward per episode: 1.57
# Num timesteps: 421000
# Best mean reward: 1.59 - Last mean reward per episode: 1.57
# Num timesteps: 422000
# Best mean reward: 1.59 - Last mean reward per episode: 1.56
# Num timesteps: 423000
# Best mean reward: 1.59 - Last mean reward per episode: 1.56
# Num timesteps: 424000
# Best mean reward: 1.59 - Last mean reward per episode: 1.56
# Num timesteps: 425000
# Best mean reward: 1.59 - Last mean reward per episode: 1.56
# Num timesteps: 426000
# Best mean reward: 1.59 - Last mean reward per episode: 1.57
# Num timesteps: 427000
# Best mean reward: 1.59 - Last mean reward per episode: 1.57
# Num timesteps: 428000
# Best mean reward: 1.59 - Last mean reward per episode: 1.60
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 429000
# Best mean reward: 1.60 - Last mean reward per episode: 1.59
# Num timesteps: 430000
# Best mean reward: 1.60 - Last mean reward per episode: 1.58
# Num timesteps: 431000
# Best mean reward: 1.60 - Last mean reward per episode: 1.56
# Num timesteps: 432000
# Best mean reward: 1.60 - Last mean reward per episode: 1.54
# Num timesteps: 433000
# Best mean reward: 1.60 - Last mean reward per episode: 1.55
# Num timesteps: 434000
# Best mean reward: 1.60 - Last mean reward per episode: 1.55
# Num timesteps: 435000
# Best mean reward: 1.60 - Last mean reward per episode: 1.54
# Num timesteps: 436000
# Best mean reward: 1.60 - Last mean reward per episode: 1.54
# Num timesteps: 437000
# Best mean reward: 1.60 - Last mean reward per episode: 1.54
# Num timesteps: 438000
# Best mean reward: 1.60 - Last mean reward per episode: 1.53
# Num timesteps: 439000
# Best mean reward: 1.60 - Last mean reward per episode: 1.54
# Num timesteps: 440000
# Best mean reward: 1.60 - Last mean reward per episode: 1.54
# Num timesteps: 441000
# Best mean reward: 1.60 - Last mean reward per episode: 1.53
# Num timesteps: 442000
# Best mean reward: 1.60 - Last mean reward per episode: 1.54
# Num timesteps: 443000
# Best mean reward: 1.60 - Last mean reward per episode: 1.56
# Num timesteps: 444000
# Best mean reward: 1.60 - Last mean reward per episode: 1.55
# Num timesteps: 445000
# Best mean reward: 1.60 - Last mean reward per episode: 1.55
# Num timesteps: 446000
# Best mean reward: 1.60 - Last mean reward per episode: 1.56
# Num timesteps: 447000
# Best mean reward: 1.60 - Last mean reward per episode: 1.57
# Num timesteps: 448000
# Best mean reward: 1.60 - Last mean reward per episode: 1.58
# Num timesteps: 449000
# Best mean reward: 1.60 - Last mean reward per episode: 1.59
# Num timesteps: 450000
# Best mean reward: 1.60 - Last mean reward per episode: 1.58
# Num timesteps: 451000
# Best mean reward: 1.60 - Last mean reward per episode: 1.57
# Num timesteps: 452000
# Best mean reward: 1.60 - Last mean reward per episode: 1.56
# Num timesteps: 453000
# Best mean reward: 1.60 - Last mean reward per episode: 1.55
# Num timesteps: 454000
# Best mean reward: 1.60 - Last mean reward per episode: 1.56
# Num timesteps: 455000
# Best mean reward: 1.60 - Last mean reward per episode: 1.57
# Num timesteps: 456000
# Best mean reward: 1.60 - Last mean reward per episode: 1.60
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 457000
# Best mean reward: 1.60 - Last mean reward per episode: 1.59
# Num timesteps: 458000
# Best mean reward: 1.60 - Last mean reward per episode: 1.59
# Num timesteps: 459000
# Best mean reward: 1.60 - Last mean reward per episode: 1.58
# Num timesteps: 460000
# Best mean reward: 1.60 - Last mean reward per episode: 1.58
# Num timesteps: 461000
# Best mean reward: 1.60 - Last mean reward per episode: 1.57
# Num timesteps: 462000
# Best mean reward: 1.60 - Last mean reward per episode: 1.58
# Num timesteps: 463000
# Best mean reward: 1.60 - Last mean reward per episode: 1.58
# Num timesteps: 464000
# Best mean reward: 1.60 - Last mean reward per episode: 1.56
# Num timesteps: 465000
# Best mean reward: 1.60 - Last mean reward per episode: 1.57
# Num timesteps: 466000
# Best mean reward: 1.60 - Last mean reward per episode: 1.57
# Num timesteps: 467000
# Best mean reward: 1.60 - Last mean reward per episode: 1.56
# Num timesteps: 468000
# Best mean reward: 1.60 - Last mean reward per episode: 1.56
# Num timesteps: 469000
# Best mean reward: 1.60 - Last mean reward per episode: 1.57
# Num timesteps: 470000
# Best mean reward: 1.60 - Last mean reward per episode: 1.57
# Num timesteps: 471000
# Best mean reward: 1.60 - Last mean reward per episode: 1.58
# Num timesteps: 472000
# Best mean reward: 1.60 - Last mean reward per episode: 1.59
# Num timesteps: 473000
# Best mean reward: 1.60 - Last mean reward per episode: 1.61
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 474000
# Best mean reward: 1.61 - Last mean reward per episode: 1.60
# Num timesteps: 475000
# Best mean reward: 1.61 - Last mean reward per episode: 1.61
# Num timesteps: 476000
# Best mean reward: 1.61 - Last mean reward per episode: 1.60
# Num timesteps: 477000
# Best mean reward: 1.61 - Last mean reward per episode: 1.59
# Num timesteps: 478000
# Best mean reward: 1.61 - Last mean reward per episode: 1.60
# Num timesteps: 479000
# Best mean reward: 1.61 - Last mean reward per episode: 1.62
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 480000
# Best mean reward: 1.62 - Last mean reward per episode: 1.63
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 481000
# Best mean reward: 1.63 - Last mean reward per episode: 1.64
# Saving new best model to /tmp/gym6_2bc/best_model.zip
# Num timesteps: 482000
# Best mean reward: 1.64 - Last mean reward per episode: 1.63
# Num timesteps: 483000
# Best mean reward: 1.64 - Last mean reward per episode: 1.62
# Num timesteps: 484000
# Best mean reward: 1.64 - Last mean reward per episode: 1.63
# Num timesteps: 485000
# Best mean reward: 1.64 - Last mean reward per episode: 1.62
# Num timesteps: 486000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 487000
# Best mean reward: 1.64 - Last mean reward per episode: 1.60
# Num timesteps: 488000
# Best mean reward: 1.64 - Last mean reward per episode: 1.60
# Num timesteps: 489000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 490000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 491000
# Best mean reward: 1.64 - Last mean reward per episode: 1.63
# Num timesteps: 492000
# Best mean reward: 1.64 - Last mean reward per episode: 1.62
# Num timesteps: 493000
# Best mean reward: 1.64 - Last mean reward per episode: 1.63
# Num timesteps: 494000
# Best mean reward: 1.64 - Last mean reward per episode: 1.60
# Num timesteps: 495000
# Best mean reward: 1.64 - Last mean reward per episode: 1.60
# Num timesteps: 496000
# Best mean reward: 1.64 - Last mean reward per episode: 1.59
# Num timesteps: 497000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 498000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 499000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 500000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 501000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 502000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 503000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 504000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 505000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 506000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 507000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 508000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 509000
# ...
# Num timesteps: 807000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 808000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 809000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 810000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 811000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 812000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 813000
# Best mean reward: 1.64 - Last mean reward per episode: 1.51
# Num timesteps: 814000
# Best mean reward: 1.64 - Last mean reward per episode: 1.50
# Num timesteps: 815000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 816000
# Best mean reward: 1.64 - Last mean reward per episode: 1.51
# Num timesteps: 817000
# Best mean reward: 1.64 - Last mean reward per episode: 1.50
# Num timesteps: 818000
# Best mean reward: 1.64 - Last mean reward per episode: 1.51
# Num timesteps: 819000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 820000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 821000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 822000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 823000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 824000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 825000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 826000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 827000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 828000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 829000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 830000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 831000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 832000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 833000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 834000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 835000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 836000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 837000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 838000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 839000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 840000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 841000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 842000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 843000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 844000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 845000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 846000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 847000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 848000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 849000
# Best mean reward: 1.64 - Last mean reward per episode: 1.59
# Num timesteps: 850000
# Best mean reward: 1.64 - Last mean reward per episode: 1.59
# Num timesteps: 851000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 852000
# Best mean reward: 1.64 - Last mean reward per episode: 1.59
# Num timesteps: 853000
# Best mean reward: 1.64 - Last mean reward per episode: 1.59
# Num timesteps: 854000
# Best mean reward: 1.64 - Last mean reward per episode: 1.60
# Num timesteps: 855000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 856000
# Best mean reward: 1.64 - Last mean reward per episode: 1.63
# Num timesteps: 857000
# Best mean reward: 1.64 - Last mean reward per episode: 1.62
# Num timesteps: 858000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 859000
# Best mean reward: 1.64 - Last mean reward per episode: 1.60
# Num timesteps: 860000
# Best mean reward: 1.64 - Last mean reward per episode: 1.59
# Num timesteps: 861000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 862000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 863000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 864000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 865000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 866000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 867000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 868000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 869000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 870000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 871000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 872000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 873000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 874000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 875000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 876000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 877000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 878000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 879000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 880000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 881000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 882000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 883000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 884000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 885000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 886000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 887000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 888000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 889000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 890000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 891000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 892000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 893000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 894000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 895000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 896000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 897000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 898000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 899000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 900000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 901000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 902000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 903000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 904000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 905000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 906000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 907000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 908000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 909000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 910000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 911000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 912000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 913000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 914000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 915000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 916000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 917000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 918000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 919000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 920000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 921000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 922000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 923000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 924000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 925000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 926000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 927000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 928000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 929000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 930000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 931000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 932000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 933000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 934000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 935000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 936000
# Best mean reward: 1.64 - Last mean reward per episode: 1.59
# Num timesteps: 937000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 938000
# Best mean reward: 1.64 - Last mean reward per episode: 1.62
# Num timesteps: 939000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 940000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 941000
# Best mean reward: 1.64 - Last mean reward per episode: 1.60
# Num timesteps: 942000
# Best mean reward: 1.64 - Last mean reward per episode: 1.59
# Num timesteps: 943000
# Best mean reward: 1.64 - Last mean reward per episode: 1.60
# Num timesteps: 944000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 945000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 946000
# Best mean reward: 1.64 - Last mean reward per episode: 1.62
# Num timesteps: 947000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 948000
# Best mean reward: 1.64 - Last mean reward per episode: 1.62
# Num timesteps: 949000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 950000
# Best mean reward: 1.64 - Last mean reward per episode: 1.63
# Num timesteps: 951000
# Best mean reward: 1.64 - Last mean reward per episode: 1.63
# Num timesteps: 952000
# Best mean reward: 1.64 - Last mean reward per episode: 1.62
# Num timesteps: 953000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 954000
# Best mean reward: 1.64 - Last mean reward per episode: 1.59
# Num timesteps: 955000
# Best mean reward: 1.64 - Last mean reward per episode: 1.60
# Num timesteps: 956000
# Best mean reward: 1.64 - Last mean reward per episode: 1.59
# Num timesteps: 957000
# Best mean reward: 1.64 - Last mean reward per episode: 1.59
# Num timesteps: 958000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 959000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 960000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 961000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 962000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 963000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 964000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 965000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 966000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 967000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 968000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 969000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 970000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 971000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 972000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 973000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 974000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 975000
# Best mean reward: 1.64 - Last mean reward per episode: 1.59
# Num timesteps: 976000
# Best mean reward: 1.64 - Last mean reward per episode: 1.61
# Num timesteps: 977000
# Best mean reward: 1.64 - Last mean reward per episode: 1.59
# Num timesteps: 978000
# Best mean reward: 1.64 - Last mean reward per episode: 1.58
# Num timesteps: 979000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 980000
# Best mean reward: 1.64 - Last mean reward per episode: 1.56
# Num timesteps: 981000
# Best mean reward: 1.64 - Last mean reward per episode: 1.57
# Num timesteps: 982000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 983000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 984000
# Best mean reward: 1.64 - Last mean reward per episode: 1.55
# Num timesteps: 985000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 986000
# Best mean reward: 1.64 - Last mean reward per episode: 1.54
# Num timesteps: 987000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 988000
# Best mean reward: 1.64 - Last mean reward per episode: 1.53
# Num timesteps: 989000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 990000
# Best mean reward: 1.64 - Last mean reward per episode: 1.52
# Num timesteps: 991000
# Best mean reward: 1.64 - Last mean reward per episode: 1.50
# Num timesteps: 992000
# Best mean reward: 1.64 - Last mean reward per episode: 1.49
# Num timesteps: 993000
# Best mean reward: 1.64 - Last mean reward per episode: 1.48
# Num timesteps: 994000
# Best mean reward: 1.64 - Last mean reward per episode: 1.47
# Num timesteps: 995000
# Best mean reward: 1.64 - Last mean reward per episode: 1.47
# Num timesteps: 996000
# Best mean reward: 1.64 - Last mean reward per episode: 1.48
# Num timesteps: 997000
# Best mean reward: 1.64 - Last mean reward per episode: 1.46
# Num timesteps: 998000
# Best mean reward: 1.64 - Last mean reward per episode: 1.45
# Num timesteps: 999000
# Best mean reward: 1.64 - Last mean reward per episode: 1.44
# Num timesteps: 1000000
# Best mean reward: 1.64 - Last mean reward per episode: 1.42
# Num timesteps: 1001000
# Best mean reward: 1.64 - Last mean reward per episode: 1.42

# %%
print('Total time taken: {} min'.format((end - start)/60))
# Out:
# Total time taken: 19.33700463374456 min

# %% [markdown]
# ### Inference

# %%
env.M.flag_=True
# env.M.flag_=False
obs=env.reset()
obs=obs[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.M to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.M` for environment variables or `env.get_wrapper_attr('M')` that will search the reminding wrappers.
#   logger.warn(

# %%
i=0
while i<1000:
    action, _states = model.predict(obs)
    obs, rewards, dones, _, info = env.step(int(action))
    if dones:
        break
    i+=1

# %%
env.args = get_args(*mbb_beam(rd=env.rd))
t__, c__ = fast_stopt(env.args, env.x)
t__
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.rd to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.rd` for environment variables or `env.get_wrapper_attr('rd')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.x to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.x` for environment variables or `env.get_wrapper_attr('x')` that will search the reminding wrappers.
#   logger.warn(
# 39.5507999407945

# %%
c__
# Out:
# 0.527825

# %%
print(i)
# Out:
# 36

# %%
env.render()
# Out:
# Final Cantilever beam design:

# %%
results_plotter.plot_results([log_dir], ts, results_plotter.X_TIMESTEPS, "CantileverEnv")

# %%
env.M.flag_=False
obs=env.reset()
obs=obs[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.M to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.M` for environment variables or `env.get_wrapper_attr('M')` that will search the reminding wrappers.
#   logger.warn(

# %%
# Load the agent
model_best = PPO.load(log_dir + "best_model.zip",env=env)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.render_mode to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.render_mode` for environment variables or `env.get_wrapper_attr('render_mode')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:77: UserWarning: The `render_mode` attribute is not defined in your environment. It will be set to None.
#   warnings.warn("The `render_mode` attribute is not defined in your environment. It will be set to None.")

# %%
i=0
while i<1000:
    action, _states = model_best.predict(obs)
    
    obs, rewards, dones, _,info = env.step(int(action))
    if dones:
        break
    i+=1

# %%
i
# Out:
# 36

# %%
env.render()
# Out:
# Final Cantilever beam design:

# %%
env.args = get_args(*mbb_beam(rd=env.rd))
t__, c__ = fast_stopt(env.args, env.x)
t__
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.rd to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.rd` for environment variables or `env.get_wrapper_attr('rd')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.x to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.x` for environment variables or `env.get_wrapper_attr('x')` that will search the reminding wrappers.
#   logger.warn(
# 19.91666566428479

# %%
c__
# Out:
# 0.6667000000000001
