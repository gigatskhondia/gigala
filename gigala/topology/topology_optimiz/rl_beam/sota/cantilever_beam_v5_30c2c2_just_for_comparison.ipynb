# %%
import time
import os
import random
import numpy as np                                                
import matplotlib.pyplot as plt                                   
import autograd, autograd.core, autograd.extend, autograd.tracer  
import autograd.numpy as anp      
import scipy, scipy.ndimage, scipy.sparse, scipy.sparse.linalg    
                                                     
import gym
# from gym import spaces
from gymnasium import spaces


from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common import results_plotter

# %% [markdown]
# The below code is my RL extension to and rework of https://www.researchgate.net/publication/360698153_A_Tutorial_on_Structural_Optimization

# %%
x0, y0 = 10, 10

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d
    
def get_args(normals, forces, density=1e-4):  # Manage the problem setup parameters
    width = normals.shape[0] - 1
    height = normals.shape[1] - 1
    fixdofs = np.flatnonzero(normals.ravel())
    alldofs = np.arange(2 * (width + 1) * (height + 1))
    freedofs = np.sort(list(set(alldofs) - set(fixdofs)))
    params = {
      # material properties
      'young': 1, 'young_min': 1e-9, 'poisson': 0.3, 'g': 0,
      # constraints
      'density': density, 'xmin': 0.001, 'xmax': 1.0,
      # input parameters
      'nelx': width, 'nely': height, 'mask': 1, 'penal': 3.0, 'filter_width': 1,
      'freedofs': freedofs, 'fixdofs': fixdofs, 'forces': forces.ravel(),
      # optimization parameters
      'opt_steps': 80, 'print_every': 10}
    return ObjectView(params)

def mbb_beam(width=y0, height=x0, density=1e-4, y=1, x=0, rd=-1):  # textbook beam example
    normals = np.zeros((width + 1, height + 1, 2))
    normals[0, 0, x] = 1
    normals[0, 0, y] = 1
    normals[0, -1, x] = 1
    normals[0, -1, y] = 1
    forces = np.zeros((width + 1, height + 1, 2))
    forces[-1, rd, y] = -1
    return normals, forces, density

# %%
def young_modulus(x, e_0, e_min, p=3):
    return e_min + x ** p * (e_0 - e_min)

def physical_density(x, args, volume_contraint=False, use_filter=True):
    x = args.mask * x.reshape(args.nely, args.nelx)  # reshape from 1D to 2D
    return gaussian_filter(x, args.filter_width) if use_filter else x  # maybe filter

def mean_density(x, args, volume_contraint=False, use_filter=True):
    return anp.mean(physical_density(x, args, volume_contraint, use_filter)) / anp.mean(args.mask)

# %%
def objective(x, args, volume_contraint=False, use_filter=True):
    kwargs = dict(penal=args.penal, e_min=args.young_min, e_0=args.young)
    x_phys = physical_density(x, args, volume_contraint=volume_contraint, use_filter=use_filter)
    ke     = get_stiffness_matrix(args.young, args.poisson)  # stiffness matrix
    u      = displace(x_phys, ke, args.forces, args.freedofs, args.fixdofs, **kwargs)
    c      = compliance(x_phys, u, ke, **kwargs)
    return c

# %%
@autograd.extend.primitive
def gaussian_filter(x, width): # 2D gaussian blur/filter
    return scipy.ndimage.gaussian_filter(x, width, mode='reflect')

def _gaussian_filter_vjp(ans, x, width): # gives the gradient of orig. function w.r.t. x
    del ans, x  # unused
    return lambda g: gaussian_filter(g, width)
autograd.extend.defvjp(gaussian_filter, _gaussian_filter_vjp)

# %%
def compliance(x_phys, u, ke, *, penal=3, e_min=1e-9, e_0=1):
    nely, nelx = x_phys.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords for the index map

    n1 = (nely+1)*(elx+0) + (ely+0)  # nodes
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    all_ixs = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    u_selected = u[all_ixs]  # select from u matrix

    ke_u = anp.einsum('ij,jkl->ikl', ke, u_selected)  # compute x^penal * U.T @ ke @ U
    ce = anp.einsum('ijk,ijk->jk', u_selected, ke_u)
    C = young_modulus(x_phys, e_0, e_min, p=penal) * ce.T
    return anp.sum(C)

def get_stiffness_matrix(e, nu):  # e=young's modulus, nu=poisson coefficient
    k = anp.array([1/2-nu/6, 1/8+nu/8, -1/4-nu/12, -1/8+3*nu/8,
                -1/4+nu/12, -1/8-nu/8, nu/6, 1/8-3*nu/8])
    return e/(1-nu**2)*anp.array([[k[0], k[1], k[2], k[3], k[4], k[5], k[6], k[7]],
                               [k[1], k[0], k[7], k[6], k[5], k[4], k[3], k[2]],
                               [k[2], k[7], k[0], k[5], k[6], k[3], k[4], k[1]],
                               [k[3], k[6], k[5], k[0], k[7], k[2], k[1], k[4]],
                               [k[4], k[5], k[6], k[7], k[0], k[1], k[2], k[3]],
                               [k[5], k[4], k[3], k[2], k[1], k[0], k[7], k[6]],
                               [k[6], k[3], k[4], k[1], k[2], k[7], k[0], k[5]],
                               [k[7], k[2], k[1], k[4], k[3], k[6], k[5], k[0]]])

# %%
def get_k(stiffness, ke):
    # Constructs sparse stiffness matrix k (used in the displace fn)
    # First, get position of the nodes of each element in the stiffness matrix
    nely, nelx = stiffness.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords
    ely, elx = ely.reshape(-1, 1), elx.reshape(-1, 1)

    n1 = (nely+1)*(elx+0) + (ely+0)
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    edof = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    edof = edof.T[0]
    x_list = anp.repeat(edof, 8)  # flat list pointer of each node in an element
    y_list = anp.tile(edof, 8).flatten()  # flat list pointer of each node in elem

    # make the global stiffness matrix K
    kd = stiffness.T.reshape(nelx*nely, 1, 1)
    value_list = (kd * anp.tile(ke, kd.shape)).flatten()
    return value_list, y_list, x_list

def displace(x_phys, ke, forces, freedofs, fixdofs, *, penal=3, e_min=1e-9, e_0=1):
    # Displaces the load x using finite element techniques (solve_coo=most of runtime)
    stiffness = young_modulus(x_phys, e_0, e_min, p=penal)
    k_entries, k_ylist, k_xlist = get_k(stiffness, ke)

    index_map, keep, indices = _get_dof_indices(freedofs, fixdofs, k_ylist, k_xlist)

    u_nonzero = solve_coo(k_entries[keep], indices, forces[freedofs], sym_pos=True)
    u_values = anp.concatenate([u_nonzero, anp.zeros(len(fixdofs))])
    return u_values[index_map]

# %%
def _get_dof_indices(freedofs, fixdofs, k_xlist, k_ylist):
    index_map = inverse_permutation(anp.concatenate([freedofs, fixdofs]))
    keep = anp.isin(k_xlist, freedofs) & anp.isin(k_ylist, freedofs)
    # Now we index an indexing array that is being indexed by the indices of k
    i = index_map[k_ylist][keep]
    j = index_map[k_xlist][keep]
    return index_map, keep, anp.stack([i, j])

def inverse_permutation(indices):  # reverses an index operation
    inverse_perm = np.zeros(len(indices), dtype=anp.int64)
    inverse_perm[indices] = np.arange(len(indices), dtype=anp.int64)
    return inverse_perm

# %%
def _get_solver(a_entries, a_indices, size, sym_pos):
    # a is (usu.) symmetric positive; could solve 2x faster w/sksparse.cholmod.cholesky(a).solve_A
    a = scipy.sparse.coo_matrix((a_entries, a_indices), shape=(size,)*2).tocsc()
    return scipy.sparse.linalg.splu(a).solve

@autograd.primitive
def solve_coo(a_entries, a_indices, b, sym_pos=False):
    solver = _get_solver(a_entries, a_indices, b.size, sym_pos)
    return solver(b)

def grad_solve_coo_entries(ans, a_entries, a_indices, b, sym_pos=False):
    def jvp(grad_ans):
        lambda_ = solve_coo(a_entries, a_indices if sym_pos else a_indices[::-1],
                            grad_ans, sym_pos)
        i, j = a_indices
        return -lambda_[i] * ans[j]
    return jvp

autograd.extend.defvjp(solve_coo, grad_solve_coo_entries,
                       lambda: print('err: gradient undefined'),
                       lambda: print('err: gradient not implemented'))

# %%
class Model:
    def __init__(self, x):
        self.flag_ = True
#         self.flag_ = False
        self.n, self.m = x.shape
        self.actions_dic={} 
    
        k=0
        for i in range(self.n):
            for j in range(self.m):
                self.actions_dic[k]=(i,j)
                k+=1
        
    def action_space_(self, action, X):
        x,y=self.actions_dic[action]
        X[x][y]=1
        
    def draw(self,X):  
        plt.figure(dpi=50) 
        print('\nFinal Cantilever beam design:')
        plt.imshow(X) 
        plt.show()

# %%
def fast_stopt(args, x):

    reshape = lambda x: x.reshape(args.nely, args.nelx)
    objective_fn = lambda x: objective(reshape(x), args)
#     constraint = lambda params: mean_density(reshape(params), args) - args.density
    constraint = lambda params: mean_density(reshape(params), args) 
    value = objective_fn(x)
    const = constraint(x)
    return value, const

# %%
class CantileverEnv(gym.Env):
    
    metadata = {"render.modes": ["human"]}

    def __init__(self):
        super().__init__()
        
        
        self.rd=0
        self.args = get_args(*mbb_beam(rd=self.rd))
        
        DIM=self.args.nelx*self.args.nely
        N_DISCRETE_ACTIONS=self.args.nelx*self.args.nely
        
        self.action_space = spaces.Discrete(N_DISCRETE_ACTIONS)
        self.observation_space = spaces.Box(low=np.array([-1e10 for x in range(DIM)]),
                                            high=np.array([1e10 for y in range(DIM)]),
                                            shape=(DIM,),
                                           dtype=np.float64)
        
 
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density 
    
        self.M=Model(self.x)
        
        self.reward=0
        self.step_=0
        self.needs_reset = True
        
    def step(self, action):
        
        self.args = get_args(*mbb_beam(rd=self.rd))
        
        self.M.action_space_(action, self.x)
        
        
        self.step_+=1
        
        
#         const1=np.sum(self.x)/(x0*y0)
        
        
        tmp, const = fast_stopt(self.args, self.x)

        a1=1/tmp
        a2=1/const

        self.reward = 2*a1*a2/(a1+a2) 
        
       
        done=False
                  
        if self.step_>self.M.n*self.M.m:
            done=True
            
        if const>0.7:
#             self.reward-=1
            done=True
    
#         if done:
#             tmp, const = fast_stopt(self.args, self.x)

#             a1=1/tmp
#             a2=1/const
        
#             self.reward = 2*a1*a2/(a1+a2) 
            
        if self.needs_reset:
            raise RuntimeError("Tried to step environment that needs reset")
            
        if done:
            self.needs_reset = True
                         
      
        return self.x.reshape(self.x.shape[0]*self.x.shape[1]), self.reward, done,False, dict()

    def reset(self,seed=0):
        
        if not self.M.flag_:
            self.rd=random.choice([0,2,-2])
        else:
            self.rd=-1
           
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density 

        self.reward=0
        self.needs_reset = False
        self.step_=0

        return self.x.reshape(self.x.shape[0]*self.x.shape[1]),{}

    def render(self, mode="human"):
        self.M.draw(self.x)    

    def close(self):
        pass

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %%
# ts=5e6
ts=3e6

# %%
# Create log dir
log_dir = "/tmp/gym6_2bc01b/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = CantileverEnv()
# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)
check_env(env)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.render_mode to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.render_mode` for environment variables or `env.get_wrapper_attr('render_mode')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:77: UserWarning: The `render_mode` attribute is not defined in your environment. It will be set to None.
#   warnings.warn("The `render_mode` attribute is not defined in your environment. It will be set to None.")

# %%
# callback = SaveOnBestTrainingRewardCallback(check_freq=5000, log_dir=log_dir)
callback = SaveOnBestTrainingRewardCallback(check_freq=10_000, log_dir=log_dir)

# %%
start=time.time()
model = PPO("MlpPolicy", env).learn(total_timesteps=ts, callback=callback)
end=time.time()
# Out:
# Num timesteps: 10000
# Best mean reward: -inf - Last mean reward per episode: 0.56
# Saving new best model to /tmp/gym6_2bc01b/best_model.zip
# Num timesteps: 20000
# Best mean reward: 0.56 - Last mean reward per episode: 0.74
# Saving new best model to /tmp/gym6_2bc01b/best_model.zip
# Num timesteps: 30000
# Best mean reward: 0.74 - Last mean reward per episode: 1.04
# Saving new best model to /tmp/gym6_2bc01b/best_model.zip
# Num timesteps: 40000
# Best mean reward: 1.04 - Last mean reward per episode: 1.03
# Num timesteps: 50000
# Best mean reward: 1.04 - Last mean reward per episode: 1.09
# Saving new best model to /tmp/gym6_2bc01b/best_model.zip
# Num timesteps: 60000
# Best mean reward: 1.09 - Last mean reward per episode: 1.08
# Num timesteps: 70000
# Best mean reward: 1.09 - Last mean reward per episode: 1.07
# Num timesteps: 80000
# Best mean reward: 1.09 - Last mean reward per episode: 1.09
# Num timesteps: 90000
# Best mean reward: 1.09 - Last mean reward per episode: 1.13
# Saving new best model to /tmp/gym6_2bc01b/best_model.zip
# Num timesteps: 100000
# Best mean reward: 1.13 - Last mean reward per episode: 1.03
# Num timesteps: 110000
# Best mean reward: 1.13 - Last mean reward per episode: 0.97
# Num timesteps: 120000
# Best mean reward: 1.13 - Last mean reward per episode: 0.98
# Num timesteps: 130000
# Best mean reward: 1.13 - Last mean reward per episode: 0.97
# Num timesteps: 140000
# Best mean reward: 1.13 - Last mean reward per episode: 0.93
# Num timesteps: 150000
# Best mean reward: 1.13 - Last mean reward per episode: 0.92
# Num timesteps: 160000
# Best mean reward: 1.13 - Last mean reward per episode: 0.81
# Num timesteps: 170000
# Best mean reward: 1.13 - Last mean reward per episode: 0.80
# Num timesteps: 180000
# Best mean reward: 1.13 - Last mean reward per episode: 0.79
# Num timesteps: 190000
# Best mean reward: 1.13 - Last mean reward per episode: 0.69
# Num timesteps: 200000
# Best mean reward: 1.13 - Last mean reward per episode: 0.71
# Num timesteps: 210000
# Best mean reward: 1.13 - Last mean reward per episode: 0.75
# Num timesteps: 220000
# Best mean reward: 1.13 - Last mean reward per episode: 0.73
# Num timesteps: 230000
# Best mean reward: 1.13 - Last mean reward per episode: 0.69
# Num timesteps: 240000
# Best mean reward: 1.13 - Last mean reward per episode: 0.70
# Num timesteps: 250000
# Best mean reward: 1.13 - Last mean reward per episode: 0.72
# Num timesteps: 260000
# Best mean reward: 1.13 - Last mean reward per episode: 0.68
# Num timesteps: 270000
# Best mean reward: 1.13 - Last mean reward per episode: 0.67
# Num timesteps: 280000
# Best mean reward: 1.13 - Last mean reward per episode: 0.68
# Num timesteps: 290000
# Best mean reward: 1.13 - Last mean reward per episode: 0.65
# Num timesteps: 300000
# Best mean reward: 1.13 - Last mean reward per episode: 0.63
# Num timesteps: 310000
# Best mean reward: 1.13 - Last mean reward per episode: 0.59
# Num timesteps: 320000
# Best mean reward: 1.13 - Last mean reward per episode: 0.55
# Num timesteps: 330000
# Best mean reward: 1.13 - Last mean reward per episode: 0.55
# Num timesteps: 340000
# Best mean reward: 1.13 - Last mean reward per episode: 0.55
# Num timesteps: 350000
# Best mean reward: 1.13 - Last mean reward per episode: 0.55
# Num timesteps: 360000
# Best mean reward: 1.13 - Last mean reward per episode: 0.57
# Num timesteps: 370000
# Best mean reward: 1.13 - Last mean reward per episode: 0.54
# Num timesteps: 380000
# Best mean reward: 1.13 - Last mean reward per episode: 0.57
# Num timesteps: 390000
# Best mean reward: 1.13 - Last mean reward per episode: 0.58
# Num timesteps: 400000
# Best mean reward: 1.13 - Last mean reward per episode: 0.60
# Num timesteps: 410000
# Best mean reward: 1.13 - Last mean reward per episode: 0.57
# Num timesteps: 420000
# Best mean reward: 1.13 - Last mean reward per episode: 0.56
# Num timesteps: 430000
# Best mean reward: 1.13 - Last mean reward per episode: 0.55
# Num timesteps: 440000
# Best mean reward: 1.13 - Last mean reward per episode: 0.56
# Num timesteps: 450000
# Best mean reward: 1.13 - Last mean reward per episode: 0.55
# Num timesteps: 460000
# Best mean reward: 1.13 - Last mean reward per episode: 0.55
# Num timesteps: 470000
# Best mean reward: 1.13 - Last mean reward per episode: 0.53
# Num timesteps: 480000
# Best mean reward: 1.13 - Last mean reward per episode: 0.54
# Num timesteps: 490000
# Best mean reward: 1.13 - Last mean reward per episode: 0.56
# Num timesteps: 500000
# Best mean reward: 1.13 - Last mean reward per episode: 0.57
# Num timesteps: 510000
# Best mean reward: 1.13 - Last mean reward per episode: 0.55
# Num timesteps: 520000
# Best mean reward: 1.13 - Last mean reward per episode: 0.56
# Num timesteps: 530000
# Best mean reward: 1.13 - Last mean reward per episode: 0.54
# Num timesteps: 540000
# Best mean reward: 1.13 - Last mean reward per episode: 0.55
# Num timesteps: 550000
# Best mean reward: 1.13 - Last mean reward per episode: 0.55
# Num timesteps: 560000
# Best mean reward: 1.13 - Last mean reward per episode: 0.53
# Num timesteps: 570000
# Best mean reward: 1.13 - Last mean reward per episode: 0.51
# Num timesteps: 580000
# Best mean reward: 1.13 - Last mean reward per episode: 0.51
# Num timesteps: 590000
# Best mean reward: 1.13 - Last mean reward per episode: 0.52
# Num timesteps: 600000
# Best mean reward: 1.13 - Last mean reward per episode: 0.50
# Num timesteps: 610000
# Best mean reward: 1.13 - Last mean reward per episode: 0.49
# Num timesteps: 620000
# Best mean reward: 1.13 - Last mean reward per episode: 0.47
# Num timesteps: 630000
# Best mean reward: 1.13 - Last mean reward per episode: 0.49
# Num timesteps: 640000
# Best mean reward: 1.13 - Last mean reward per episode: 0.47
# Num timesteps: 650000
# Best mean reward: 1.13 - Last mean reward per episode: 0.46
# Num timesteps: 660000
# Best mean reward: 1.13 - Last mean reward per episode: 0.45
# Num timesteps: 670000
# Best mean reward: 1.13 - Last mean reward per episode: 0.42
# Num timesteps: 680000
# Best mean reward: 1.13 - Last mean reward per episode: 0.40
# Num timesteps: 690000
# Best mean reward: 1.13 - Last mean reward per episode: 0.38
# Num timesteps: 700000
# Best mean reward: 1.13 - Last mean reward per episode: 0.35
# Num timesteps: 710000
# Best mean reward: 1.13 - Last mean reward per episode: 0.33
# Num timesteps: 720000
# Best mean reward: 1.13 - Last mean reward per episode: 0.34
# Num timesteps: 730000
# Best mean reward: 1.13 - Last mean reward per episode: 0.33
# Num timesteps: 740000
# Best mean reward: 1.13 - Last mean reward per episode: 0.33
# Num timesteps: 750000
# Best mean reward: 1.13 - Last mean reward per episode: 0.31
# Num timesteps: 760000
# Best mean reward: 1.13 - Last mean reward per episode: 0.31
# Num timesteps: 770000
# Best mean reward: 1.13 - Last mean reward per episode: 0.31
# Num timesteps: 780000
# Best mean reward: 1.13 - Last mean reward per episode: 0.30
# Num timesteps: 790000
# Best mean reward: 1.13 - Last mean reward per episode: 0.30
# Num timesteps: 800000
# Best mean reward: 1.13 - Last mean reward per episode: 0.28
# Num timesteps: 810000
# Best mean reward: 1.13 - Last mean reward per episode: 0.26
# Num timesteps: 820000
# Best mean reward: 1.13 - Last mean reward per episode: 0.24
# Num timesteps: 830000
# Best mean reward: 1.13 - Last mean reward per episode: 0.22
# Num timesteps: 840000
# Best mean reward: 1.13 - Last mean reward per episode: 0.21
# Num timesteps: 850000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 860000
# Best mean reward: 1.13 - Last mean reward per episode: 0.21
# Num timesteps: 870000
# Best mean reward: 1.13 - Last mean reward per episode: 0.21
# Num timesteps: 880000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 890000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 900000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 910000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 920000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 930000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 940000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 950000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 960000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 970000
# Best mean reward: 1.13 - Last mean reward per episode: 0.21
# Num timesteps: 980000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 990000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 1000000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 1010000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 1020000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 1030000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 1040000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 1050000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 1060000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 1070000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 1080000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 1090000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 1100000
# Best mean reward: 1.13 - Last mean reward per episode: 0.22
# Num timesteps: 1110000
# Best mean reward: 1.13 - Last mean reward per episode: 0.23
# Num timesteps: 1120000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 1130000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 1140000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 1150000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 1160000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1170000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1180000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 1190000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 1200000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 1210000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 1220000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 1230000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 1240000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 1250000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 1260000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 1270000
# Best mean reward: 1.13 - Last mean reward per episode: 0.13
# Num timesteps: 1280000
# Best mean reward: 1.13 - Last mean reward per episode: 0.12
# Num timesteps: 1290000
# Best mean reward: 1.13 - Last mean reward per episode: 0.12
# Num timesteps: 1300000
# Best mean reward: 1.13 - Last mean reward per episode: 0.13
# Num timesteps: 1310000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 1320000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 1330000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 1340000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1350000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 1360000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 1370000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 1380000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1390000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1400000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 1410000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1420000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1430000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1440000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1450000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1460000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 1470000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 1480000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 1490000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 1500000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 1510000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 1520000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 1530000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 1540000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 1550000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 1560000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 1570000
# Best mean reward: 1.13 - Last mean reward per episode: 0.24
# Num timesteps: 1580000
# Best mean reward: 1.13 - Last mean reward per episode: 0.25
# Num timesteps: 1590000
# Best mean reward: 1.13 - Last mean reward per episode: 0.25
# Num timesteps: 1600000
# Best mean reward: 1.13 - Last mean reward per episode: 0.26
# Num timesteps: 1610000
# Best mean reward: 1.13 - Last mean reward per episode: 0.23
# Num timesteps: 1620000
# Best mean reward: 1.13 - Last mean reward per episode: 0.21
# Num timesteps: 1630000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 1640000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 1650000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 1660000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 1670000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 1680000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 1690000
# Best mean reward: 1.13 - Last mean reward per episode: 0.13
# Num timesteps: 1700000
# Best mean reward: 1.13 - Last mean reward per episode: 0.13
# Num timesteps: 1710000
# Best mean reward: 1.13 - Last mean reward per episode: 0.12
# Num timesteps: 1720000
# Best mean reward: 1.13 - Last mean reward per episode: 0.11
# Num timesteps: 1730000
# Best mean reward: 1.13 - Last mean reward per episode: 0.11
# Num timesteps: 1740000
# Best mean reward: 1.13 - Last mean reward per episode: 0.11
# Num timesteps: 1750000
# Best mean reward: 1.13 - Last mean reward per episode: 0.12
# Num timesteps: 1760000
# Best mean reward: 1.13 - Last mean reward per episode: 0.11
# Num timesteps: 1770000
# Best mean reward: 1.13 - Last mean reward per episode: 0.11
# Num timesteps: 1780000
# Best mean reward: 1.13 - Last mean reward per episode: 0.11
# Num timesteps: 1790000
# Best mean reward: 1.13 - Last mean reward per episode: 0.11
# Num timesteps: 1800000
# Best mean reward: 1.13 - Last mean reward per episode: 0.11
# Num timesteps: 1810000
# Best mean reward: 1.13 - Last mean reward per episode: 0.11
# Num timesteps: 1820000
# Best mean reward: 1.13 - Last mean reward per episode: 0.11
# Num timesteps: 1830000
# Best mean reward: 1.13 - Last mean reward per episode: 0.12
# Num timesteps: 1840000
# Best mean reward: 1.13 - Last mean reward per episode: 0.12
# Num timesteps: 1850000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 1860000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 1870000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1880000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 1890000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1900000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1910000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1920000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 1930000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1940000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 1950000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 1960000
# Best mean reward: 1.13 - Last mean reward per episode: 0.21
# Num timesteps: 1970000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 1980000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 1990000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 2000000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 2010000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 2020000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 2030000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 2040000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 2050000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 2060000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 2070000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 2080000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 2090000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 2100000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 2110000
# Best mean reward: 1.13 - Last mean reward per episode: 0.21
# Num timesteps: 2120000
# Best mean reward: 1.13 - Last mean reward per episode: 0.25
# Num timesteps: 2130000
# Best mean reward: 1.13 - Last mean reward per episode: 0.25
# Num timesteps: 2140000
# Best mean reward: 1.13 - Last mean reward per episode: 0.24
# Num timesteps: 2150000
# Best mean reward: 1.13 - Last mean reward per episode: 0.24
# Num timesteps: 2160000
# Best mean reward: 1.13 - Last mean reward per episode: 0.22
# Num timesteps: 2170000
# Best mean reward: 1.13 - Last mean reward per episode: 0.22
# Num timesteps: 2180000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 2190000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 2200000
# Best mean reward: 1.13 - Last mean reward per episode: 0.21
# Num timesteps: 2210000
# Best mean reward: 1.13 - Last mean reward per episode: 0.23
# Num timesteps: 2220000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 2230000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 2240000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 2250000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 2260000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 2270000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 2280000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 2290000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 2300000
# Best mean reward: 1.13 - Last mean reward per episode: 0.21
# Num timesteps: 2310000
# Best mean reward: 1.13 - Last mean reward per episode: 0.23
# Num timesteps: 2320000
# Best mean reward: 1.13 - Last mean reward per episode: 0.23
# Num timesteps: 2330000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 2340000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 2350000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 2360000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 2370000
# Best mean reward: 1.13 - Last mean reward per episode: 0.16
# Num timesteps: 2380000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 2390000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 2400000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 2410000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 2420000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 2430000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 2440000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 2450000
# Best mean reward: 1.13 - Last mean reward per episode: 0.18
# Num timesteps: 2460000
# Best mean reward: 1.13 - Last mean reward per episode: 0.21
# Num timesteps: 2470000
# Best mean reward: 1.13 - Last mean reward per episode: 0.20
# Num timesteps: 2480000
# Best mean reward: 1.13 - Last mean reward per episode: 0.21
# Num timesteps: 2490000
# Best mean reward: 1.13 - Last mean reward per episode: 0.19
# Num timesteps: 2500000
# Best mean reward: 1.13 - Last mean reward per episode: 0.17
# Num timesteps: 2510000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 2520000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2530000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2540000
# Best mean reward: 1.13 - Last mean reward per episode: 0.13
# Num timesteps: 2550000
# Best mean reward: 1.13 - Last mean reward per episode: 0.13
# Num timesteps: 2560000
# Best mean reward: 1.13 - Last mean reward per episode: 0.13
# Num timesteps: 2570000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2580000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2590000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2600000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2610000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2620000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2630000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2640000
# Best mean reward: 1.13 - Last mean reward per episode: 0.13
# Num timesteps: 2650000
# Best mean reward: 1.13 - Last mean reward per episode: 0.13
# Num timesteps: 2660000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2670000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2680000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2690000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2700000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 2710000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 2720000
# Best mean reward: 1.13 - Last mean reward per episode: 0.15
# Num timesteps: 2730000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2740000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2750000
# Best mean reward: 1.13 - Last mean reward per episode: 0.13
# Num timesteps: 2760000
# Best mean reward: 1.13 - Last mean reward per episode: 0.12
# Num timesteps: 2770000
# Best mean reward: 1.13 - Last mean reward per episode: 0.12
# Num timesteps: 2780000
# Best mean reward: 1.13 - Last mean reward per episode: 0.11
# Num timesteps: 2790000
# Best mean reward: 1.13 - Last mean reward per episode: 0.10
# Num timesteps: 2800000
# Best mean reward: 1.13 - Last mean reward per episode: 0.09
# Num timesteps: 2810000
# Best mean reward: 1.13 - Last mean reward per episode: 0.09
# Num timesteps: 2820000
# Best mean reward: 1.13 - Last mean reward per episode: 0.09
# Num timesteps: 2830000
# Best mean reward: 1.13 - Last mean reward per episode: 0.08
# Num timesteps: 2840000
# Best mean reward: 1.13 - Last mean reward per episode: 0.08
# Num timesteps: 2850000
# Best mean reward: 1.13 - Last mean reward per episode: 0.09
# Num timesteps: 2860000
# Best mean reward: 1.13 - Last mean reward per episode: 0.10
# Num timesteps: 2870000
# Best mean reward: 1.13 - Last mean reward per episode: 0.11
# Num timesteps: 2880000
# Best mean reward: 1.13 - Last mean reward per episode: 0.12
# Num timesteps: 2890000
# Best mean reward: 1.13 - Last mean reward per episode: 0.12
# Num timesteps: 2900000
# Best mean reward: 1.13 - Last mean reward per episode: 0.11
# Num timesteps: 2910000
# Best mean reward: 1.13 - Last mean reward per episode: 0.10
# Num timesteps: 2920000
# Best mean reward: 1.13 - Last mean reward per episode: 0.10
# Num timesteps: 2930000
# Best mean reward: 1.13 - Last mean reward per episode: 0.10
# Num timesteps: 2940000
# Best mean reward: 1.13 - Last mean reward per episode: 0.09
# Num timesteps: 2950000
# Best mean reward: 1.13 - Last mean reward per episode: 0.09
# Num timesteps: 2960000
# Best mean reward: 1.13 - Last mean reward per episode: 0.08
# Num timesteps: 2970000
# Best mean reward: 1.13 - Last mean reward per episode: 0.10
# Num timesteps: 2980000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 2990000
# Best mean reward: 1.13 - Last mean reward per episode: 0.14
# Num timesteps: 3000000
# Best mean reward: 1.13 - Last mean reward per episode: 0.13

# %%
print('Total time taken: {} min'.format((end - start)/60))
# Out:
# Total time taken: 82.31798078219096 min

# %% [markdown]
# ### Inference

# %%
env.M.flag_=True
# env.M.flag_=False
obs=env.reset()
obs=obs[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.M to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.M` for environment variables or `env.get_wrapper_attr('M')` that will search the reminding wrappers.
#   logger.warn(

# %%
i=0
while i<1000:
    action, _states = model.predict(obs)
    obs, rewards, dones, _, info = env.step(int(action))
    if dones:
        break
    i+=1

# %%
env.args = get_args(*mbb_beam(rd=env.rd))
t__, c__ = fast_stopt(env.args, env.x)
t__
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.rd to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.rd` for environment variables or `env.get_wrapper_attr('rd')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.x to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.x` for environment variables or `env.get_wrapper_attr('x')` that will search the reminding wrappers.
#   logger.warn(
# 1430.9624054489905

# %%
c__
# Out:
# 0.15008500000000002

# %%
print(i)
# Out:
# 100

# %%
env.render()
# Out:
# Final Cantilever beam design:

# %%
results_plotter.plot_results([log_dir], ts, results_plotter.X_TIMESTEPS, "CantileverEnv")

# %%
env.M.flag_=False
obs=env.reset()
obs=obs[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.M to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.M` for environment variables or `env.get_wrapper_attr('M')` that will search the reminding wrappers.
#   logger.warn(

# %%
# Load the agent
model_best = PPO.load(log_dir + "best_model.zip",env=env)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.render_mode to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.render_mode` for environment variables or `env.get_wrapper_attr('render_mode')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:77: UserWarning: The `render_mode` attribute is not defined in your environment. It will be set to None.
#   warnings.warn("The `render_mode` attribute is not defined in your environment. It will be set to None.")

# %%
i=0
while i<1000:
    action, _states = model_best.predict(obs)
    
    obs, rewards, dones, _,info = env.step(int(action))
    if dones:
        break
    i+=1

# %%
i
# Out:
# 100

# %%
env.render()
# Out:
# Final Cantilever beam design:

# %%
env.args = get_args(*mbb_beam(rd=env.rd))
t__, c__ = fast_stopt(env.args, env.x)
t__
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.rd to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.rd` for environment variables or `env.get_wrapper_attr('rd')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.x to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.x` for environment variables or `env.get_wrapper_attr('x')` that will search the reminding wrappers.
#   logger.warn(
# 3018.282052947002

# %%
c__
# Out:
# 0.50005
